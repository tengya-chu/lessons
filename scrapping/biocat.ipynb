# %% [markdown]
# ### Web Scrapping

# %% [markdown]
# **Problema real**: A nuestra compañera Tengya su jefe le ha mandado la ardua tarea de recopilar información de la siguiente página WEB: https://biocat.force.com/Catalonialifesciencesdatabase/s/

# %% [markdown]
# Hay más de 1600 empresas páginadas de 20 en 20, y para cada una de ellas hay que recopilar los siguientes campos:

# %%
campos = ['company', 'location', 'main_sector', 'subsector', 'primary', 'description']

# %% [markdown]
# Yendo rápido, podemos hacer una estimaciín del tiempo que nos ocuparía:

# %% [markdown]
# $$tiempo\:necesario = 1609\times2\:min = 3218\:min = 53h = 6.7\:jornadas\:laborales$$

# %% [markdown]
# **Alternativa**: Utilizar nuestros conocimientos de **SCRAPPING** como **data analysts**

# %% [markdown]
# #### Librerias necesarias

# %% [markdown]
# conda install -c conda-forge selenium   (o bien pip install selenium)

# %% [markdown]
# conda install -c anaconda beautifulsoup4   (o bien pip install beautifulsoup4)

# %% [markdown]
# **Es necesario tener le navegador Chrome instalado**

# %% [markdown]
# #### Código:

# %%
import time
import pandas as pd
import re
from bs4 import BeautifulSoup
from selenium import webdriver

# %% [markdown]
# Definimos la URL:

# %%
url_base = "https://biocat.force.com/Catalonialifesciencesdatabase/s/"

# %% [markdown]
# Vamos a controlar una instancia de Chrome a través de Python:

# %%
driver = webdriver.Chrome("./chromedriver.exe")

# %% [markdown]
# Nos descargamos toda la información de la página, incluído el html que se genera con el javascript que llega incrustado:

# %%
driver.get(url_base)
time.sleep(3)

# %% [markdown]
# Para obtener la página en HTML usamos:

# %%
html = driver.execute_script("return document.getElementsByTagName('html')[0].innerHTML")
time.sleep(2)

# %%
html
# Out:
# '<head><title>Catalonia Health and Life Sciences Data Platform</title><link rel="shortcut icon" href="https://biocat.force.com/Catalonialifesciencesdatabase/resource/1664541382000/BiocatFavicon"><meta name="viewport" content="initial-scale=1.0, maximum-scale=5.0, minimum-scale=1.0, minimal-ui">\n<style>\n        .auraMsgMask, #auraErrorMask, body .auraLoadingBox {\n            display: none;\n        }\n\n        .spaError {\n            padding: 10px;\n        }\n\n        .spaErrorLink {\n            padding: 10px 0;\n            display: block\n        }\n\n        </style><style></style><link data-href="/Catalonialifesciencesdatabase/s/sfsites/l/%7B%22mode%22%3A%22PROD%22%2C%22app%22%3A%22siteforce%3AcommunityApp%22%2C%22loaded%22%3A%7B%22APPLICATION%40markup%3A%2F%2Fsiteforce%3AcommunityApp%22%3A%22HU7u5uZWBH_8Nshn9opI8g%22%7D%2C%22styleContext%22%3A%7B%22c%22%3A%22webkit%22%2C%22x%22%3A%5B%22isDesktop%22%5D%2C%22tokens%22%3A%5B%22markup%3A%2F%2Fsiteforce%3AserializedTokens%22%2C%22markup%3A%2F%2Fforce%3AsldsTokens%22%2C%22markup%3A%2F%2Fsiteforce%3AcommunityTokens%22%2C%22markup%3A%2F%2Fforce%3AformFactorLarge%22%2C%22markup%3A%2F%2Fsiteforce%3AcommunityFormFactorLarge%22%2C%22markup%3A%2F%2Fsiteforce%3AauraDynamicTokens%22%2C%22markup%3A%2F%2Fsiteforce%3AsldsFontOverride%22%5D%2C%22tuid%22%3A%229PBqu-FpjtlZ9sBjLLE07A%22%2C%22cuid%22%3A447746204%7D%2C%22pathPrefix%22%3A%22%2FCatalonialifesciencesdatabase%22%7D/app.css?2=&amp;aura.attributes=%7B%22ac%22%3A%22%22%2C%22authenticated%22%3A%22false%22%2C%22brandingSetId%22%3A%22ccdae195-9f21-4fb8-95ff-e3d09e617605%22%2C%22formFactor%22%3A%22LARGE%22%2C%22isHybrid%22%3A%22false%22%2C%22language%22%3A%22en_US%22%2C%22pageId%22%3A%22c6bd20e0-1a22-4f54-973e-4071fe8c67dc%22%2C%22publishedChangelistNum%22%3A%2220%22%2C%22schema%22%3A%22Published%22%2C%22themeLayoutType%22%3A%22Inner%22%2C%22viewType%22%3A%22Published%22%7D" class="auraCss" rel="stylesheet" type="text/css" href="/Catalonialifesciencesdatabase/s/sfsites/l/%7B%22mode%22%3A%22PROD%22%2C%22app%22%3A%22siteforce%3AcommunityApp%22%2C%22loaded%22%3A%7B%22APPLICATION%40markup%3A%2F%2Fsiteforce%3AcommunityApp%22%3A%22HU7u5uZWBH_8Nshn9opI8g%22%7D%2C%22styleContext%22%3A%7B%22c%22%3A%22webkit%22%2C%22x%22%3A%5B%22isDesktop%22%5D%2C%22tokens%22%3A%5B%22markup%3A%2F%2Fsiteforce%3AserializedTokens%22%2C%22markup%3A%2F%2Fforce%3AsldsTokens%22%2C%22markup%3A%2F%2Fsiteforce%3AcommunityTokens%22%2C%22markup%3A%2F%2Fforce%3AformFactorLarge%22%2C%22markup%3A%2F%2Fsiteforce%3AcommunityFormFactorLarge%22%2C%22markup%3A%2F%2Fsiteforce%3AauraDynamicTokens%22%2C%22markup%3A%2F%2Fsiteforce%3AsldsFontOverride%22%5D%2C%22tuid%22%3A%229PBqu-FpjtlZ9sBjLLE07A%22%2C%22cuid%22%3A447746204%7D%2C%22pathPrefix%22%3A%22%2FCatalonialifesciencesdatabase%22%7D/app.css?2=&amp;aura.attributes=%7B%22ac%22%3A%22%22%2C%22authenticated%22%3A%22false%22%2C%22brandingSetId%22%3A%22ccdae195-9f21-4fb8-95ff-e3d09e617605%22%2C%22formFactor%22%3A%22LARGE%22%2C%22isHybrid%22%3A%22false%22%2C%22language%22%3A%22en_US%22%2C%22pageId%22%3A%22c6bd20e0-1a22-4f54-973e-4071fe8c67dc%22%2C%22publishedChangelistNum%22%3A%2220%22%2C%22schema%22%3A%22Published%22%2C%22themeLayoutType%22%3A%22Inner%22%2C%22viewType%22%3A%22Published%22%7D">\n<link rel="stylesheet" id="siteforce_fontStyleSheet" href="/Catalonialifesciencesdatabase/s/sfsites/runtimedownload/fonts.css?lastMod=1659357200000&amp;brandSet=ccdae195-9f21-4fb8-95ff-e3d09e617605" type="text/css">\n<style id="themeCSS"></style><style id="customCSS"></style><style>.siteforceContentArea .comm-layout-column .ui-widget:not(:last-child),.siteforceContentArea .cb-section_column .ui-widget:not(:last-child){margin-bottom:var(--lwc-uiWidgetMarginBottom,1.5rem)}.siteforceContentArea .comm-layout-column:not(:empty){padding-top:var(--lwc-layoutVerticalPadding,0.75rem);padding-bottom:var(--lwc-layoutVerticalPadding,0.75rem)}:root{--dxp-g-root:var(--lwc-dxpGRoot,rgb(255, 255, 255));--dxp-g-root-1:var(--lwc-dxpGRoot1,rgb(235, 235, 235));--d ...

# %% [markdown]
# Una vez tenemos el HTML generado ya podemos utilizar BeautifulSoup:

# %%
soup = BeautifulSoup(html, "html.parser")

# %% [markdown]
# Ahora la gracia está en analizar bien el HTML y donde están las etiquetas de los elementos que nos interesa scrappear.
#
# Para ver el documento HTML de la forma más ordenada posible, podemos utilizar:

# %%
from lxml import etree, html

document_root = html.fromstring(str(soup))
print(etree.tostring(document_root, encoding='unicode', pretty_print=True))
# Out:
# <html>
#   <head><title>Catalonia Health and Life Sciences Data Platform</title><link href="https://biocat.force.com/Catalonialifesciencesdatabase/resource/1664541382000/BiocatFavicon" rel="shortcut icon"/><meta content="initial-scale=1.0, maximum-scale=5.0, minimum-scale=1.0, minimal-ui" name="viewport"/>
# <style>
#         .auraMsgMask, #auraErrorMask, body .auraLoadingBox {
#             display: none;
#         }
#
#         .spaError {
#             padding: 10px;
#         }
#
#         .spaErrorLink {
#             padding: 10px 0;
#             display: block
#         }
#
#         </style><style/><link class="auraCss" data-href="/Catalonialifesciencesdatabase/s/sfsites/l/%7B%22mode%22%3A%22PROD%22%2C%22app%22%3A%22siteforce%3AcommunityApp%22%2C%22loaded%22%3A%7B%22APPLICATION%40markup%3A%2F%2Fsiteforce%3AcommunityApp%22%3A%22HU7u5uZWBH_8Nshn9opI8g%22%7D%2C%22styleContext%22%3A%7B%22c%22%3A%22webkit%22%2C%22x%22%3A%5B%22isDesktop%22%5D%2C%22tokens%22%3A%5B%22markup%3A%2F%2Fsiteforce%3AserializedTokens%22%2C%22markup%3A%2F%2Fforce%3AsldsTokens%22%2C%22markup%3A%2F%2Fsiteforce%3AcommunityTokens%22%2C%22markup%3A%2F%2Fforce%3AformFactorLarge%22%2C%22markup%3A%2F%2Fsiteforce%3AcommunityFormFactorLarge%22%2C%22markup%3A%2F%2Fsiteforce%3AauraDynamicTokens%22%2C%22markup%3A%2F%2Fsiteforce%3AsldsFontOverride%22%5D%2C%22tuid%22%3A%229PBqu-FpjtlZ9sBjLLE07A%22%2C%22cuid%22%3A447746204%7D%2C%22pathPrefix%22%3A%22%2FCatalonialifesciencesdatabase%22%7D/app.css?2=&amp;aura.attributes=%7B%22ac%22%3A%22%22%2C%22authenticated%22%3A%22false%22%2C%22brandingSetId%22%3A%22ccdae195-9f21-4fb8-95ff-e3d09e617605%22%2C%22formFactor%22%3A%22LARGE%22%2C%22isHybrid%22%3A%22false%22%2C%22language%22%3A%22en_US%22%2C%22pageId%22%3A%22c6bd20e0-1a22-4f54-973e-4071fe8c67dc%22%2C%22publishedChangelistNum%22%3A%2220%22%2C%22schema%22%3A%22Published%22%2C%22themeLayoutType%22%3A%22Inner%22%2C%22viewType%22%3A%22Published%22%7D" href="/Catalonialifesciencesdatabase/s/sfsites/l/%7B%22mode%22%3A%22PROD%22%2C%22app%22%3A%22siteforce%3AcommunityApp%22%2C%22loaded%22%3A%7B%22APPLICATION%40markup%3A%2F%2Fsiteforce%3AcommunityApp%22%3A%22HU7u5uZWBH_8Nshn9opI8g%22%7D%2C%22styleContext%22%3A%7B%22c%22%3A%22webkit%22%2C%22x%22%3A%5B%22isDesktop%22%5D%2C%22tokens%22%3A%5B%22markup%3A%2F%2Fsiteforce%3AserializedTokens%22%2C%22markup%3A%2F%2Fforce%3AsldsTokens%22%2C%22markup%3A%2F%2Fsiteforce%3AcommunityTokens%22%2C%22markup%3A%2F%2Fforce%3AformFactorLarge%22%2C%22markup%3A%2F%2Fsiteforce%3AcommunityFormFactorLarge%22%2C%22markup%3A%2F%2Fsiteforce%3AauraDynamicTokens%22%2C%22markup%3A%2F%2Fsiteforce%3AsldsFontOverride%22%5D%2C%22tuid%22%3A%229PBqu-FpjtlZ9sBjLLE07A%22%2C%22cuid%22%3A447746204%7D%2C%22pathPrefix%22%3A%22%2FCatalonialifesciencesdatabase%22%7D/app.css?2=&amp;aura.attributes=%7B%22ac%22%3A%22%22%2C%22authenticated%22%3A%22false%22%2C%22brandingSetId%22%3A%22ccdae195-9f21-4fb8-95ff-e3d09e617605%22%2C%22formFactor%22%3A%22LARGE%22%2C%22isHybrid%22%3A%22false%22%2C%22language%22%3A%22en_US%22%2C%22pageId%22%3A%22c6bd20e0-1a22-4f54-973e-4071fe8c67dc%22%2C%22publishedChangelistNum%22%3A%2220%22%2C%22schema%22%3A%22Published%22%2C%22themeLayoutType%22%3A%22Inner%22%2C%22viewType%22%3A%22Published%22%7D" rel="stylesheet" type="text/css"/>
# <link href="/Catalonialifesciencesdatabase/s/sfsites/runtimedownload/fonts.css?lastMod=1659357200000&amp;brandSet=ccdae195-9f21-4fb8-95ff-e3d09e617605" id="siteforce_fontStyleSheet" rel="stylesheet" type="text/css"/>
# <style id="themeCSS"/><style id="customCSS"/><style>.siteforceContentArea .comm-layout-column .ui-widget:not(:last-child),.siteforceContentArea .cb-section_column .ui-widget:not(:last-child){margin-bottom:var(--lwc-uiWidgetMarginBottom,1.5rem)}.siteforceContentArea .comm-layout-column:not(:empty){padding-top:var(--lwc-layoutVerticalPadding,0.75rem);padding-bottom:var(--lwc-layoutVerticalPadding,0.75rem)}:root{--dxp-g-root:var(--lwc-dxpGRoot,rgb(255, 255, 255));--dxp-g-root-1:var(--lwc-dxpGRoot1,rgb(235, 235, 235));--dxp-g-root-2:var(--lwc-dxpGRoot2,rgb(194, 194, 194));--dxp-g-root-3:var(--lwc-dxpGRoot3,rgb(133, 133, 133));--dxp-g-root-contrast:var(--lwc-dxpGRootContrast,#222222);--dxp-g-root-contrast-1:var(--lwc-dxpGRootContrast1,rgb(14, 14, 14));--dxp-g-root-contrast-2:var(--lwc-dxpGRootContrast2,rgb(0, 0, 0));--dxp-g-root-contrast-3:var(--lwc-dxpGRootContrast3,rgb(0, 0, 0));--dxp-g-neutral:var(--lwc-dxpGNeutral,#ecebea);--dxp-g-neutral-1:var(--lwc-dxpGNeutral1,rgb(217, 215, 213));--dxp-g-neutral-2:var(--lwc-dxpGNeutral2,rgb(178, 174, 170));--dxp-g-neutral-3:var(--lwc-dxpGNeutral3,rgb(118, 113, 107));--dxp-g-neutral-contrast:var(--lwc-dxpGNeutralContrast,#000);--dxp-g-neutral-contrast-1:var(--lwc-dxpGNeutralContrast1,#000);--dxp-g-neutral-contrast-2:var(--lwc-dxpGNeutralContrast2,#000);--dxp-g-neutral-contrast-3:var(--lwc-dxpGNeutralContrast3,#fff);--dxp-g-brand:var(--lwc-dxpGBrand,#0099DE);--dxp-g-brand-1:var(--lwc-dxpGBrand1,rgb(0, 125, 181));--dxp-g-brand-2:var(--lwc-dxpGBrand2,rgb(0, 69, 100));--dxp-g-brand-3:var(--lwc-dxpGBrand3,rgb(0, 0, 0));--dxp-g-brand-contrast:var(--lwc-dxpGBrandContrast,#FFFFFF);--dxp-g-brand-contrast-1:var(--lwc-dxpGBrandContrast1,rgb(255, 255, 255));--dxp-g-brand-contrast-2:var(--lwc-dxpGBrandContrast2,rgb(255, 255, 255));--dxp-g-brand-contrast-3:var(--lwc-dxpGBrandContrast3,rgb(255, 255, 255));--dxp-g-success:#4bca81;--dxp-g-success-1:#36b66c;--dxp-g-success-2:#237747;--dxp-g-success-3:#07190f;--dxp-g-success-contrast:#000;--dxp-g-success-contrast-1:#000;--dxp-g-success-contrast-2:#fff;--dxp-g-success-contrast-3:#fff;--dxp-g-destructive:#c23934;--dxp-g-destructive-1:#a2302b;--dxp-g-destructive-2:#611d1a;--dxp-g-destructive-3:#010000;--dxp-g-destructive-contrast:#fff;--dxp-g-destructive-contrast-1:#fff;--dxp-g-destructive-contrast-2:#fff;--dxp-g-destructive-contrast-3:#fff;--dxp-g-warning:#ffb75d;--dxp-g-warning-1:#ffa534;--dxp-g-warning-2:#e27d00;--dxp-g-warning-3:#673900;--dxp-g-warning-contrast:#000;--dxp-g-warning-contrast-1:#000;--dxp-g-warning-contrast-2:#000;--dxp-g-warning-contrast-3:#fff;--dxp-g-info:#16325c;--dxp-g-info-1:#0e203b;--dxp-g-info-2:#000000;--dxp-g-info-3:#000000;--dxp-g-info-contrast:#fff;--dxp-g-info-contrast-1:#fff;--dxp-g-info-contrast-2:#fff;--dxp-g-info-contrast-3:#fff;--dxp-g-offline:#444;--dxp-g-offline-1:#303030;--dxp-g-offline-2:#070707;--dxp-g-offline-3:#000000;--dxp-g-offline-contrast:#fff;--dxp-g-offline-contrast-1:#fff;--dxp-g-offline-contrast-2:#fff;--dxp-g-offline-contrast-3:#fff;--dxp-g-spacing-none:0!important;--dxp-g-spacing-xxxsmall:.125rem;--dxp-g-spacing-xxsmall:.25rem;--dxp-g-spacing-xsmall:.5rem;--dxp-g-spacing-small:.75rem;--dxp-g-spacing-medium:1rem;--dxp-g-spacing-large:1.5rem;--dxp-g-spacing-xlarge:2rem;--dxp-g-spacing-xxlarge:3rem;--dxp-g-root-font-family:var(--lwc-fontFamily,Ek Mukta);--dxp-g-heading-font-family:var(--lwc-fontFamilyHeader,Ek Mukta);--dxp-g-font-size-1:.625rem;--dxp-g-font-size-2:.75rem;--dxp-g-font-size-3:.8125rem;--dxp-g-font-size-4:.875rem;--dxp-g-font-size-5:1rem;--dxp-g-font-size-6:1.125rem;--dxp-g-font-size-7:1.25rem;--dxp-g-font-size-8:1.5rem;--dxp-g-font-size-9:1.75rem;--dxp-g-font-size-10:2rem;--dxp-g-font-size-11:2.625rem;--dxp-s-html-font-size:16px;--dxp-s-text-heading-extra-large-font-family:var(--lwc-fontFamilyHeader,Ek Mukta);--dxp-s-text-heading-extra-large-font-size:2.5rem;--dxp-s-text-heading-extra-large-font-style:normal;--dxp-s-text-heading-extra-large-font-weight:300;--dxp-s-text-heading-extra-large-text-decor ...
#   <body class="null comm-page-home">
#     <div class="auraMsgBox auraLoadingBox" id="auraLoadingBox">
#       <div class="logo"/>
#       <div class="spinner"/>
#       <span>Loading</span>
#     </div>
#     <div class="" id="auraErrorMask">
#       <div class="auraErrorBox" id="auraError">
#         <span><a class="close" id="dismissError">×</a>Sorry to interrupt</span>
#         <div id="auraErrorMessage">CSS Error</div>
#         <div id="auraErrorStack"/>
#         <div class="auraErrorFooter">
#           <a href="?nocache=https%3A%2F%2Fbiocat.force.com%2FCatalonialifesciencesdatabase%2Fs%2F" id="auraErrorReload">Refresh</a>
#         </div>
#       </div>
#     </div>
#     <!--"'-->
#     <script async="" nonce="" src="https://www.googletagmanager.com/gtag/js?id=G-RHHWYYP9S2&amp;l=dataLayer&amp;cx=c" type="text/javascript"/>
#     <script async="" nonce="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"/>
#     <script async="" src="https://www.googletagmanager.com/gtag/js?id=GTM-KQRP68Z"/>
#     <script nonce="" type="text/javascript">
#         (function() {
#             if (!navigator.cookieEnabled) {
#                 var cookieMessage = document.createElement("div");
#                 cookieMessage.innerHTML = "&lt;section role='alertdialog' tabindex='-1' aria-labelledby='prompt-heading-id' aria-describedby='prompt-message-wrapper'         class='slds-modal slds-fade-in-open slds-modal_prompt' aria-modal='true' style='color: rgb(62, 62, 60);'&gt;   &lt;div class='slds-modal__container'&gt;       &lt;header class='slds-modal__header slds-theme_info slds-theme_alert-texture'&gt;           &lt;h2 class='slds-text-heading_medium' id='prompt-heading-id'&gt;{0}&lt;/h2&gt;       &lt;/header&gt;       &lt;div class='slds-modal__content slds-p-around_medium' id='prompt-message-wrapper'&gt;           &lt;p&gt;{1}&lt;/p&gt;       &lt;/div&gt;   &lt;/div&gt;&lt;/section&gt;&lt;div class='slds-backdrop slds-backdrop_open'&gt;&lt;/div&gt;".replace("{0}", "Technical Stuff").replace("{1}", "To view this site, enable cookies in your browser.");
#                 document.body.appendChild(cookieMessage);
#             }
#         }());
#     </script>
#     <!--"'-->
#     <script nonce="" type="text/javascript">
#         (function() {
#             var templateType = "home";
#             var showUnsupportedBrowserModal = false;
#
#             if (templateType === "login") {
#                 return;
#             }
#
#             if (showUnsupportedBrowserModal) {
#                 var browserNotSupportedMessage = document.createElement("div");
#                 browserNotSupportedMessage.id = "community-browser-not-support-message";
#                 browserNotSupportedMessage.innerHTML = "&lt;section role='alertdialog' tabindex='-1' aria-labelledby='prompt-heading-id' aria-describedby='prompt-message-wrapper'         class='slds-modal slds-fade-in-open slds-modal_prompt' aria-modal='true' style='color: rgb(62, 62, 60);'&gt;   &lt;div class='slds-modal__container'&gt;       &lt;header class='slds-modal__header slds-theme_info slds-theme_alert-texture'&gt;           &lt;h2 class='slds-text-heading_medium' id='prompt-heading-id'&gt;{0}&lt;/h2&gt;       &lt;/header&gt;       &lt;div class='slds-modal__content slds-p-around_medium' id='prompt-message-wrapper'&gt;           &lt;p&gt;{1}&lt;/p&gt;       &lt;/div&gt;   &lt;footer class='slds-modal__footer slds-theme_default'&gt;               &lt;button class='slds-button slds-button_neutral'&gt;{GOT_IT_LABEL}&lt;/button&gt;           &lt;/footer&gt;&lt;/div&gt;&lt;/section&gt;&lt;div class='slds-backdrop slds-backdrop_open'&gt;&lt;/div&gt;".replace("{0}", "Your browser isn't supported")
#                                                                                               .replace("{1}", "Your browser doesn’t support some features on this site. For the best experience, update your browser to the latest version, or switch to another browser.")
#                                                                                               .replace("{GOT_IT_LABEL}", "Got It");
#                 document.body.appendChild(browserNotSupportedMessage);
#                 var okButton = document.querySelector("#community-browser-not-support-message .slds-modal__footer .slds-button");
#                 okButton.addEventListener("click", function() {
#                     closeModal();
#                 });
#             }
#
#             function closeModal() {
#                 var modal = document.getElementById("community-browser-not-support-message");
#                 if (modal) {
#                     document.body.removeChild(modal);
#                 }
#             }
#         }());
#     </script>
#     <!--"'-->
#     <script nonce="" type="text/javascript">
#         // keep this variable here, because users do window.picassoSPA in order to check if in PSSC.
#         var picassoSPA = {};
#         var comm__attrVariationKey = "11FxOYiYfpMxmANj4kGJzg";
#     </script>
#     <!--"'-->
#     <script nonce="">
# (function () {
# window.pageStartTime = (new Date()).getTime();
# window.Aura || (window.Aura = {});
# window.Aura.bootstrap || (window.Aura.bootstrap = {});
#
#
# var time = window.performance &amp;&amp; window.performance.now ? window.performance.now.bind(performance) : function(){return Date.now();};
# window.Aura.bootstrap.execInlineJs = time();
#
# window.Aura.inlineJsLoaded = true;
#
# var auraConfig = {"deftype":"APPLICATION","ns":{"internal":["adminsuccess","adminui","aloha_sales_forecasting","aloha_sales_opptysplit","aloha_sales_tm2","analytics","analyticsHome","analytics_data_manager","analyzer_framework","app_flexipage","appbuilder_actions_bridge","appexUi","assistantFramework","assistantFrameworkModules","assistant_builder","aura","auraStorage","auradev","auradocs","auraplat","b2b_buyer_builder","b2b_buyer_cart","b2b_buyer_coupons","b2b_buyer_data","b2b_buyer_einstein_activities","b2b_buyer_error_states","b2b_buyer_navigation","b2b_buyer_orders","b2b_buyer_pricing","b2b_buyer_product_category","b2b_buyer_product_details","b2b_buyer_product_images","b2b_buyer_promotions","b2b_buyer_quick_order","b2b_buyer_styling","b2b_buyer_wishlists","b2b_lwr_buyer_builder","b2b_search_api","b2b_search_builder","b2b_search_facets","b2b_search_management","b2b_search_product_card","b2b_search_results","b2b_search_results_tiles","b2b_search_settings","b2b_search_suggestions","b2b_storefront","b2c_lite_commerce","backToWork","briefcase","builder_communities_nba","builder_framework","builder_industries_arcgraph","builder_industries_dataprocessingengine","builder_industries_fsc","builder_industries_healthcare","builder_industries_insurance","builder_industries_interaction_rule","builder_industries_publicsector","builder_industries_survey","builder_industries_utilizationmanagement","builder_industries_visit","builder_payments","builder_platform_interaction","builder_platform_process","builder_platform_usage","builder_record_flexipage","builder_service_chatbots","calendar","calendar_view","cg_retail","chatbots","chatterui","ci_player","clients","clients_chatapp","cmsAuthor","commerce","commerce_builder","commerce_cart","commerce_catalog","commerce_checkout","commerce_console","commerce_data_provider","commerce_my_account","commerce_product_details","commerce_store_integrations","commerce_unified_checkout","commerce_unified_coupons","commerce_unified_promotions","communitySetup","community_article","community_builder","community_byo","community_case","community_content","community_dam","community_deflection","community_hierarchy","community_layout","community_login","community_navigation","community_reputation","community_runtime","community_setup","community_styling","community_topic","community_user","community_utils","componentReference","console","contentbuilder","contentpage","conversation","cooper","cordaDashboards","cxm","dashboards","dataImporter","ddcProspector","designtime_cdp","designtime_journeys","desktopDashboards","dxp","dxp_base","dxp_builder","dxp_content_layout","dxp_crm_search","dxp_data_provider","dxp_flow","dxp_flowruntime","dxp_form","dxp_layout","dxp_page_layout","dxp_search","dxp_styling","dxp_util","eamobile","educationcloud","einstein_assistant","einstein_discovery","einsteinbuilder","einsteinconduit","emailStream","emailui","embeddedMessaging","embeddedService","embedded_service","embedded_service_iframe","entityinterface","environmenthub","erb","escBuilder","essentials_trialassistant","exp_builder","experience","experience_availability","experience_einstein","experience_incident_mgmt","experience_messaging","explainability_setup","externalServicesSetup","feeds_answer_badging","feeds_autocomplete","feeds_best_answer","feeds_caching","feeds_cases","feeds_compact","feeds_discussion_threading","feeds_emoji","feeds_liking","feeds_metrics","feeds_paging","feeds_placeholding","feeds_post_body_content","feeds_replying","feeds_sorter","feeds_timestamping","feeds_translation","feeds_voting","fieldservicemobile","flexipage","flexipageEditor","flow_object_linking","flow_object_linking_admin_experience","flowruntime","flowtrigger","folder","force","forceChatter","forceChatterApi","forceCommunity","forceContent","forceDiscovery","forceHelp","forceKnowledge","forceSearch","forceTopic","formula","googleConnector","guardrails","hammerSetup","healthcloud","hello","home","hvcc","hybrid","hyperforce_assistant","indust ...
# auraConfig.context.styleContext = null;
#
# function auraPreInitBlock () {
#
#             $A.storageService.setIsolation("00D58000000c8Pi0DB4H000000k9tb0054H000007VUkWen_USccdae195-9f21-4fb8-95ff-e3d09e617605BLM165935720000000000000000");
#             $A.storageService.setVersion("56.0");
#             $A.storageService.setPartition("communityApp ~ /Catalonialifesciencesdatabase/s ~ 0DB4H000000k9tb");
#         (function(debug, key){
# function setCryptoKey(key) {
#     var buffer, view;
#     if (Array.isArray(key) &amp;&amp; (key.length === 32 || key.length === 16)) {
#         try {
#             buffer = new ArrayBuffer(key.length);
#             view = new Uint8Array(buffer);
#             view.set(key);
#         } catch (ignored) {}
#     }
#     CryptoAdapter.setKey(buffer);
# }
# debug &amp;&amp; $A.log('CryptoAdapter registering');
# var CryptoAdapter = $A.storageService.CryptoAdapter;
# CryptoAdapter.register();
# if (!$A.storageService.isRegisteredAdapter(CryptoAdapter.NAME)) {
#     $A.log('CryptoAdapter was not registered');
#     return;
# }
# setCryptoKey(key);
#
# }(true,[45, 103, -14, -85, -98, 116, 35, -79, -112, -19, 45, 17, -99, 123, -67, -91, 106, 64, -66, 95, -32, -59, -75, 115, 78, -21, 35, -113, 0, -55, -118, -30]));$A.storageService.initStorage({name: 'actions', persistent: true, secure: true, maxSize: 157286400, expiration: 900, autoRefreshInterval: 30, debugLogging: false, clearOnInit: false, version: ''});
# $A.storageService.initStorage({name: 'ComponentDefStorage', persistent: true, secure: false, maxSize: 104857600, expiration: 900, autoRefreshInterval: 900, debugLogging: false, clearOnInit: false, version: ''});
#
# }
#
# function initFramework () {
# 	window.Aura = window.Aura || {};
# 	window.Aura.app = auraConfig["context"]["app"];
# 	window.Aura.beforeFrameworkInit = Aura.beforeFrameworkInit || [];
# 	window.Aura.beforeFrameworkInit.push(auraPreInitBlock);
# 	window.Aura.inlineJsReady = time();
#
# 	;
#
# 	if (!window.Aura.frameworkJsReady) {
# 		window.Aura.initConfig = auraConfig;
# 	} else {
# 		if (auraConfig.context) {
# 			if (auraConfig.context.dpbp) {
# 				// Set a data attribute on document.body to signal engine to bypass global patching
# 				document.body.setAttribute("data-global-patching-bypass", "temporary-bypass");
# 			}
# 			$A.componentService.initLwcFeatureFlags(auraConfig.context);
# 		}
#
# 		// LockerService must be initialized before scripts can be executed.
# 		$A.lockerService.initialize(auraConfig.context);
#
# 		// scripts inside custom templates with Locker active are stored
# 		// until now since we need LockerService before running
#
# 		var scripts = window.Aura.inlineJsLocker;
# 		if (scripts) {
# 			for (var i = 0; i &lt; scripts.length; i++) {
# 				$A.lockerService.runScript(scripts[i]["callback"], scripts[i]["namespace"]);
# 			}
#
# 			delete window.Aura.inlineJsLocker;
# 		}
#
# 		if (true) {
# 			$A.initAsync(auraConfig);
# 		} else if (false) {
# 			$A.initConfig(auraConfig);
# 		}
# 	}
# }
#
# // Error msg
# var x = document.getElementById("dismissError");
# if (x) {
# 	x.addEventListener("click", function () {
# 		var auraErrorMask = document.getElementById("auraErrorMask");
# 		if (window["$A"]) {
# 			$A.util.removeClass(auraErrorMask, "auraForcedErrorBox");
# 			$A.util.removeClass($A.util.getElement("auraErrorReload"), "show");
# 		} else {
# 			document.body.removeChild(auraErrorMask);
# 		}
# 	});
# }
#
# setTimeout(initFramework, 0); // ensure async
#
#
#
# var appCssLoadingCount = 0;
# function onLoadStyleSheets(event) {
# 	if(event){
# 		var element = event.target;
# 		element.removeEventListener("load",onLoadStyleSheets);
# 		element.removeEventListener("error",onLoadStyleSheetsError);
# 	}
# 	window.Aura.bootstrap.appCssLoading = (--appCssLoadingCount) &gt; 0;
# 	if (!window.Aura.bootstrap.appCssLoading) {
# 		if (typeof window.Aura.bootstrap.appCssLoadedCallback === "function") {
# 			window.Aura.bootstrap.appCssLoadedCallback();
# 			window.Aura.bootstrap.appCssLoadedCallback = undefined;
# 		}
# 	}
# }
# function onLoadStyleSheetsError(event) {
# 	window.Aura.bootstrap.hasCssLoadError = true;
# 	onLoadStyleSheets(event);
# }
#
# var auraCss = document.getElementsByClassName("auraCss");
# var current;
# window.Aura.bootstrap.appCssLoading = auraCss.length &gt; 0;
# for (var c=0,length=auraCss.length;c&lt;length;c++) {
# 	current = auraCss[c];
# 	appCssLoadingCount++;
# 	if(auraConfig.applyCssVarPolyfill) {
# 		loadViaAjax(current, auraConfig.cssVariables);
# 	} else {
# 		current.addEventListener("load",onLoadStyleSheets);
# 		current.addEventListener("error",onLoadStyleSheetsError);
# 		current.href = current.getAttribute("data-href");
# 	}
# }
#
# function rewriteCssVars(css, varLookup) {
# 	var VAR_BEGINNING = "var(--",
# 		VAR_PATTERN = /var\(--[^-]+-(.*?)\)/g,
# 		startIndex = 0,
# 		output = [],
# 		result;
#
# 	function processInContext(css, start, delimiter) {
# 		while( start++ &amp;&amp; start &lt; css.length) {
# 			if(css[start] === delimiter) {
#
# 				return start;
# 			}
# 		}
# 	}
#
# 	function processParenthesesInContext(css, start) {
# 		var opens = 0; var closes = 0;
# 		while(start &lt; css.length) {
# 			// This allows us to support nested variables.
# 			// Count "open" and "close" parentheses. These must match before we return.
# 			// Note: this assumes parentheses formatting is valid.
# 			if (css[start] === "(") { opens++; }
# 			else if (css[start] === ")") { closes++; }
# 			if(opens === closes) {
# 				return start;
# 			}
# 			start++;
# 		}
# 	}
#
# 	function findVarEnd(css) {
# 		for(var idx = VAR_BEGINNING.length; idx &lt; css.length; idx++) {
# 			switch(css[idx]) {
# 				case "'":
# 					idx = processInContext(css, idx, "'");
# 					break;
# 				case '"':
# 					idx = processInContext(css, idx, '"');
# 					break;
# 				case "(":
# 					// we process parentheses differently because open/close must match
# 					idx = processParenthesesInContext(css, idx);
# 					break;
# 				case ")":
# 					//end of var
# 					return idx + 1;
# 				default:
# 				//continue
# 			}
# 		}
# 	}
#
# 	function extractValue(declaration, lookup) {
# 		var parts = declaration.split(",");
# 		// try to get value from the lookup
# 		if(lookup) {
# 			var match = /var\(--(.*)(?:$|\))/.exec(parts[0]);
# 			if(match &amp;&amp; match.length &gt; 1) {
# 				var value = lookup[match[1]];
# 				if(value) {
# 					return value;
# 				}
# 			}
# 		}
# 		// get hard coded fallback value
# 		if(parts.length &gt; 1) {
# 			var val = declaration.substring(declaration.indexOf(",") + 1);
# 			var fallback = val.substring(0, val.length-1);
#
# 			// if the fallback is another variable, resolve the value recursively
# 			if (fallback.indexOf("var(") != -1) {
# 				return extractValue(fallback, lookup);
# 			}
# 			return fallback;
# 		}
# 	}
#
# 	function replaceBlobUrlSubresources(css) {
# 		var anchor = document.createElement("a");
# 		return css.replace(/\b(url\s*\(\s*['"]?)([^)"']+)(['"]?\))/g, function (match, left, url, right) {
# 			anchor.href = url;
# 			return left + anchor.href + right;
# 		});
# 	}
#
# 	while ( (result = VAR_PATTERN.exec(css)) ) {
#
# 		output.push(css.substring(startIndex, result.index));
# 		startIndex = result.index;
#
# 		var endIndex = startIndex + findVarEnd(css.substring(startIndex));
# 		var declaration = css.substring(startIndex, endIndex);
# 		var value = extractValue(declaration, varLookup);
#
# 		if(value) {
# 			output.push(value);
# 		} else {
# 			output.push(declaration);
# 		}
# 		startIndex = endIndex;
# 	}
#
# 	if(startIndex === 0) {
# 		return replaceBlobUrlSubresources(css);
# 	}
#
# 	output.push(css.substring(startIndex));
#
# 	return replaceBlobUrlSubresources(output.join(""));
# }
#
# function injectStyles(linkEl,css){
# 	var cssEl;
#
# 	if(auraConfig.applyCssVarPolyfillViaBlob) {
# 		var blob=new Blob([css],{type:"text/css"});
# 		cssEl=document.createElement("link");
# 		cssEl.addEventListener("load",onLoadStyleSheets);
# 		cssEl.addEventListener("error",onLoadStyleSheetsError);
# 		cssEl.setAttribute("rel","stylesheet");
# 		cssEl.setAttribute("href",URL.createObjectURL(blob));
# 		linkEl.parentElement.insertBefore(cssEl,linkEl);
# 	}else{
# 		cssEl=document.createElement("style");
# 		cssEl.textContent=css;
# 		linkEl.parentElement.insertBefore(cssEl,linkEl);
# 		onLoadStyleSheets();
# 	}
# }
#
# function rewriteAndInjectCss(linkEl, source, varLookup) {
# 	var css = rewriteCssVars(source, varLookup);
# 	injectStyles(linkEl, css);
# }
#
# function loadViaAjax(linkEl, cssVariables) {
# 	var url = linkEl.getAttribute("data-href");
# 	var xhr = new XMLHttpRequest();
# 	xhr.addEventListener("error", onLoadStyleSheetsError);
# 	xhr.addEventListener("load", function (e) {
# 		if (this.status === 200) {
# 			rewriteAndInjectCss(linkEl, xhr.responseText, cssVariables);
# 		} else {
# 			onLoadStyleSheets(e);
# 		}
# 	});
# 	xhr.open("GET", url);
# 	xhr.withCredentials = true;
# 	xhr.send();
# }
#
# window.Aura.rewriteCssVars = rewriteCssVars;
# }());
#     </script>
#     <script data-src="/Catalonialifesciencesdatabase/jslibrary/1667877166000/canvas/CanvasRendering.js"/>
#     <script data-src="/Catalonialifesciencesdatabase/jslibrary/1667877166000/ui-analytics-reporting/EclairNG.js"/>
#     <!--"'-->
#     <script nonce="">
# (function(){
#     function loadLocaleData(moment){
#
#
#      var monthsShortDot$2 = 'ene._feb._mar._abr._may._jun._jul._ago._sep._oct._nov._dic.'.split('_'),
#          monthsShort$3 = 'ene_feb_mar_abr_may_jun_jul_ago_sep_oct_nov_dic'.split('_');
#
#      var monthsParse$3 = [/^ene/i, /^feb/i, /^mar/i, /^abr/i, /^may/i, /^jun/i, /^jul/i, /^ago/i, /^sep/i, /^oct/i, /^nov/i, /^dic/i];
#      var monthsRegex$3 = /^(enero|febrero|marzo|abril|mayo|junio|julio|agosto|septiembre|octubre|noviembre|diciembre|ene\.?|feb\.?|mar\.?|abr\.?|may\.?|jun\.?|jul\.?|ago\.?|sep\.?|oct\.?|nov\.?|dic\.?)/i;
#
#      moment.defineLocale('es', {
#          months : 'enero_febrero_marzo_abril_mayo_junio_julio_agosto_septiembre_octubre_noviembre_diciembre'.split('_'),
#          monthsShort : function (m, format) {
#              if (!m) {
#                  return monthsShortDot$2;
#              } else if (/-MMM-/.test(format)) {
#                  return monthsShort$3[m.month()];
#              } else {
#                  return monthsShortDot$2[m.month()];
#              }
#          },
#          monthsRegex : monthsRegex$3,
#          monthsShortRegex : monthsRegex$3,
#          monthsStrictRegex : /^(enero|febrero|marzo|abril|mayo|junio|julio|agosto|septiembre|octubre|noviembre|diciembre)/i,
#          monthsShortStrictRegex : /^(ene\.?|feb\.?|mar\.?|abr\.?|may\.?|jun\.?|jul\.?|ago\.?|sep\.?|oct\.?|nov\.?|dic\.?)/i,
#          monthsParse : monthsParse$3,
#          longMonthsParse : monthsParse$3,
#          shortMonthsParse : monthsParse$3,
#          weekdays : 'domingo_lunes_martes_miércoles_jueves_viernes_sábado'.split('_'),
#          weekdaysShort : 'dom._lun._mar._mié._jue._vie._sáb.'.split('_'),
#          weekdaysMin : 'do_lu_ma_mi_ju_vi_sá'.split('_'),
#          weekdaysParseExact : true,
#          longDateFormat : {
#              LT : 'H:mm',
#              LTS : 'H:mm:ss',
#              L : 'DD/MM/YYYY',
#              LL : 'D [de] MMMM [de] YYYY',
#              LLL : 'D [de] MMMM [de] YYYY H:mm',
#              LLLL : 'dddd, D [de] MMMM [de] YYYY H:mm'
#          },
#          calendar : {
#              sameDay : function () {
#                  return '[hoy a la' + ((this.hours() !== 1) ? 's' : '') + '] LT';
#              },
#              nextDay : function () {
#                  return '[mañana a la' + ((this.hours() !== 1) ? 's' : '') + '] LT';
#              },
#              nextWeek : function () {
#                  return 'dddd [a la' + ((this.hours() !== 1) ? 's' : '') + '] LT';
#              },
#              lastDay : function () {
#                  return '[ayer a la' + ((this.hours() !== 1) ? 's' : '') + '] LT';
#              },
#              lastWeek : function () {
#                  return '[el] dddd [pasado a la' + ((this.hours() !== 1) ? 's' : '') + '] LT';
#              },
#              sameElse : 'L'
#          },
#          relativeTime : {
#              future : 'en %s',
#              past : 'hace %s',
#              s : 'unos segundos',
#              ss : '%d segundos',
#              m : 'un minuto',
#              mm : '%d minutos',
#              h : 'una hora',
#              hh : '%d horas',
#              d : 'un día',
#              dd : '%d días',
#              M : 'un mes',
#              MM : '%d meses',
#              y : 'un año',
#              yy : '%d años'
#          },
#          dayOfMonthOrdinalParse : /\d{1,2}º/,
#          ordinal : '%dº',
#          week : {
#              dow : 1, // Monday is the first day of the week.
#              doy : 4  // The week that contains Jan 4th is the first week of the year.
#          }
#      });
#
#      }
#     (window.Aura &amp;&amp; window.Aura.moment)? loadLocaleData(window.Aura.moment) : (window.Aura || (window.Aura = {}), window.Aura.loadLocaleData=loadLocaleData);
# })();
# ;(function() { window.Aura = window.Aura || {}; window.Aura.beforeFrameworkInit = Aura.beforeFrameworkInit || []; window.Aura.beforeFrameworkInit.push(function() { /*
#  * This code is for Internal Salesforce use only, and subject to change without notice.
#  * Customers shouldn't reference this file in any web pages.
#  */
# var ContentAssetGlobalValueProvider=function(a,b){this.orgId=a;this.contentDomainUrl=b};ContentAssetGlobalValueProvider.prototype.merge=function(){};ContentAssetGlobalValueProvider.prototype.isStorable=function(){return!1};ContentAssetGlobalValueProvider.prototype.get=function(a){var b="";if(!a||0===a.length)return null;b=a+"?oid\x3d"+this.orgId+"\x26";a="/file-asset/"+b;var b=$A.get("$SfdcSite.pathPrefix"),c=$A.get("$Absolute.url");return b?[c||b||"",a].join(""):[this.contentDomainUrl||"",a].join("")};
#
# //# sourceMappingURL=/javascript/1667812443076/ui-sfdc-javascript-impl/source/ContentAssetGVP.js.map
#
# $A.addValueProvider('$ContentAsset', new ContentAssetGlobalValueProvider('00D58000000c8Pi',''))
#  ; }); window.Aura.beforeFrameworkInit.push(function() { /*
#  * This code is for Internal Salesforce use only, and subject to change without notice.
#  * Customers shouldn't reference this file in any web pages.
#  */
# var RecordGlobalValueProvider=function(a,b,c,d,e){this._cmp=null;this.configs={refresh:1E3*a,expiration:1E3*b,maxSize:c,version:d,previousVersion:e,minSaveToStorageInterval:3E3};Object.freeze(this.configs)};RecordGlobalValueProvider.prototype.getValues=function(){return{}};RecordGlobalValueProvider.prototype.merge=function(a){$A.util.isEmpty(a)||(this._createCmp(),this._cmp.helper.recordLib.records._receiveFrom$RecordGvp(a))};
# RecordGlobalValueProvider.prototype.get=function(a,b){if("configs"===a)return this.configs;this._requestFromServer(a)};RecordGlobalValueProvider.prototype._requestFromServer=function(a){if(this._createCmp()){var b=this._cmp.get("c.getRecord");b.setParams({recordDescriptor:a});b.setCallback(this,$A.getCallback(function(b){"INCOMPLETE"===b.getState()&amp;&amp;this._cmp.helper.handleIncomplete.call(this._cmp.helper,a)}));$A.enqueueAction(b);$A.run(function(){},"RecordGlobalValueProvider._requestFromServer")}};
# RecordGlobalValueProvider.prototype._createCmp=function(){this._cmp||(this._cmp=$A.createComponentFromConfig({descriptor:"markup://force:recordGlobalValueProvider",attributes:null}));return!$A.util.isUndefinedOrNull(this._cmp)};
#
# //# sourceMappingURL=/javascript/1667812443076/ui-sfdc-javascript-impl/source/RecordGVP.js.map
#
# $A.addValueProvider('$Record', new RecordGlobalValueProvider(30, 1800, 5120, '56.0', '55.0')) ; });  }());</script>
#     <script src="/Catalonialifesciencesdatabase/s/sfsites/l/%7B%22mode%22%3A%22PROD%22%2C%22app%22%3A%22siteforce%3AcommunityApp%22%2C%22fwuid%22%3A%22tr2UlkrAHzi37ijzEeD2UA%22%2C%22loaded%22%3A%7B%22APPLICATION%40markup%3A%2F%2Fsiteforce%3AcommunityApp%22%3A%22HU7u5uZWBH_8Nshn9opI8g%22%7D%2C%22apce%22%3A1%2C%22apck%22%3A%22Lqyy7t6zxKOsCKu_Y5k2vQ%22%2C%22mlr%22%3A1%2C%22pathPrefix%22%3A%22%2FCatalonialifesciencesdatabase%22%2C%22dns%22%3A%22c%22%7D/resources.js?pv=16679829530001498909467&amp;rv=1665453640000"/>
#     <script src="/Catalonialifesciencesdatabase/s/sfsites/auraFW/javascript/tr2UlkrAHzi37ijzEeD2UA/aura_prod.js"/>
#     <script src="/Catalonialifesciencesdatabase/s/sfsites/l/%7B%22mode%22%3A%22PROD%22%2C%22app%22%3A%22siteforce%3AcommunityApp%22%2C%22serializationVersion%22%3A%221-240.1.8-2.20.6-b%22%2C%22parts%22%3A%22f%22%2C%22loaded%22%3A%7B%22APPLICATION%40markup%3A%2F%2Fsiteforce%3AcommunityApp%22%3A%22HU7u5uZWBH_8Nshn9opI8g%22%7D%2C%22dns%22%3A%22c%22%7D/app.js?2="/>
#     <script src="/Catalonialifesciencesdatabase/s/sfsites/l/%7B%22mode%22%3A%22PROD%22%2C%22app%22%3A%22siteforce%3AcommunityApp%22%2C%22fwuid%22%3A%22tr2UlkrAHzi37ijzEeD2UA%22%2C%22loaded%22%3A%7B%22APPLICATION%40markup%3A%2F%2Fsiteforce%3AcommunityApp%22%3A%22HU7u5uZWBH_8Nshn9opI8g%22%7D%2C%22apce%22%3A1%2C%22apck%22%3A%22Lqyy7t6zxKOsCKu_Y5k2vQ%22%2C%22mlr%22%3A1%2C%22pathPrefix%22%3A%22%2FCatalonialifesciencesdatabase%22%2C%22dns%22%3A%22c%22%7D/bootstrap.js?aura.attributes=%7B%22ac%22%3A%22%22%2C%22authenticated%22%3A%22false%22%2C%22brandingSetId%22%3A%22ccdae195-9f21-4fb8-95ff-e3d09e617605%22%2C%22formFactor%22%3A%22LARGE%22%2C%22isHybrid%22%3A%22false%22%2C%22language%22%3A%22en_US%22%2C%22pageId%22%3A%22c6bd20e0-1a22-4f54-973e-4071fe8c67dc%22%2C%22publishedChangelistNum%22%3A%2220%22%2C%22schema%22%3A%22Published%22%2C%22themeLayoutType%22%3A%22Inner%22%2C%22viewType%22%3A%22Published%22%7D"/>
#     <!--render facet: 87:0-->
#     <!--render facet: 89:0-->
#     <!--render facet: 91:0-->
#     <!--render facet: 94:0-->
#     <!--render facet: 98:0-->
#     <!--render facet: 101:0-->
#     <!--render facet: 103:0-->
#     <!--render facet: 105:0-->
#     <!--render facet: 106:0-->
#     <!--render facet: 109:0-->
#     <!--render facet: 111:0-->
#     <div class="siteforceCptBody" data-aura-class="siteforceCptBody" data-aura-rendered-by="315:0" id="CustomerPortalTemplate">
#       <a class="forceSkipLink" data-aura-class="forceSkipLink" data-aura-rendered-by="320:0" href="javascript:void(0);">Skip to Navigation</a>
#       <a class="forceSkipLink" data-aura-class="forceSkipLink" data-aura-rendered-by="325:0" href="javascript:void(0);">Skip to Main Content</a>
#       <!--render facet: 327:0-->
#       <div class="cCenterPanel" data-aura-rendered-by="328:0" role="main" style="max-width: 1400px;" tabindex="-1">
#         <!--render facet: 3:2;a-->
#         <div class="siteforceSldsOneColLayout siteforceContentArea" data-aura-class="siteforceSldsOneColLayout siteforceContentArea" data-aura-rendered-by="35:2;a">
#           <div class="slds-col--padded comm-content-header comm-layout-column" data-aura-rendered-by="36:2;a">
#             <div data-aura-rendered-by="32:2;a" data-item-id="bf7ab8f0-9dac-4079-a973-246116b6358c" data-region-name="header">
#               <div class="ui-widget" data-aura-rendered-by="23:2;a" data-item-id="4f0f004e-d646-4702-921b-9a640a45f341" data-priority="">
#                 <c-header c-header_header-host="" data-aura-rendered-by="20:2;a" data-data-rendering-service-uid="39">
#                   <div c-header_header="" class="header-wrapper">
#                     <a c-header_header="" href="https://biocat.force.com/Catalonialifesciencesdatabase/s/">
#                       <img alt="catalan life sciences database logo" c-header_header="" src="/Catalonialifesciencesdatabase/resource/1664541382000/commonStyles/img/Logo-biocat.jpeg"/>
#                       <p c-header_header="">Catalonia Health and Life Sciences Data Platform</p>
#                     </a>
#                   </div>
#                 </c-header>
#               </div>
#               <div class="ui-widget" data-aura-rendered-by="29:2;a" data-item-id="b5b7df5e-fd4d-48c3-b9d6-3489fd44244b" data-priority="">
#                 <c-search-landing c-searchlanding_searchlanding-host="" data-aura-rendered-by="26:2;a" data-data-rendering-service-uid="40">
#                   <div c-searchlanding_searchlanding="" class="wrapper">
#                     <section c-searchlanding_searchlanding="" class="kpi-container">
#                       <div c-searchlanding_searchlanding="" class="indicators-container">
#                         <c-indicator c-indicator_indicator-host="" c-searchlanding_searchlanding="">
#                           <div c-indicator_indicator="" class="indicator-container">
#                             <span c-indicator_indicator="" class="indicator-amount">1610</span>
#                             <div c-indicator_indicator="" class="indicator-line"/>
#                             <span c-indicator_indicator="" class="indicator-text">COMPANIES &amp; INSTITUTIONS</span>
#                           </div>
#                         </c-indicator>
#                         <c-indicator c-indicator_indicator-host="" c-searchlanding_searchlanding="">
#                           <div c-indicator_indicator="" class="indicator-container">
#                             <span c-indicator_indicator="" class="indicator-amount">530</span>
#                             <div c-indicator_indicator="" class="indicator-line"/>
#                             <span c-indicator_indicator="" class="indicator-text">STARTUPS</span>
#                           </div>
#                         </c-indicator>
#                         <c-indicator c-indicator_indicator-host="" c-searchlanding_searchlanding="">
#                           <div c-indicator_indicator="" class="indicator-container">
#                             <span c-indicator_indicator="" class="indicator-amount">+325 M€</span>
#                             <div c-indicator_indicator="" class="indicator-line"/>
#                             <span c-indicator_indicator="" class="indicator-text">Total investment YTD*</span>
#                           </div>
#                         </c-indicator>
#                         <c-indicator c-indicator_indicator-host="" c-searchlanding_searchlanding="">
#                           <div c-indicator_indicator="" class="indicator-container">
#                             <span c-indicator_indicator="" class="indicator-amount">32</span>
#                             <div c-indicator_indicator="" class="indicator-line"/>
#                             <span c-indicator_indicator="" class="indicator-text">VC rounds YTD</span>
#                           </div>
#                         </c-indicator>
#                         <c-indicator c-indicator_indicator-host="" c-searchlanding_searchlanding="">
#                           <div c-indicator_indicator="" class="indicator-container">
#                             <a c-indicator_indicator="" class="indicator-image-link" href="https://smile2impress.com/es" target="_blank">
#                               <img alt="" c-indicator_indicator="" src="https://t2.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://smile2impress.com/es&amp;size=64"/>
#                             </a>
#                             <span c-indicator_indicator="" class="indicator-name-text">Impress</span>
#                             <div c-indicator_indicator="" class="indicator-line"/>
#                             <span c-indicator_indicator="" class="indicator-text">Featured round /Exit **</span>
#                           </div>
#                         </c-indicator>
#                       </div>
#                     </section>
#                     <section c-searchlanding_searchlanding="" class="filters-container">
#                       <c-search-filters c-searchfilters_searchfilters-host="" c-searchlanding_searchlanding="">
#                         <h1 c-searchfilters_searchfilters="" class="filter-title">Discover Catalonia’s most promising health and life sciences startups, companies and research intitutions.</h1>
#                         <p c-searchfilters_searchfilters="" class="filter-desc">Access a comprehensive database of one of the fastest growing ecosystems in Europe.</p>
#                         <div c-searchfilters_searchfilters="" class="filter-results d-none">
#                           <div c-searchfilters_searchfilters="" class="filter-results_container">
#                             <h3 c-searchfilters_searchfilters="">Current Search:</h3>
#                             <ul c-searchfilters_searchfilters=""/>
#                           </div>
#                           <div c-searchfilters_searchfilters="" class="filter-results_buttons buttons-container">
#                             <button c-searchfilters_searchfilters="" class="btn-primary">Refine search</button>
#                           </div>
#                         </div>
#                         <div c-searchfilters_searchfilters="" class="filters" id="filters-10">
#                           <div c-searchfilters_searchfilters="" class="buttons-container only-mobile">
#                             <button c-searchfilters_searchfilters="" class="btn-secondary">Reset</button>
#                             <button c-searchfilters_searchfilters="" class="btn-primary">Explore</button>
#                           </div>
#                           <div c-searchfilters_searchfilters="" class="filters-row">
#                             <lightning-input c-searchfilters_searchfilters="" class="slds-form-element" lightning-input_input-host="">
#                               <label class="slds-form-element__label slds-no-flex" for="input-46" lightning-input_input="">Keywords</label>
#                               <div class="slds-form-element__control slds-grow" lightning-input_input="">
#                                 <input class="slds-input" id="input-46" lightning-input_input="" type="text"/>
#                               </div>
#                             </lightning-input>
#                             <lightning-input c-searchfilters_searchfilters="" class="slds-form-element" lightning-input_input-host="">
#                               <label class="slds-form-element__label slds-no-flex" for="input-47" lightning-input_input="">Company name</label>
#                               <div class="slds-form-element__control slds-grow" lightning-input_input="">
#                                 <input class="slds-input" id="input-47" lightning-input_input="" type="text"/>
#                               </div>
#                             </lightning-input>
#                           </div>
#                           <div c-searchfilters_searchfilters="" class="filters-row">
#                             <c-multi-pick-list c-multipicklist_multipicklist-host="" c-searchfilters_searchfilters="">
#                               <div c-multipicklist_multipicklist="" class="slds-form-element">
#                                 <label c-multipicklist_multipicklist="" class="slds-form-element__label">Main sector</label>
#                                 <div c-multipicklist_multipicklist="" class="slds-form-element__control">
#                                   <div c-multipicklist_multipicklist="" class="slds-combobox_container">
#                                     <div aria-expanded="false" aria-haspopup="listbox" c-multipicklist_multipicklist="" class="slds-combobox slds-dropdown-trigger slds-dropdown-trigger_click slds-picklist ms-picklist-dropdown" id="ms-picklist-dropdown-48" role="combobox">
#                                       <div c-multipicklist_multipicklist="" class="slds-combobox_form-element slds-input-has-icon slds-input-has-icon_right" role="none">
#                                         <input aria-controls="ms-dropdown-items-48" c-multipicklist_multipicklist="" class="slds-combobox__input ms-input" id="ms-input-48" readonly="" role="textbox" type="text"/>
#                                         <span c-multipicklist_multipicklist="" class="slds-icon_container slds-icon-utility-down slds-input__icon slds-input__icon_right" title="Click to open the dropdown">
#                                           <lightning-icon c-multipicklist_multipicklist="" class="slds-icon slds-icon--selected slds-icon--x-small slds-icon-text-default slds-m-right--x-small slds-icon-utility-down slds-icon_container">
#                                             <lightning-primitive-icon>
#                                               <svg aria-hidden="true" class="slds-icon slds-icon-text-default slds-icon_x-small" data-key="down" focusable="false" viewbox="0 0 52 52">
#                                                 <g>
#                                                   <path d="M8.3 14h35.4c1 0 1.7 1.3.9 2.2L27.3 37.4c-.6.8-1.9.8-2.5 0L7.3 16.2c-.7-.9-.1-2.2 1-2.2z"/>
#                                                 </g>
#                                               </svg>
#                                             </lightning-primitive-icon>
#                                             <span class="slds-assistive-text">Click here</span>
#                                           </lightning-icon>
#                                         </span>
#                                       </div>
#                                       <div c-multipicklist_multipicklist="" class="te" id="ms-dropdown-items-48" role="listbox">
#                                         <ul c-multipicklist_multipicklist="" class="slds-listbox slds-listbox_vertical slds-dropdown slds-dropdown_fluid" role="presentation">
#                                           <c-pick-list-item c-multipicklist_multipicklist="" c-picklistitem_picklistitem-host="">
#                                             <li c-picklistitem_picklistitem="" class="slds-listbox__item ms-list-item" data-name="Biotechnology - Therapeutics and Diagnostics" id="ms-list-item-51" role="presentation">
#                                               <div c-picklistitem_picklistitem="" class="slds-media slds-listbox__option slds-listbox__option_plain slds-media_small slds-media_center" id="listbox-option-unique-id-01-51" role="option">
#                                                 <span c-picklistitem_picklistitem="" class="slds-media__figure">
#                                                   <lightning-icon c-picklistitem_picklistitem="" class="slds-icon slds-icon--selected slds-icon--x-small slds-icon-text-default slds-m-right--x-small slds-icon-utility-check slds-icon_container">
#                                                     <lightning-primitive-icon>
#                                                       <svg aria-hidden="true" class="slds-icon slds-icon-text-default slds-icon_x-small" data-key="check" focusable="false" viewbox="0 0 52 52">
#                                                         <g>
#                                                           <path d="M19.1 42.5L2.6 25.9c-.6-.6-.6-1.6 0-2.2l2.2-2.2c.6-.6 1.6-.6 2.2 0L19.4 34c.4.4 1.1.4 1.5 0L45.2 9.5c.6-.6 1.6-.6 2.2 0l2.2 2.2c.6.6.6 1.6 0 2.2L21.3 42.5c-.6.7-1.6.7-2.2 0z"/>
#                                                         </g>
#                                                       </svg>
#                                                     </lightning-primitive-icon>
#                                                     <span class="slds-assistive-text">Selected</span>
#                                                   </lightning-icon>
#                                                 </span>
#                                                 <span c-picklistitem_picklistitem="" class="slds-media__body">
#                                                   <span c-picklistitem_picklistitem="" class="slds-truncate" title="Biotechnology - Therapeutics and Diagnostics">Biotechnology - Therapeutics and Diagnostics</span>
#                                                 </span>
#                                               </div>
# ...
#                                 <p c-companycard_companycard="" class="section-title">Main Sector</p>
#                                 <p c-companycard_companycard="" class="section-desc">Supplier &amp; Engineering</p>
#                               </section>
#                               <section c-companycard_companycard="" class="section-list">
#                                 <p c-companycard_companycard="" class="section-title">Subsector</p>
#                                 <ul c-companycard_companycard="" class="section-list-value">
#                                   <li c-companycard_companycard="" class="section-desc">Medical devices</li>
#                                 </ul>
#                               </section>
#                               <section c-companycard_companycard="" class="section-text">
#                                 <p c-companycard_companycard="" class="section-title">Description</p>
#                                 <p c-companycard_companycard="" class="section-desc">Acteon Group is specialized in small dental equipment, imaging and consumables. The Group is active in the European, Asian and American dental markets. Acteon Medico-Dental Iberica is a marketing subsidiary.</p>
#                               </section>
#                             </div>
#                             <div c-companycard_companycard="" class="card-footer">
#                               <p c-companycard_companycard="" class="btn-tertiary">More details</p>
#                             </div>
#                           </button>
#                         </c-company-card>
#                         <c-company-card c-companycard_companycard-host="" c-searchlanding_searchlanding="">
#                           <button c-companycard_companycard="" class="card-container">
#                             <div c-companycard_companycard="" class="card-header">
#                               <p c-companycard_companycard="" class="card-title">Active Medical Disposable</p>
#                               <lightning-icon c-companycard_companycard="" class="slds-icon-standard-account slds-icon_container" title="Active Medical Disposable">
#                                 <lightning-primitive-icon>
#                                   <svg aria-hidden="true" class="slds-icon slds-icon_large" data-key="account" focusable="false" viewbox="0 0 100 100">
#                                     <g>
#                                       <path d="M79 51.1c.1-2.1-1.4-2.7-2-2.7H55.2c-1.9 0-2.2 2-2.2 2.2V74h26V51.1zM64 67.9c0 1.1-.9 2-2 2h-2c-1.1 0-2-.9-2-2v-2c0-1.1.9-2 2-2h2c1.1 0 2 .9 2 2v2zm0-10.2c0 1.1-.9 2-2 2h-2c-1.1 0-2-.9-2-2v-2c0-1.1.9-2 2-2h2c1.1 0 2 .9 2 2v2zm10 10.2c0 1.1-.9 2-2 2h-2c-1.1 0-2-.9-2-2v-2c0-1.1.9-2 2-2h2c1.1 0 2 .9 2 2v2zm0-10.2c0 1.1-.9 2-2 2h-2c-1.1 0-2-.9-2-2v-2c0-1.1.9-2 2-2h2c1.1 0 2 .9 2 2v2z"/>
#                                       <path d="M59 40.3V28.7c.1-2.1-1.4-2.7-2-2.7H23.2c-1.9 0-2.2 2-2.2 2.2V74h26V44.7s0-2.4 2.2-2.4h7.9c1.1 0 1.9-1.2 1.9-2zM32 66.9c0 1.1-.9 2-2 2h-2c-1.1 0-2-.9-2-2v-2c0-1.1.9-2 2-2h2c1.1 0 2 .9 2 2v2zm0-10.3c0 1.1-.9 2-2 2h-2c-1.1 0-2-.9-2-2v-2c0-1.1.9-2 2-2h2c1.1 0 2 .9 2 2v2zm0-10.2c0 1.1-.9 2-2 2h-2c-1.1 0-2-.9-2-2v-2c0-1.1.9-2 2-2h2c1.1 0 2 .9 2 2v2zm0-10.2c0 1.1-.9 2-2 2h-2c-1.1 0-2-.9-2-2v-2c0-1.1.9-2 2-2h2c1.1 0 2 .9 2 2v2zm11 30.7c0 1.1-.9 2-2 2h-2c-1.1 0-2-.9-2-2v-2c0-1.1.9-2 2-2h2c1.1 0 2 .9 2 2v2zm0-10.3c0 1.1-.9 2-2 2h-2c-1.1 0-2-.9-2-2v-2c0-1.1.9-2 2-2h2c1.1 0 2 .9 2 2v2zm0-10.2c0 1.1-.9 2-2 2h-2c-1.1 0-2-.9-2-2v-2c0-1.1.9-2 2-2h2c1.1 0 2 .9 2 2v2zm0-10.2c0 1.1-.9 2-2 2h-2c-1.1 0-2-.9-2-2v-2c0-1.1.9-2 2-2h2c1.1 0 2 .9 2 2v2zm11 0c0 1.1-.9 2-2 2h-2c-1.1 0-2-.9-2-2v-2c0-1.1.9-2 2-2h2c1.1 0 2 .9 2 2v2z"/>
#                                     </g>
#                                   </svg>
#                                 </lightning-primitive-icon>
#                                 <span class="slds-assistive-text">Active Medical Disposable</span>
#                               </lightning-icon>
#                               <p c-companycard_companycard="" class="card-subtitle">Mataró, Barcelona</p>
#                             </div>
#                             <div c-companycard_companycard="" class="card-body">
#                               <section c-companycard_companycard="" class="section-text">
#                                 <p c-companycard_companycard="" class="section-title">Main Sector</p>
#                                 <p c-companycard_companycard="" class="section-desc">Supplier &amp; Engineering</p>
#                               </section>
#                               <section c-companycard_companycard="" class="section-list">
#                                 <p c-companycard_companycard="" class="section-title">Subsector</p>
#                                 <ul c-companycard_companycard="" class="section-list-value">
#                                   <li c-companycard_companycard="" class="section-desc">Medical devices</li>
#                                 </ul>
#                               </section>
#                               <section c-companycard_companycard="" class="section-text">
#                                 <p c-companycard_companycard="" class="section-title">Description</p>
#                                 <p c-companycard_companycard="" class="section-desc">Activ Medical Disposable is a company which manufactures and markets absorbent incontinence products. The company offers a range of urinary incontinence protection products for men and women. Activ Medical Disposables serves customers in France.</p>
#                               </section>
#                             </div>
#                             <div c-companycard_companycard="" class="card-footer">
#                               <p c-companycard_companycard="" class="btn-tertiary">More details</p>
#                             </div>
#                           </button>
#                         </c-company-card>
#                       </div>
#                       <div c-searchlanding_searchlanding="" class="pagination-container">
#                         <lightning-button-group c-searchlanding_searchlanding="" class="slds-button-group" role="group">
#                           <slot>
#                             <lightning-button c-searchlanding_searchlanding="" class="selected">
#                               <button class="slds-button slds-button_neutral slds-button_first" type="button">1</button>
#                             </lightning-button>
#                             <lightning-button c-searchlanding_searchlanding="">
#                               <button class="slds-button slds-button_neutral slds-button_middle" type="button">2</button>
#                             </lightning-button>
#                             <lightning-button c-searchlanding_searchlanding="">
#                               <button class="slds-button slds-button_neutral slds-button_middle" type="button">3</button>
#                             </lightning-button>
#                             <lightning-button c-searchlanding_searchlanding="">
#                               <button class="slds-button slds-button_neutral slds-button_middle" type="button">4</button>
#                             </lightning-button>
#                             <lightning-button c-searchlanding_searchlanding="">
#                               <button class="slds-button slds-button_neutral slds-button_last" type="button">5</button>
#                             </lightning-button>
#                           </slot>
#                         </lightning-button-group>
#                         <lightning-button c-searchlanding_searchlanding="" class="btn-icon right">
#                           <button class="slds-button slds-button_neutral" title="last" type="button">Next<lightning-primitive-icon><svg aria-hidden="true" class="slds-button__icon slds-button__icon_right" data-key="chevronright" focusable="false" viewbox="0 0 52 52"><g><path d="M17.9 4.4l20.7 20.5c.6.6.6 1.6 0 2.2L17.9 47.6c-.6.6-1.6.6-2.2 0l-2.2-2.2c-.6-.6-.6-1.6 0-2.2l16.3-16.1c.6-.6.6-1.6 0-2.2L13.6 8.8c-.6-.6-.6-1.6 0-2.2l2.2-2.2c.6-.5 1.5-.5 2.1 0z"/></g></svg></lightning-primitive-icon></button>
#                         </lightning-button>
#                       </div>
#                     </section>
#                     <div c-searchlanding_searchlanding="" class="legend">
#                       <p c-searchlanding_searchlanding="">(*) Funds include VC investment raised YTD, competitive grants and crowdfunding</p>
#                       <p c-searchlanding_searchlanding="">(**) Latest success story of a startup in the BioRegion of Catalonia</p>
#                     </div>
#                   </div>
#                 </c-search-landing>
#               </div>
#             </div>
#           </div>
#           <div class="slds-col--padded contentRegion comm-layout-column" data-aura-rendered-by="38:2;a">
#             <!--render facet: 39:2;a-->
#           </div>
#           <div class="slds-col--padded comm-content-footer comm-layout-column" data-aura-rendered-by="40:2;a">
#             <!--render facet: 41:2;a-->
#           </div>
#         </div>
#       </div>
#       <div class="cFooterPanel" data-aura-rendered-by="330:0" role="contentinfo">
#         <div data-aura-rendered-by="125:0" data-item-id="2f36b12f-e716-44a6-953c-804094580339" data-region-name="footer">
#           <div class="ui-widget" data-aura-rendered-by="122:0" data-item-id="3cbe9412-d9d3-4c39-962c-5a9e45b09ee4" data-priority="">
#             <c-footer c-footer_footer-host="" data-aura-rendered-by="119:0" data-data-rendering-service-uid="35">
#               <div c-footer_footer="" class="footer-container">
#                 <ul c-footer_footer="" class="footer-menu">
#                   <li c-footer_footer="" class="footer-menu_item">
#                     <a c-footer_footer="" href="/Catalonialifesciencesdatabase/s">Home</a>
#                   </li>
#                   <li c-footer_footer="" class="footer-menu_item">
#                     <a c-footer_footer="" href="/Catalonialifesciencesdatabase/s/update-your-company">Add or update your company</a>
#                   </li>
#                   <li c-footer_footer="" class="footer-menu_item">
#                     <a c-footer_footer="" href="/Catalonialifesciencesdatabase/s/definitions">Definitions</a>
#                   </li>
#                   <li c-footer_footer="" class="footer-menu_item">
#                     <a c-footer_footer="" href="/Catalonialifesciencesdatabase/s/legal">Legal notice &amp; Privacy policy</a>
#                   </li>
#                   <li c-footer_footer="" class="footer-menu_item">
#                     <a c-footer_footer="" href="/Catalonialifesciencesdatabase/s/social">Social media privacy policy</a>
#                   </li>
#                   <li c-footer_footer="" class="footer-menu_item">
#                     <a c-footer_footer="" href="https://www.biocat.cat/en/who-we-are/contact" target="_blank">Contact</a>
#                   </li>
#                 </ul>
#                 <div c-footer_footer="" class="footer-container_bottom">
#                   <p c-footer_footer="" class="copyright">© Biocat, 2022</p>
#                   <div c-footer_footer="" class="rrss">
#                     <p c-footer_footer="" class="rrss-label">Follow us on...</p>
#                     <ul c-footer_footer="" class="rrss-list">
#                       <li c-footer_footer="" class="rrss-list_item">
#                         <a c-footer_footer="" href="https://twitter.com/biocat_en" target="_blank">
#                           <img alt="twitter icon" c-footer_footer="" class="twitter" src="/Catalonialifesciencesdatabase/resource/1664541382000/commonStyles/img/icons/square-twitter.svg"/>
#                         </a>
#                       </li>
#                       <li c-footer_footer="" class="rrss-list_item">
#                         <a c-footer_footer="" href="http://es.linkedin.com/company/biocat-bioregion-of-catalonia" target="_blank">
#                           <img alt="linkedin icon" c-footer_footer="" class="linkedin" src="/Catalonialifesciencesdatabase/resource/1664541382000/commonStyles/img/icons/linkedin.svg"/>
#                         </a>
#                       </li>
#                       <li c-footer_footer="" class="rrss-list_item">
#                         <a c-footer_footer="" href="https://www.youtube.com/user/bioregiodecatalunya" target="_blank">
#                           <img alt="youtube icon" c-footer_footer="" class="youtube" src="/Catalonialifesciencesdatabase/resource/1664541382000/commonStyles/img/icons/square-youtube.svg"/>
#                         </a>
#                       </li>
#                       <li c-footer_footer="" class="rrss-list_item">
#                         <a c-footer_footer="" href="https://www.flickr.com/photos/biocat/" target="_blank">
#                           <img alt="flickr icon" c-footer_footer="" class="flickr" src="/Catalonialifesciencesdatabase/resource/1664541382000/commonStyles/img/icons/flickr.svg"/>
#                         </a>
#                       </li>
#                       <li c-footer_footer="" class="rrss-list_item">
#                         <a c-footer_footer="" href="http://vimeo.com/biocat" target="_blank">
#                           <img alt="vimeo icon" c-footer_footer="" class="vimeo" src="/Catalonialifesciencesdatabase/resource/1664541382000/commonStyles/img/icons/square-vimeo.svg"/>
#                         </a>
#                       </li>
#                       <li c-footer_footer="" class="rrss-list_item">
#                         <a c-footer_footer="" href="http://es.slideshare.net/biocat" target="_blank">
#                           <img alt="slideshare icon" c-footer_footer="" class="slideshare" src="/Catalonialifesciencesdatabase/resource/1664541382000/commonStyles/img/icons/slideshare.svg"/>
#                         </a>
#                       </li>
#                     </ul>
#                   </div>
#                 </div>
#               </div>
#             </c-footer>
#           </div>
#         </div>
#       </div>
#     </div>
#     <!--render facet: 334:0-->
#     <!--render facet: 339:0-->
#     <!--render facet: 342:0-->
#     <!--render facet: 344:0-->
#     <!--render facet: 345:0-->
#     <!--render facet: 3:0-->
#     <!--render facet: 7:0-->
#     <div class="forceCommunityToastManager forceToastManager--default forceToastManager" data-aura-class="forceToastManager--default forceToastManager" data-aura-rendered-by="11:0">
#       <div class="forceVisualMessageQueue" data-aura-class="forceVisualMessageQueue" data-aura-rendered-by="15:0">
#         <!--render facet: 13:0-->
#         <!--render facet: 17:0-->
#       </div>
#       <!--render facet: 18:0-->
#     </div>
#     <div class="forceHoverPrototype" data-aura-class="forceHoverPrototype" data-aura-rendered-by="25:0" style="top: 0px; left: -1500px; position: fixed;">
#       <div class="scrollableContainer" data-aura-rendered-by="26:0"/>
#     </div>
#     <!--render facet: 29:0-->
#     <!--render facet: 31:0-->
#     <!--render facet: 33:0-->
#     <div class="hideEl siteforceSpinnerManager siteforcePanelsContainer" data-aura-class="siteforceSpinnerManager siteforcePanelsContainer" data-aura-rendered-by="38:0">
#       <div class="mask" data-aura-rendered-by="39:0"/>
#       <div class="loadingCon global siteforceLoadingBalls" data-aura-class="siteforceLoadingBalls" data-aura-rendered-by="42:0">
#         <span class="loadingBall first" data-aura-rendered-by="43:0"/>
#         <span class="loadingBall second" data-aura-rendered-by="44:0"/>
#         <span class="loadingBall third" data-aura-rendered-by="45:0"/>
#         <span class="assistiveText" data-aura-rendered-by="46:0">Loading</span>
#       </div>
#     </div>
#     <!--render facet: 53:0-->
#     <div class="DESKTOP comm-panels-container uiContainerManager siteforcePanelsContainer" data-aura-class="uiContainerManager siteforcePanelsContainer" data-aura-rendered-by="57:0"/>
#     <!--render facet: 62:0-->
#     <!--render facet: 64:0-->
#     <!--render facet: 66:0-->
#     <!--render facet: 68:0-->
#   </body>
# </html>

# %% [markdown]
# Una vez hemos identificado los campos que queremos recoger nos creamos una función que nos lo haga automáticamente:

# %%
def biocat_parser(card):
    # title parsing (company name)
    title_line = card.find_all(True, {"class": "card-title"})
    title = re.findall(r'>(.*?)<', str(title_line))
    company = [row for row in title if re.findall("[A-z]", row)][0]
    try:
        # City, Province
        subtitle_line = card.find_all(True, {"class": "card-subtitle"})
        subtitle = re.findall(r'>(.*?)<', str(subtitle_line))
        location = [row for row in subtitle if re.findall("[A-z]", row)][0]

        # Main sector, subsector, Primary therapeutic areas and Description
        section = str(card.find_all(True, {"class": "section-desc"}))
        section = [row for row in re.findall(r'>(.*?)<', section) if re.findall("[A-z]", row)]
        main_sector = section[0]
        subsector = section[1]
        if len(section) == 4:
            primary = section[2]
            description = section[3]
        elif len(section) == 3:
            primary = ''
            description = section[2]
        else:
            return None, company

        return company, location, main_sector, subsector, primary, description
    except:
        return None, company

# %% [markdown]
# Tambien tendremos que encontrar el botton de `Next` para que el programa vaya navegando por las distintas paginaciones. Lo podemos encontrar por el texto que contiene:

# %%
boton_next = driver.find_element_by_xpath('//button[text()="Next"]')

# %% [markdown]
# Nos definimos un DataFrame vació donde iremos guardando la información que queremos recoger sobre las compañías:

# %%
columns = ['company', 'location', 'main_sector', 'subsector', 'primary', 'description']
data = pd.DataFrame([], columns=columns)

# %% [markdown]
# Ahora, recorreremos todas las página de resultados con el botón `Next`e iremos recogiendo toda la información que nos interese con la función que hemos creado `biocat_parser`:

# %%
not_finished = True
potential_conflict_companies = []
potential_conflict_indexes = []
pagination_lengths = []
time.sleep(3)
while not_finished:
    try:
        html = driver.execute_script("return document.getElementsByTagName('html')[0].innerHTML")
        soup = BeautifulSoup(html, "html.parser")
        cards = soup.find_all(True, {"class": "card-container"})
        pagination_lengths.append(len(cards))
        for i, card in enumerate(cards):
            try:
                item_df = pd.DataFrame([list(biocat_parser(card))], columns=columns)
                if item_df.empty or biocat_parser(card) is None:
                    pass
                data = pd.concat([data, item_df], ignore_index=True)
                print(f"Data from company extracted: {item_df['company'].iloc[0]}")
            except:
                try:
                    _, company_conflict = biocat_parser(card)
                except:
                    pass
                potential_conflict_companies.append(f"{company_conflict}")
                print(f"\n********************************** Potential issue in company: "
                      f"{company_conflict}\n")
        driver.find_element_by_xpath('//button[text()="Next"]').click()
        time.sleep(1)
    except:
        not_finished = False
# Out:
# Data from company extracted: AB Medica Group
# Data from company extracted: Abac Capital
# Data from company extracted: Abac Therapeutics
# Data from company extracted: Abamed Pharma
# Data from company extracted: AB-Biotics
# Data from company extracted: ABC Farma Internacional
# Data from company extracted: Abeona Health
# Data from company extracted: ABG Patentes
# Data from company extracted: Ability Pharma
# Data from company extracted: ABLE Human Motion
# Data from company extracted: Abzu
# Data from company extracted: Accelerate Diagnostics
# Data from company extracted: ACCIÓ Agència per a la competitivitat de l'empresa
#
# ********************************** Potential issue in company: Accord Healthcare
#
# Data from company extracted: Accure Therapeutics
# Data from company extracted: ACEFE
# Data from company extracted: Acellera
# Data from company extracted: Actelion Pharmaceuticals España
# Data from company extracted: Acteon Medico-Dental Iberica
# Data from company extracted: Active Medical Disposable
# Data from company extracted: Active Venture Partners
# Data from company extracted: Acuidad
# Data from company extracted: Adacyte Therapeutics
# Data from company extracted: Adan Medical Innovation
# Data from company extracted: ADAPT Localization Services
# Data from company extracted: AdaptiveCity
#
# ********************************** Potential issue in company: Additio Investment Group
#
# Data from company extracted: AddVANTE Economists &amp; Lawyers
# Data from company extracted: AddVANTE M&amp;A
# Data from company extracted: Adecco Medical &amp; Science
# Data from company extracted: Adelphi
# Data from company extracted: Adiccare
# Data from company extracted: Adiemed
# Data from company extracted: Adienne Spain
# Data from company extracted: ADKNOMA Health Research
# Data from company extracted: ADmit Therapeutics
# Data from company extracted: AdSalutem Institute
#
# ********************************** Potential issue in company: Advance Fluorescence Microscopy Unit (IBMB-PCB)
#
# Data from company extracted: Advanced Accelerator Applications Iberica
# Data from company extracted: Advanced Digital Microscopy Core Facility (IRB)
# Data from company extracted: Advanced Light Microscopy Unit (CRG)
#
# ********************************** Potential issue in company: Advanced Nanotechnologies
#
#
# ********************************** Potential issue in company: Adventura Capital
#
# Data from company extracted: AEC Partners
# Data from company extracted: Aelix Therapeutics
# Data from company extracted: Aeris Tecnologías Ambientales
#
# ********************************** Potential issue in company: AEROFYBERS
#
# Data from company extracted: Aether Tech
#
# ********************************** Potential issue in company: Afarvi Sistemas
#
# Data from company extracted: Afferent Technologies
# Data from company extracted: Affirma Biotech
# Data from company extracted: Afinitica
#
# ********************************** Potential issue in company: Agència de Qualitat i Avaluació Sanitàrias de Catalunya (AQuAS)
#
# Data from company extracted: Agència de Salut Pública de Catalunya (ASPCAT)
# Data from company extracted: Agència per a la Qualitat del Sistema Universitari de Catalunya (AQU)
# Data from company extracted: Agromillora Catalana
# Data from company extracted: Agrprojects
# Data from company extracted: Aguettant Ibérica
# Data from company extracted: Ahead Therapeutics
# Data from company extracted: Aimentia Healthtech
# Data from company extracted: Airmedical Products
# Data from company extracted: Airpharm
# Data from company extracted: AIS Channel
# Data from company extracted: Albajuna Therapeutics
# Data from company extracted: Alchemlife
# Data from company extracted: Alcon
# Data from company extracted: Alcura Health
#
# ********************************** Potential issue in company: AldeA Ventures
#
# Data from company extracted: Aldo-Union
#
# ********************************** Potential issue in company: Alere
#
# Data from company extracted: Alexion Pharma Spain
# Data from company extracted: Alfasigma
# Data from company extracted: Algaktiv
# Data from company extracted: Alifarm
# Data from company extracted: AliNyMA Alimentación Nutrición y Medio Ambiente
# Data from company extracted: Alira Health
# Data from company extracted: Allergeneat
# Data from company extracted: Allergy Therapheutics Iberica
# Data from company extracted: Allinone Healthpro
# Data from company extracted: Alma Medical Imaging
# Data from company extracted: Almirall (HQ, Barcelona)
# Data from company extracted: Almus Farmaceutica
# Data from company extracted: Alta Life Sciences
# Data from company extracted: Alta Medical Services
# Data from company extracted: Altaquimica
# Data from company extracted: Alteraid
# Data from company extracted: Alter-Entorn
#
# ********************************** Potential issue in company: Althea Healthcare España
#
# Data from company extracted: Amalfi Analytics
# Data from company extracted: Amapex
# Data from company extracted: Amaris Consulting &amp; Innovation
# Data from company extracted: Ambit BST (HQ, Barcelona)
# Data from company extracted: Amedyn Healthcare
# Data from company extracted: Amelia Virtual Care
# Data from company extracted: Amgen
# Data from company extracted: AMP biotech
# Data from company extracted: Anaconda BioMed
# Data from company extracted: Anagram-ESIC
# Data from company extracted: ANAIS medical
# Data from company extracted: Anapharm Bioanalytics
# Data from company extracted: Anaxomics
#
# ********************************** Potential issue in company: Ancar
#
# Data from company extracted: Andersen
# Data from company extracted: Andrés Pintaluba
#
# ********************************** Potential issue in company: Angelini Farmacéutica
#
# Data from company extracted: Aniling
# Data from company extracted: Ànima Design
# Data from company extracted: Anota
#
# ********************************** Potential issue in company: Antares Consulting
#
# Data from company extracted: AntibodyBCN (AbBcn)
# Data from company extracted: Antonio Matachana
# Data from company extracted: AON Therapeutics
# Data from company extracted: AOResearch
# Data from company extracted: Aortyx
# Data from company extracted: Apa Laboratoris Clínics
# Data from company extracted: Applied Nanoparticles
# Data from company extracted: Aptadel Therapeutics
# Data from company extracted: Aqualogy
#
# ********************************** Potential issue in company: Aquiles Robotic Systems
#
# Data from company extracted: Aragogamma
# Data from company extracted: Arber Surgical
# Data from company extracted: Arboribus
#
# ********************************** Potential issue in company: ARCh MAX
#
# Data from company extracted: Archivel Farma
# Data from company extracted: Arelsa
# Data from company extracted: Arian International Projects
# Data from company extracted: Aristos Innovation Consulting
# Data from company extracted: Aromics
# Data from company extracted: Arroba Capital
# Data from company extracted: Arvor Consulting
# Data from company extracted: Asabys Partners
# Data from company extracted: ASCIL Biopharm
# Data from company extracted: Asho
# Data from company extracted: Asociación Forum Auditorias (AFA)
#
# ********************************** Potential issue in company: AsorCAD
#
# Data from company extracted: Aspen Pharma Iberia
# Data from company extracted: Asphalion
# Data from company extracted: Assi Sistemes
# Data from company extracted: Associació Catalana d’Entitats de Recerca (ACER)
# Data from company extracted: Associació Catalana d'Universitats Públiques (ACUP)
# Data from company extracted: Astradentium Health Technologies
# Data from company extracted: AstraZeneca
# Data from company extracted: Ateknea Solutions Catalonia
# Data from company extracted: Atens
# Data from company extracted: AtG Therapeutics
# Data from company extracted: ATIC (Centre d'Avantguarda Tecnològica per la Innovació)
# Data from company extracted: Atomian
# Data from company extracted: Atos Medical Spain
# Data from company extracted: Atraura
# Data from company extracted: Atrys Health
# Data from company extracted: AttendBio Research
# Data from company extracted: AuditGMP Pharma
# Data from company extracted: Auditories Tècniques BCN
# Data from company extracted: Aureel
# Data from company extracted: Auren
# Data from company extracted: Aurocis (Nanotargeting)
# Data from company extracted: Automated Crystallography Platform (IBMB-CSIC)
# Data from company extracted: Avançsa
# Data from company extracted: Àvida Biotech
# Data from company extracted: Avinent Implant System
# Data from company extracted: Axeb Biotech
# Data from company extracted: AYO by Novalogy
# Data from company extracted: Azbil Telstar Technologies
# Data from company extracted: Azelis España
# Data from company extracted: Azierta
# Data from company extracted: B. Braun VetCare
# Data from company extracted: Bactabio
# Data from company extracted: Bacteralia
# Data from company extracted: Bagi Xarxa d'Àngels Inversors de Girona
# Data from company extracted: Baker &amp; Mckenzie
# Data from company extracted: Ball Head System
# Data from company extracted: Banc de Sang i Teixits (BST)
#
# ********************************** Potential issue in company: Barça Innovation Hub
#
#
# ********************************** Potential issue in company: Barcelona Activa
#
# Data from company extracted: Barcelona Advanced Industry Park (BAIP)
#
# ********************************** Potential issue in company: Barcelona Centre Universitari (BCU)
#
# Data from company extracted: Barcelona Graduate School of Economics (Barcelona GSE)
# Data from company extracted: Barcelona Innovation Partners
# Data from company extracted: Barcelona Institut Emprenedoria (BIE)
# Data from company extracted: Barcelona International Medical Academy (BIMA)
# Data from company extracted: Barcelona Liver Bioservices
# Data from company extracted: Barcelona Macula Foundation: Research for Vision (BMF)
# Data from company extracted: Barcelona Skin Genomics (BSG)
#
# ********************************** Potential issue in company: Barcelona Supercomputing Center - Centro Nacional de Supercomputación (BSC-CNS)
#
# Data from company extracted: Barcelona Synchrotron Park (Parc de l'Alba)
# Data from company extracted: Barcelona Ventures
# Data from company extracted: BarcelonaBeta Brain Research Center (BBRC)
# Data from company extracted: Bard de España
# Data from company extracted: Bardehle Pagenberg
# Data from company extracted: BASF Española
# Data from company extracted: Batec Mobility
# Data from company extracted: Bax &amp; Willems Consulting Venturing
# Data from company extracted: Bayer Hispania
# Data from company extracted: B&amp;B Asesores
# Data from company extracted: BCN Business Angels
# Data from company extracted: BCN Farma
# Data from company extracted: BCN Health Economics &amp; Outcomes Research
# Data from company extracted: BCN Innova Technological Evolution
#
# ********************************** Potential issue in company: BCN Peptides
#
# Data from company extracted: BCN3D Technologies
# Data from company extracted: BDcare
# Data from company extracted: Beauty Cluster Barcelona
# Data from company extracted: Beckman Coulter
# Data from company extracted: Bellavista Legal
#
# ********************************** Potential issue in company: Bellco
#
# Data from company extracted: Berdac
# Data from company extracted: Bertrandt (Barcelona)
#
# ********************************** Potential issue in company: BetaScreen
#
# Data from company extracted: Better Care
# Data from company extracted: BHV Partners
# Data from company extracted: Bicosome
# Data from company extracted: bIDEA Avant
# Data from company extracted: Biel Glasses
# Data from company extracted: Bien Air España
# Data from company extracted: Bimedica
# Data from company extracted: Bioaccez Controls
# Data from company extracted: Biobank (HUB-ICO-IDIBELL)
# Data from company extracted: Biobank (IDIBAPS)
# Data from company extracted: BIOBIZ Strategy &amp; Communications
# Data from company extracted: Biocat
# Data from company extracted: Biochemize
# Data from company extracted: BioClever
# Data from company extracted: BioCloud
# Data from company extracted: BIOcomuniCA'T
# Data from company extracted: Biocontrol Technologies
# Data from company extracted: Biocosmetica Exel
# Data from company extracted: BioEclosion
#
# ********************************** Potential issue in company: Bioemprèn
#
#
# ********************************** Potential issue in company: Biogard
#
# Data from company extracted: Bioibérica (HQ, Barcelona)
# Data from company extracted: Bioinfogate
#
# ********************************** Potential issue in company: Bioinformatics Barcelona Association (BIB)
#
#
# ********************************** Potential issue in company: Bioinformatics (IDIBAPS)
#
# Data from company extracted: Bioinformatics Unit (CRG)
# Data from company extracted: Bioingenium
# Data from company extracted: Bioinnove
# Data from company extracted: Biointaxis
# Data from company extracted: Biomedical Logistics
#
# ********************************** Potential issue in company: Biomet 3i Dental Iberica
#
# Data from company extracted: Bioner
# Data from company extracted: Bioo
# Data from company extracted: Biopharma Synergies (BPS)
# Data from company extracted: Bioprognos
# Data from company extracted: Bioquim
# Data from company extracted: Bio-Rad Laboratories
# Data from company extracted: BioSeed Capital
# Data from company extracted: Biosfer Teslab
# Data from company extracted: Biosystems
# Data from company extracted: BIOTAP
# Data from company extracted: Biotech Tricopharming Research
# Data from company extracted: Biotechnology Business Institute (BBI)
# Data from company extracted: Biotronik
# Data from company extracted: Biovert
# Data from company extracted: Biovet
# Data from company extracted: Biprocel
# Data from company extracted: Bitac
#
# ********************************** Potential issue in company: Bitmetrics
#
# Data from company extracted: Biwel
# Data from company extracted: Blanca
# Data from company extracted: Blistersuit
# Data from company extracted: BloodGenetics
# Data from company extracted: Blueberry Diagnostics (BCN)
# Data from company extracted: Bluephage
# Data from company extracted: Boehringer Ingelheim Animal Health
# Data from company extracted: Boehringer Ingelheim España
# Data from company extracted: Bolsaplast
# Data from company extracted: Bonoom
# Data from company extracted: Boston Scientific Barcelona
# Data from company extracted: Brain Health Solutions
#
# ********************************** Potential issue in company: Braincats Consulting
#
# Data from company extracted: Braingaze
# Data from company extracted: BRASCAT
# Data from company extracted: Brave Lifescience
# Data from company extracted: Breaz Medical
# Data from company extracted: BrickBio
# Data from company extracted: Brill Pharma
# Data from company extracted: Broomx
# Data from company extracted: Brudy Technology
# Data from company extracted: Brugués
# Data from company extracted: BSN Medical
# Data from company extracted: Bsure Medical (HQ, Cornellà de Llobregat)
# Data from company extracted: b_TEC Barcelona Innovació Tecnològica
# Data from company extracted: BTHT
#
# ********************************** Potential issue in company: Business Angels Network de Catalunya (BANC)
#
# Data from company extracted: Butler Scientifics
#
# ********************************** Potential issue in company: BZ Barcelona Zona Innovació
#
# Data from company extracted: B'ZEOS
#
# ********************************** Potential issue in company: Cabinet de Asesoramiento y Expertise (Cabex)
#
# Data from company extracted: Cafosa Gum
# Data from company extracted: Caixa Capital Risc
# Data from company extracted: Cannabity Healthcare
# Data from company extracted: Capenergy Medical
#
# ********************************** Potential issue in company: Capital Cell
#
# Data from company extracted: Cardiolink
#
# ********************************** Potential issue in company: Cardionlive
#
# Data from company extracted: Cardiosafe
# Data from company extracted: CardioSOS
# Data from company extracted: Cardiumm
# Data from company extracted: Care Respite
# Data from company extracted: CataloniaBio &amp; HealthTech
# Data from company extracted: Catlab
# Data from company extracted: CDClinic
# Data from company extracted: Cebiotex
# Data from company extracted: Cellab
# Data from company extracted: Celltec UB
# Data from company extracted: Cenavisa
#
# ********************************** Potential issue in company: Center for Computational Imaging &amp; Simulation Technologies in Biomedicine (CISTIB)
#
# Data from company extracted: Centre de Desenvolupaments Biotecnològics i Agroalimentaris (DBA)
# Data from company extracted: Centre de Medicina Comparativa i bioimatge de Catalunya (CMCiB)
#
# ********************************** Potential issue in company: Centre de Nanotecnologia i Materials Moleculars (NANOMOL)
#
# Data from company extracted: Centre de Recerca de Nanoenginyeria (CRNE)
# Data from company extracted: Centre de Recerca en Agrigenòmica (CRAG)
# Data from company extracted: Centre de Recerca en Agrotecnologia (Agrotecnio)
# Data from company extracted: Centre de Recerca en Enginyeria Biomèdica (CREB-UPC)
#
# ********************************** Potential issue in company: Centre de Recerca en Enginyeria de Materials i micro/nano Sistemes (EMaS)
#
# Data from company extracted: Centre de Recerca en Sanitat Animal (CRESA)
#
# ********************************** Potential issue in company: Centre de Recerca en Seguretat i Control Alimentari (CRESCA)
#
#
# ********************************** Potential issue in company: Centre de Recerca en Toxicologia (CERETOX)
#
# Data from company extracted: Centre de Recerca Matemàtica (CRM)
# Data from company extracted: Centre de Referència en Biotecnologia (CERBA)
# Data from company extracted: Centre de Regulació Genòmica (CRG)
#
# ********************************** Potential issue in company: Centre de Transferència de Tecnologia de la Universitat de Lleida UdL (TTO)
#
#
# ********************************** Potential issue in company: Centre de Transferència de Tecnologia i Innovació de la Universitat Rovira i Virgili (TTO)
#
#
# ********************************** Potential issue in company: Centre de Transferència de Tecnologia UPC (TTO)
#
# Data from company extracted: Centre de Transferència del Coneixement i Valorització de la Recerca de la Universitat Internacional de Catalunya (TTO)
# Data from company extracted: Centre de Visió per Computador (CVC)
# Data from company extracted: Centre d’Estudis de Ciència, Comunicació i Societat de la Universitat Pompeu Fabra (CCS-UPF)
# Data from company extracted: Centre d'Estudis Demogràfics (CED)
# Data from company extracted: Centre d'Estudis Sanitaris i Socials (CESS)
# Data from company extracted: Centre Especial de Recerca Planta de Tecnologia dels Aliments (CERPTA)
# Data from company extracted: Centre for Omic Sciences (COS)
#
# ********************************** Potential issue in company: Centre Internacional de Mètodes Numèrics en Enginyeria (CIMNE)
#
# Data from company extracted: Centre Nacional d'Anàlisi Genòmica (CNAG)
#
# ********************************** Potential issue in company: Centre Nacional de Microelectrònica (CNM)
#
# Data from company extracted: Centro de Estudios Superiores de la Industria Farmacéutica (CESIF)
# Data from company extracted: Centro Médico Teknon
# Data from company extracted: Ceramtec Ibérica
# Data from company extracted: Cercle Tecnològic de Catalunya
# Data from company extracted: Cetir Grup Mèdic
# Data from company extracted: Ceva Salud Animal
# Data from company extracted: CEX Internacional
# Data from company extracted: CG Health Ventures
# Data from company extracted: Change Dyslexia
# Data from company extracted: Charles River Laboratories España
# Data from company extracted: Chasing Science
# Data from company extracted: Chemgineering (Barcelona)
# Data from company extracted: Chemo Iberica
# Data from company extracted: Chemotargets
#
# ********************************** Potential issue in company: Chemswiss Ibérica
#
# Data from company extracted: Chiesi España
# Data from company extracted: CIDQO
# Data from company extracted: Ciència i Recerca Experimental Biomèdica Aplicada (CREBA)
# Data from company extracted: CIMAB (Centro de Infertilidad Masculina y Análisis de Barcelona)
# Data from company extracted: Cimer
# Data from company extracted: Cinta-Plast
# Data from company extracted: Cirex Consulting
# Data from company extracted: CITA.iO
# Data from company extracted: Clarivate Analytics (Barcelona)
# Data from company extracted: Clarke, Modet y Companyía
# Data from company extracted: Clementine Global
# Data from company extracted: Click Doctors
# Data from company extracted: Clinic Point
# Data from company extracted: Clinica Eugin
# Data from company extracted: Clinical Document Engineering
#
# ********************************** Potential issue in company: Clinical Research Unit (UCICEC)
#
# Data from company extracted: CLINOBS
# Data from company extracted: ClinTec International
#
# ********************************** Potential issue in company: Clúster de Nutrició i Salut
#
#
# ********************************** Potential issue in company: Clúster de Salut Mental
#
# Data from company extracted: Clúster Digital
# Data from company extracted: CN Logistica
# Data from company extracted: Cobapharma
# Data from company extracted: Col·legi Oficial de Metges de Barcelona (COMB)
# Data from company extracted: ColorSensing
#
# ********************************** Potential issue in company: ColorsTheApp
#
# Data from company extracted: Combinatorial Chemistry Unit (UQC-PCB)
#
# ********************************** Potential issue in company: Comercial Rafer
#
# Data from company extracted: Complife Group (Barcelona)
# Data from company extracted: Comser Pharma
# Data from company extracted: Connecta Therapeutics
#
# ********************************** Potential issue in company: Connectem. Healthcare Business Consulting
#
# Data from company extracted: ConnecThink
#
# ********************************** Potential issue in company: Consorci de Serveis Universitaris de Catalunya (CSUC)
#
# Data from company extracted: Consorci Hospitalari de Vic (CHV)
# Data from company extracted: Consorci Sanitari de Terrassa (CST)
# Data from company extracted: Consulpi
# Data from company extracted: Control Live
# Data from company extracted: Convatec
# Data from company extracted: Cook España
#
# ********************************** Potential issue in company: Coolvacuum
#
# Data from company extracted: Cornea Project
# Data from company extracted: Coronis Computing
# Data from company extracted: Corus Dental
#
# ********************************** Potential issue in company: Co-Salud
#
# Data from company extracted: COSINGO - Imagine Optic Spain
# Data from company extracted: Costaisa
# Data from company extracted: Cotecnica
# Data from company extracted: Coyma
# Data from company extracted: CPQ Ingenieros
# Data from company extracted: Crea Inversión
# Data from company extracted: CRISA RX
# Data from company extracted: Crisalix
#
# ********************************** Potential issue in company: Croda (Barcelona)
#
# Data from company extracted: Crowdcube
#
# ********************************** Potential issue in company: CSL Behring
#
# Data from company extracted: CSV Experts
# Data from company extracted: Cuantum Medical Cosmetics
# Data from company extracted: Cuatrecasas
# Data from company extracted: Cube Technology Innovation
# Data from company extracted: Cuideo
# Data from company extracted: Cuore Care
# Data from company extracted: Curell Suñol
# Data from company extracted: CV Medica
# Data from company extracted: Cygyc
# Data from company extracted: Cytes Biotechnologies
# Data from company extracted: Cytometry and Cell Sorting Facility (IDIBAPS)
# Data from company extracted: Cytomics Unit (IDIBELL)
# Data from company extracted: Daiprox
# Data from company extracted: Dallant
# Data from company extracted: Dana (A thousand colibris)
# Data from company extracted: Danagen
# Data from company extracted: DAN*NA Artificial Nature
# Data from company extracted: Dara Pharma
# Data from company extracted: DBGen Ocular Genomics
#
# ********************************** Potential issue in company: DBS Screening
#
#
# ********************************** Potential issue in company: DC Fine Chemicals Spain
#
# Data from company extracted: DDBIOLAB
# Data from company extracted: De Dietrich Equipos Químicos
# Data from company extracted: DeepUll
# Data from company extracted: Deloitte Barcelona
# Data from company extracted: Deltalab
# Data from company extracted: Dentaid
# Data from company extracted: Dentsply Implants
#
# ********************************** Potential issue in company: Deretil
#
# Data from company extracted: Deretil Agronutritional
# Data from company extracted: Dermavision Solutions
# Data from company extracted: Dermofarm
# Data from company extracted: Devicare
#
# ********************************** Potential issue in company: DevsHealth
#
# Data from company extracted: Devsynthesis (Barcelona)
# Data from company extracted: Dextro Medica (HQ,Sant Cugat del Valles)
# Data from company extracted: Diagnóstica Stago
#
# ********************************** Potential issue in company: Diamed Iberica
#
# Data from company extracted: DICOMOL
# Data from company extracted: Dictyapharma
# Data from company extracted: Dicus
# Data from company extracted: Diet Creator
# Data from company extracted: Dietary Molecular Diagnostics
# Data from company extracted: Dietox
# Data from company extracted: Digimevo
#
# ********************************** Potential issue in company: Digital Cell
#
# Data from company extracted: Dinbeat
# Data from company extracted: Disproquima
# Data from company extracted: Ditec Medical
# Data from company extracted: Divasa-Farmavic (DFV)
# Data from company extracted: DJO Ibérica
# Data from company extracted: DK Diagnostics EMEA
# Data from company extracted: DNANutricoach
# Data from company extracted: Doctivi
#
# ********************************** Potential issue in company: Doctomatic
#
# Data from company extracted: Doctoralia
# Data from company extracted: Doctuo
# Data from company extracted: Doctux Mhealth Services
# Data from company extracted: Docuchem
# Data from company extracted: Dominion
# Data from company extracted: DOMMA
# Data from company extracted: Dompé Farmaceutici España
# Data from company extracted: Doole Health
# Data from company extracted: Dosis Health
#
# ********************************** Potential issue in company: Dr. Healthcare España
#
# Data from company extracted: DRACO SYSTEMS
# Data from company extracted: Draconis Pharma
# Data from company extracted: Dribia Data Research
# Data from company extracted: Dromex International
# Data from company extracted: Drug Development and Regulation (DDR)
# Data from company extracted: Dryox Health
# Data from company extracted: DSM Sinochem Pharmaceuticals Spain
# Data from company extracted: Duke Chem
# Data from company extracted: Durcal
# Data from company extracted: Durr Dental Medics Iberica
# Data from company extracted: DVD Dental
# Data from company extracted: Dycare (Dynamic Care Solutions)
# Data from company extracted: Dynamic Abutment Solutions
# Data from company extracted: eCareYou Innovation
# Data from company extracted: Ecobium Biotech
# Data from company extracted: Ecoceutics
# Data from company extracted: Ecogen
# Data from company extracted: Economistes BAN (Col·legi d'economistes de Catalunya)
# Data from company extracted: Econtrol Assessors y Consultors
# Data from company extracted: Ecopol Tech
#
# ********************************** Potential issue in company: Edryx Healthcare
#
# Data from company extracted: Efarmes
#
# ********************************** Potential issue in company: Effiloop Alerts
#
# Data from company extracted: Efron Consulting
# Data from company extracted: EG Active Cosmetics
# Data from company extracted: eHealthAI
# Data from company extracted: Eignapharma
# Data from company extracted: EIT Health Spain (Barcelona)
# Data from company extracted: Eix Technova Barcelona
# Data from company extracted: El Coco
# Data from company extracted: Elausa
# Data from company extracted: Electro AD
# Data from company extracted: Electrolomas
# Data from company extracted: Elem Biotech
# Data from company extracted: Elix Polymers
# Data from company extracted: EMA
# Data from company extracted: Embryotools
#
# ********************************** Potential issue in company: Emjoy
#
# Data from company extracted: EMLIFE
# Data from company extracted: Enantia
# Data from company extracted: ENDOASIC Technologies
# Data from company extracted: Endolipid Therapeutics
# Data from company extracted: Endor Nanotechnologies
# Data from company extracted: Enerbio
# Data from company extracted: Energy for Business
# Data from company extracted: Enext engineers and contractors
# Data from company extracted: EngiCom
# Data from company extracted: Engidi
# Data from company extracted: Enginy Biorem
# Data from company extracted: Ensis Sciences
#
# ********************************** Potential issue in company: Entregoo
#
# Data from company extracted: Envigo
# Data from company extracted: Enzyme Advising Group
# Data from company extracted: Eodyne Systems
# Data from company extracted: Eolo
# Data from company extracted: EoxSense
#
# ********************************** Potential issue in company: Ephion Health
#
# Data from company extracted: Eprodics
# Data from company extracted: EQ Esteve
# Data from company extracted: Ercros
# Data from company extracted: Ernst &amp; Young (EY) Barcelona
# Data from company extracted: ESADE
# Data from company extracted: ESADE BAN
# Data from company extracted: Esade Creapolis
# Data from company extracted: ESAME
# Data from company extracted: Escuela de Alta Dirección y Administración (EADA)
# Data from company extracted: Especialidades Medicas MYR
# Data from company extracted: Essilor
#
# ********************************** Potential issue in company: Estabulari (UDL)
#
# Data from company extracted: Esteve
# Data from company extracted: Esteve-Teijin Healthcare
# Data from company extracted: EstimTrack
# Data from company extracted: eSTRATELIS
# Data from company extracted: Eurecat
# Data from company extracted: Eurofins BioPharma
# Data from company extracted: EUROGINE
# Data from company extracted: Eurohold
# Data from company extracted: Euroklee
# Data from company extracted: Euromed
# Data from company extracted: European Quality Assurance Spain (EQA)
# Data from company extracted: EVERAI Medical Technologies
# Data from company extracted: Everest, Tecnología Veterinaria y Médica
# Data from company extracted: Evic Hispania (Centro Experimental de Evaluación Cutánea)
# Data from company extracted: Evolutive Medica
# Data from company extracted: Excelera
# Data from company extracted: Exheus
# Data from company extracted: Expert Ymaging
# Data from company extracted: Family Synergy
# Data from company extracted: Farmaban
# Data from company extracted: Farmaconfianza
# Data from company extracted: Farmantra
# Data from company extracted: Farmaprojects
# Data from company extracted: Fatro Iberica
# Data from company extracted: Faus &amp; Moliner Advocats
# Data from company extracted: Federació Europea de Malalties Minoritàries (Eurordis)
# Data from company extracted: Fermentation Pilot Plant (UAB)
# Data from company extracted: Ferrer (HQ, Barcelona)
#
# ********************************** Potential issue in company: Finaves
#
# Data from company extracted: Fisiovirtual
# Data from company extracted: Fitomón
# Data from company extracted: Flexor
# Data from company extracted: Flomics Biotech
# Data from company extracted: Flow Citometry (UPF)
# Data from company extracted: Flubetech
# Data from company extracted: Forbaker
# Data from company extracted: Formas Naturales
#
# ********************************** Potential issue in company: Foro capital pymes
#
# Data from company extracted: Forté Pharma
# Data from company extracted: Founder Institute
# Data from company extracted: FractalMed
# Data from company extracted: FreeOx Biotech
# Data from company extracted: Fresco International
# Data from company extracted: Fresco Podologia
# Data from company extracted: Fresenius Kabi España
# Data from company extracted: FrontWave Imaging
# Data from company extracted: Fuelfor
# Data from company extracted: Fuelium
# Data from company extracted: Fujirebio Iberia
# Data from company extracted: Funbrain
# Data from company extracted: Functional Genomics (IDIBAPS)
#
# ********************************** Potential issue in company: Fundacio Althaia. Xarxa Assistencial de Manresa
#
# Data from company extracted: Fundació Bosch i Gimpera FBG (TTO)
# Data from company extracted: Fundació CIM
# Data from company extracted: Fundació Clínic per a la Recerca Biomèdica (FCRB)
# Data from company extracted: Fundació Dr. Antoni Esteve
#
# ********************************** Potential issue in company: Fundació Dr. Ferran per a la Investigació en Ciències de la Salut
#
# Data from company extracted: Fundació DTI-Donation &amp; Transplantation Institute
# Data from company extracted: Fundació GAEM
# Data from company extracted: Fundació Garcia Cugat
# Data from company extracted: Fundació Hospital Asil de Granollers
#
# ********************************** Potential issue in company: Fundació Institut Català de Farmacologia (FICF)
#
# Data from company extracted: Fundació Oncològica de Catalunya (FOC)
# Data from company extracted: Fundació Pasqual Maragall per a la recerca sobre l’Alzheimer (FPM)
# Data from company extracted: Fundació per a la Investigació Nutricional (FIN)
# Data from company extracted: Fundació Puigvert
# Data from company extracted: Fundació The Barcelona Institute of Science and Technology (BIST)
# Data from company extracted: Fundación iSYS
# Data from company extracted: Fundación Step by Step
# Data from company extracted: Future Companies Partners
# Data from company extracted: Futureco Bioscience
# Data from company extracted: GAES Medica
# Data from company extracted: Gain Therapeutics (Barcelona)
# Data from company extracted: GalChimia
# Data from company extracted: Galenicum
# Data from company extracted: Galgo Medical
# Data from company extracted: Garrigues
# Data from company extracted: Gases Research Innovation and Technology (GRIT)
# Data from company extracted: Gasinox
# Data from company extracted: Gat Biosciences
# Data from company extracted: Gat Therapeutics
# Data from company extracted: Gate2Brain
# Data from company extracted: GE Healthcare
#
# ********************************** Potential issue in company: GEA Westfalia Separator Ibérica
#
# Data from company extracted: Gebro Pharma
# Data from company extracted: Gedeon Richter Iberica
# Data from company extracted: Gen Incode (Terrassa, Barcelona)
# Data from company extracted: GENESIS Biomed
#
# ********************************** Potential issue in company: GenIUL
#
# Data from company extracted: Genomics Unit (IDIBELL)
# Data from company extracted: Gentec
# Data from company extracted: Gesaworld
#
# ********************************** Potential issue in company: GesFilter
#
# Data from company extracted: Gil Roda Medical writing
# Data from company extracted: Gisek Diagnostic Thermography
#
# ********************************** Potential issue in company: G&amp;L Scientific (Barcelona)
#
# Data from company extracted: Glifing
# Data from company extracted: GlobaCare Clinical trials
# Data from company extracted: Global Sensory
# Data from company extracted: GLOBMOD
#
# ********************************** Potential issue in company: Gloria Digital
#
# Data from company extracted: GlyCardial Diagnostics
# Data from company extracted: GMI Ilerimplant Group
# Data from company extracted: Goo Apps
# Data from company extracted: Goo Medical
# Data from company extracted: Goodgrower
# Data from company extracted: GoodGut
# Data from company extracted: GP Pharm
# Data from company extracted: GPA Medical
# Data from company extracted: GraphenicaLab
#
# ********************************** Potential issue in company: Green in Blue
#
# Data from company extracted: Greenaltech
# Data from company extracted: Grifols Engineering
# Data from company extracted: Grifols (HQ, Sant Cugat del Valles)
# Data from company extracted: Groenlandia Tech
# Data from company extracted: Grow Venture Partners
# Data from company extracted: Growup Services
# Data from company extracted: Grup Maculart
# Data from company extracted: Grup SAGESSA
# Data from company extracted: Grupo B. Braun España
# Data from company extracted: Grupo Menarini España
# Data from company extracted: Grupo Pulso
# Data from company extracted: g.tec medical engineering Spain
# Data from company extracted: Gutmar
# Data from company extracted: GxMed Healthcare
# Data from company extracted: Gyala Therapeutics
# Data from company extracted: Gym For Less
# Data from company extracted: HallTech
# Data from company extracted: Hamamatsu Photonics
# Data from company extracted: Hans e Ruth
# Data from company extracted: Hartington Pharmaceuticals (HQ)
# Data from company extracted: Hartmann España
#
# ********************************** Potential issue in company: Health Circuit
#
# Data from company extracted: Health Innovation Technology Transfer (HITT)
# Data from company extracted: Health Market Research (HMR) - Barcelona
# Data from company extracted: Healthapp
#
# ********************************** Potential issue in company: Healthcor
#
#
# ********************************** Potential issue in company: HealthEquity
#
# Data from company extracted: HealthQuay
# Data from company extracted: Health&amp;sportlab
#
# ********************************** Potential issue in company: HealthTech Bioactives (HTBA)
#
# Data from company extracted: Hemophotonics
# Data from company extracted: Hemostatics Pharmaceuticals
# Data from company extracted: Herrero y Asociados
# Data from company extracted: Hesoft Group
# Data from company extracted: Hexacath España
# Data from company extracted: HHP Spain
#
# ********************************** Potential issue in company: High Throughput Screening and Robotic  Unit (CRG)
#
# Data from company extracted: Higiatech
# Data from company extracted: Hipra (HQ, Girona)
# Data from company extracted: Hipra scientific
# Data from company extracted: Hipra scientific
# Data from company extracted: Hologic Iberia
# Data from company extracted: HoMu Health Ventures
# Data from company extracted: Hospital Clínic de Barcelona
# Data from company extracted: Hospital de la Santa Creu i Sant Pau (HSCiSP)
#
# ********************************** Potential issue in company: Hospital de Sant Joan de Déu (HSJD)
#
#
# ********************************** Potential issue in company: Hospital de Sant Joan Despí Moisès Broggi
#
# Data from company extracted: Hospital del Mar
#
# ********************************** Potential issue in company: Hospital Quirónsalud Barcelona
#
# Data from company extracted: Hospital Universitari Arnau de Vilanova
# Data from company extracted: Hospital Universitari de Bellvitge (HUB)
# Data from company extracted: Hospital Universitari de Girona Doctor Josep Trueta
# Data from company extracted: Hospital Universitari Dexeus
# Data from company extracted: Hospital Universitari d'Igualada
# Data from company extracted: Hospital Universitari General de Catalunya
# Data from company extracted: Hospital Universitari Germans Trias i Pujol (HUGTiP)
# Data from company extracted: Hospital Universitari Joan XXIII de Tarragona
# Data from company extracted: Hospital Universitari Mútua de Terrassa
# Data from company extracted: Hospital Universitari Sagrat Cor
# Data from company extracted: Hospital Universitari Sant Joan de Reus
# Data from company extracted: Hospital Universitari Vall d'Hebron
# Data from company extracted: Hospital Verge de la Cinta de Tortosa
# Data from company extracted: HPC Now!
# Data from company extracted: HTSS
# Data from company extracted: HumanITcare
# Data from company extracted: Humantiks
# Data from company extracted: Hygeia Technologies
# Data from company extracted: IALE Tecnologia
# Data from company extracted: IBERinsect
# Data from company extracted: ICON Clinical Research
# Data from company extracted: Idom Ingeniería y Consultoría
# Data from company extracted: I-Dositecno
# Data from company extracted: IDP Pharma
# Data from company extracted: IESE
# Data from company extracted: Ige Ingenieros
# Data from company extracted: Ignite Technologies
# Data from company extracted: Igrobe
# Data from company extracted: Iguña Pharmaceutical Technologies
# Data from company extracted: IHT - Innovative Health Technologies
# Data from company extracted: iMAZTECH Smartglove
# Data from company extracted: Imb Grup
#
# ********************************** Potential issue in company: IMCD España Especialidades Quimicas
#
# Data from company extracted: iMedicPlus
# Data from company extracted: ​IMIDomics (HQ, Barcelona)
# Data from company extracted: Immucor
# Data from company extracted: Impetux Optics
# Data from company extracted: Implant Microdent System
# Data from company extracted: Implant Protesis Dental 2004
# Data from company extracted: Impress
# Data from company extracted: Inbiomotion
# Data from company extracted: InBrain Neuroelectronics
# Data from company extracted: Indalter
#
# ********************************** Potential issue in company: Indiba (HQ, Sant Quirze del Valles)
#
# Data from company extracted: Induct
# Data from company extracted: Indukern S.A.
# Data from company extracted: Industrial Química LASEM
# Data from company extracted: Industrial Tècnica Pecuària (ITPSA) (HQ,Barcelona)
# Data from company extracted: Infinitec Activos (HQ, Barcelona)
# Data from company extracted: InfoGenia SCP
# Data from company extracted: Infomed Servicios Informaticos
# Data from company extracted: INGECAL, Ingeniería de la Calidad y el Medio Ambiente, SL
# Data from company extracted: INGELYT
# Data from company extracted: Inke
# Data from company extracted: Inkemia IUCT Group
# Data from company extracted: INKO21
# Data from company extracted: INLEAN Engineering
# Data from company extracted: Inn Flavours
# Data from company extracted: Innerva Pharmaceuticals
# Data from company extracted: INNERVIA Bioelectronics
#
# ********************************** Potential issue in company: Innitius (Barcelona)
#
# Data from company extracted: Innoget
# Data from company extracted: InnoPharma
# Data from company extracted: Innopro Consulting
# Data from company extracted: Innoqua
# Data from company extracted: Innovafarm
# Data from company extracted: Innovamed Spain
# Data from company extracted: Innovatech Law Firm
# Data from company extracted: Innovem
# Data from company extracted: Innovex Therapeutics
# Data from company extracted: Innuo
# Data from company extracted: Institució Catalana de Recerca i Estudis Avançats (ICREA)
#
# ********************************** Potential issue in company: Institut Català de Ciències Cardiovasculars (ICCC)
#
# Data from company extracted: Institut Català de Finances (ICF)
# Data from company extracted: Institut Català de la Salut (ICS)
# Data from company extracted: Institut Català de Nanociència i Nanotecnologia (ICN2)
# Data from company extracted: Institut Català de Recerca de l'Aigua (ICRA)
# Data from company extracted: Institut Català d'Investigació Química (ICIQ)
#
# ********************************** Potential issue in company: Institut Català d'Oncologia de l'Hospitalet de Llobregat (ICO)
#
# Data from company extracted: Institut de Bioenginyeria de Catalunya (IBEC)
#
# ********************************** Potential issue in company: Institut de Biologia Evolutiva (IBE-CSIC-UPF)
#
# Data from company extracted: Institut de Biologia Molecular de Barcelona (IBMB-CSIC)
# Data from company extracted: Institut de Biotecnologia i Biomedicina Vicent Villar Palasí (IBB)
# Data from company extracted: Institut de Ciència de Materials de Barcelona (ICMAB-CSIC)
# Data from company extracted: Institut de Ciències Fotòniques (ICFO)
# Data from company extracted: Institut de Física d'Altes Energies (IFAE)
# Data from company extracted: Institut de Microcirurgia Ocular (IMO)
# Data from company extracted: Institut de Microelectrònica de Barcelona (IMB-CNM-CSIC)
# Data from company extracted: Institut de Nanociència i Nanotecnologia (IN2UB)
#
# ********************************** Potential issue in company: Institut de Neurociències de la Universitat de Barcelona
#
#
# ********************************** Potential issue in company: Institut de Neurociències (INc) de la UAB
#
# Data from company extracted: Institut de Química Avançada de Catalunya (IQAC-CSIC)
# Data from company extracted: Institut de Química Computacional (IQC)
# Data from company extracted: Institut de Química Teorica i Computacional (IQTC-UB)
#
# ********************************** Potential issue in company: Institut de Recerca Biomèdica de Barcelona (IRB Barcelona)
#
# Data from company extracted: Institut de Recerca Biomèdica de Lleida (IRB Lleida)
# Data from company extracted: Institut de Recerca Contra la Leucèmia Josep Carreras (IJC)
# Data from company extracted: Institut de Recerca de la Sida (IrsiCaixa)
# Data from company extracted: Institut de Recerca en Energia de Catalunya (IREC)
# Data from company extracted: Institut de Recerca i Tecnologia Agroalimentàries (IRTA)
# Data from company extracted: Institut de Recerca Sant Joan de Déu (IRSJD)
# Data from company extracted: Institut de Robòtica i Informàtica Industrial (IRI-CSIC-UPC)
# Data from company extracted: Institut de Salut Global de Barcelona (ISGlobal)
# Data from company extracted: Institut de Tecnologia Agroalimentària (INTEA)
# Data from company extracted: Institut d'Informàtica i Aplicacions (IIiA)
#
# ********************************** Potential issue in company: Institut d'Investigació Biomèdica de Bellvitge (IDIBELL)
#
# Data from company extracted: Institut d'Investigació Biomèdica de Girona Dr. Josep Trueta (IdiBGi)
# Data from company extracted: Institut d'Investigació Biomèdica Sant Pau (IIB Sant Pau)
#
# ********************************** Potential issue in company: Institut d'Investigació en Ciències de la Salut Germans Trias i Pujol (IGTP)
#
#
# ********************************** Potential issue in company: Institut d'Investigació en Intel•ligència Artificial (IIIA-CSIC)
#
# Data from company extracted: Institut d’Investigació i Innovació Parc Taulí (I3PT)
# Data from company extracted: Institut d’Investigació i Recerca en Atenció Primària (IDIAP Jordi Gol)
# Data from company extracted: Institut d'Investigació Sanitària Pere Virgili (IISPV)
# Data from company extracted: Institut d'Investigacions Biomèdiques August Pi i Sunyer (IDIBAPS)
# Data from company extracted: Institut d'Investigacions Biomèdiques de Barcelona (IIBB)
# Data from company extracted: Institut Guttmann. Hospital de Neurorrehabilitació
# Data from company extracted: Institut Hospital del Mar d'Investigacions Mèdiques (IMIM)
# Data from company extracted: Institut Oncològic Baselga (IOB)
# Data from company extracted: Institut Químic de Sarrià (IQS)
# Data from company extracted: Institute of Environmental Assessment and Water Research (IDAEA-CSIC)
# Data from company extracted: Instituto de Dermatologia Ignacio Umbert
#
# ********************************** Potential issue in company: Instrumentation and Bioengineering Division of CREB-UPC
#
# Data from company extracted: Integra Therapeutics
# Data from company extracted: INTERmedic
#
# ********************************** Potential issue in company: International Team Consulting
#
# Data from company extracted: Internet i Innovació Digital a Catalunya (i2CAT)
# Data from company extracted: Interpharma
# Data from company extracted: Interquim (HQ, Sant Cugat del Valles)
# Data from company extracted: Invacare
# Data from company extracted: Invelon Technologies
# Data from company extracted: Inveniam Group
#
# ********************************** Potential issue in company: Invent Farma
#
#
# ********************************** Potential issue in company: Inveready Capital Company
#
# Data from company extracted: INVESA
# Data from company extracted: Invintia
# Data from company extracted: Invivo Ventures
# Data from company extracted: Iomed Medical Solutions
# Data from company extracted: IP Triana
# Data from company extracted: IPB Consulting
# Data from company extracted: Ipsen Pharma
# Data from company extracted: IQVIA
# Data from company extracted: Irideon
# Data from company extracted: iSalud
# Data from company extracted: iSalus
# Data from company extracted: Isdin
# Data from company extracted: Isensi
# Data from company extracted: ISERN Medical Telecom
# Data from company extracted: Isoquimen
# Data from company extracted: Isotope-Ratio Mass Spectrometry Laboratory (UAB)
# Data from company extracted: Itnig
#
# ********************************** Potential issue in company: IUCT Empren
#
# Data from company extracted: IUL
# Data from company extracted: iVascular
# Data from company extracted: IVFtech (Barcelona)
# Data from company extracted: Izasa Hospital
# Data from company extracted: Izasa Scientific
#
# ********************************** Potential issue in company: i2walk
#
# Data from company extracted: Jardemon
# Data from company extracted: JAUSAS
# Data from company extracted: JG Ingenieros
#
# ...
# Data from company extracted: Semillas Fitó
# Data from company extracted: SENER Ingeniería y Sistemas
# Data from company extracted: SeniorDomo
# Data from company extracted: Senolytic Therapeutics
# Data from company extracted: Sens Solutions
# Data from company extracted: Sense4care
# Data from company extracted: Sensing &amp; Control
# Data from company extracted: Sensofar Medical
# Data from company extracted: Sepmag
# Data from company extracted: Sepsia Therapeutics
# Data from company extracted: Seqera Labs
# Data from company extracted: Sequentia Biotech
# Data from company extracted: Seritech Europe
# Data from company extracted: Sermes CRO
# Data from company extracted: Servei d'Anàlisi Elemental i per Espectroscòpia NIR (UdL)
# Data from company extracted: Servei d'Anàlisi Química (UAB)
#
# ********************************** Potential issue in company: Servei d'Anàlisi Sensorial i Físico-Química d'Aliments (UDL)
#
# Data from company extracted: Servei d'Assaig en Planta Pilot de Processament d'Aliments (UDL)
# Data from company extracted: Servei de Bioquímica Clínica Veterinària (UAB)
# Data from company extracted: Servei de Camps Experimentals (UB)
#
# ********************************** Potential issue in company: Servei de Citometria de Flux Separador (UDL)
#
# Data from company extracted: Servei de Cromatografia de Gasos i de Líquid-Líquid (UDL)
# Data from company extracted: Servei de Cultius Cel·lulars, Producció d'Anticossos i Citometria (UAB)
# Data from company extracted: Servei de Cultius Cel·lulars (UB)
# Data from company extracted: Servei de Desenvolupament del Medicament (SDM)
# Data from company extracted: Servei de Desenvolupament i Aplicació de Tècniques Cromatogràfiques i d'Espectrometria de Masses (UDL)
#
# ********************************** Potential issue in company: Servei de Fermentació (UB)
#
#
# ********************************** Potential issue in company: Servei de Genòmica Bioinformàtica (UAB)
#
# Data from company extracted: Servei de Granges i Camps Experimentals (UAB)
# Data from company extracted: Servei de Malherbologia i Botànica Agroforestal (UDL)
# Data from company extracted: Servei de Microscòpia electrònica (UDL)
# Data from company extracted: Servei de Microscòpia, Morfometria i Microfluorimetria (UDL)
# Data from company extracted: Servei de Microscòpia (UAB)
#
# ********************************** Potential issue in company: Servei de Proteòmica i Biologia Estructural (UAB)
#
# Data from company extracted: Servei de Proteòmica i Genòmica (UDL)
# Data from company extracted: Servei de Qualitat Microbiològica en el Sector Agroalimentari (UDL)
# Data from company extracted: Servei de Ressonància Magnètica Nuclear (UDL)
# Data from company extracted: Servei de Seqüenciació i Síntesi d'Àcids Nucleïcs (UAB)
# Data from company extracted: Servei d'Espectrofotometria UV-Vis / FT-IR (UDL)
#
# ********************************** Potential issue in company: Serveis Integrats de l'Animal de Laboratori (UAB)
#
# Data from company extracted: Service of Nuclear Magnetic Resonance- SERMN (UAB)
# Data from company extracted: Servocad Microtronics
# Data from company extracted: Sevibe Cells
# Data from company extracted: Sherplay
# Data from company extracted: Ship2B
# Data from company extracted: Sia Enginyers
# Data from company extracted: Sibelmed
# Data from company extracted: Siemens Healthineers
# Data from company extracted: Simpexfarma
# Data from company extracted: Sincrofarm
# Data from company extracted: Singularity Biomed
#
# ********************************** Potential issue in company: Sisemed
#
#
# ********************************** Potential issue in company: SiTec PharmaBio
#
#
# ********************************** Potential issue in company: Sixsenso
#
# Data from company extracted: Skilled Skin
# Data from company extracted: Skin Tech Pharma Group
# Data from company extracted: SkinTemp
# Data from company extracted: SM Genomics
# Data from company extracted: Smart MedTech Platform (SMTP)
# Data from company extracted: SmartSalus
# Data from company extracted: Smiletronix
# Data from company extracted: Smith &amp; Nephew
# Data from company extracted: Smiths Medical España
# Data from company extracted: Social Diabetes
# Data from company extracted: Societat Catalana de Biotecnologia Mèdica
# Data from company extracted: Societat Catalana d’Immunologia
#
# ********************************** Potential issue in company: Solitek
#
# Data from company extracted: Solutia Global Health Solutions
# Data from company extracted: SOM Biotech
# Data from company extracted: Sonicat Systems
#
# ********************************** Potential issue in company: Sorin Group España
#
# Data from company extracted: Southern European Cluster in Photonics and Optics (SECPHO)
# Data from company extracted: SP Química
# Data from company extracted: SP Veterinaria
# Data from company extracted: SPCEN Invest XXI
# Data from company extracted: Special Chemicals
#
# ********************************** Potential issue in company: Specific Pig (SPECIPIG)
#
# Data from company extracted: Sphera Global Health
# Data from company extracted: Spinreact
# Data from company extracted: Spiral Therapeutics
# Data from company extracted: Splice Bio (HQ, Barcelona)
# Data from company extracted: Stacks
# Data from company extracted: Stada
# Data from company extracted: Stalicla (Barcelona)
# Data from company extracted: Stallergenes Iberica
#
# ********************************** Potential issue in company: STANGEST
#
#
# ********************************** Potential issue in company: Starlab
#
# Data from company extracted: Status EMA Partners Spain
# Data from company extracted: STE Pharma Systems
# Data from company extracted: Stimulo
#
# ********************************** Potential issue in company: Suan Farma
#
# Data from company extracted: Suanity
# Data from company extracted: SUCCIPRO
#
# ********************************** Potential issue in company: Sunstar Iberia
#
# Data from company extracted: Super's Diana
# Data from company extracted: SurgiTrainer
# Data from company extracted: Suvoda (Barcelona)
# Data from company extracted: Swan Medical
# Data from company extracted: SWEANTY
# Data from company extracted: Sycai Medical
# Data from company extracted: Sylvius
# Data from company extracted: Syna Therapeutics
#
# ********************************** Potential issue in company: Synapse Research Management Partners
#
# Data from company extracted: Synchrotron Light facility ALBA (CELLS)
# Data from company extracted: Syneos Health Spain
# Data from company extracted: Synlab Barcelona
# Data from company extracted: SynteractHCR
# Data from company extracted: Synthon Hispania
# Data from company extracted: Sysmex España
# Data from company extracted: Systelab Technologies
# Data from company extracted: S4e Solutions Four Engineering BCN 2003
#
# ********************************** Potential issue in company: Tailor Surgery
#
# Data from company extracted: Tarbis Farma
# Data from company extracted: TAVIL
# Data from company extracted: TBIOM
#
# ********************************** Potential issue in company: TDV Compliance Technology
#
# Data from company extracted: Tecan Ibérica Instrumentación
#
# ********************************** Potential issue in company: TechnoSperm
#
# Data from company extracted: Tech4freedom
# Data from company extracted: Tech4Health Systems
# Data from company extracted: TECIL
# Data from company extracted: Tecnic
# Data from company extracted: Tecno Products
# Data from company extracted: TecnoCampus Mataró-Maresme (TCM)
# Data from company extracted: Tecno-med Ingenieros
# Data from company extracted: Teknics
# Data from company extracted: Teknokroma
# Data from company extracted: Teladoc Health (Barcelona)
# Data from company extracted: Telemedicine Clinic
# Data from company extracted: TELIC
# Data from company extracted: Telomere Therapeutics
# Data from company extracted: Tempack Packaging Solutions
# Data from company extracted: Tensormedical
# Data from company extracted: Terapme
# Data from company extracted: Terrats Medical
# Data from company extracted: Texpol
# Data from company extracted: Textil Elastico
# Data from company extracted: TFS - Trial Form Support
# Data from company extracted: The Binding Site
# Data from company extracted: The Blue Box (Tarragona)
# Data from company extracted: The Smart Lollipop
# Data from company extracted: ThePaperMill
# Data from company extracted: Theriva Biologics (Barcelona)
# Data from company extracted: Thermo Fisher Diagnostics
# Data from company extracted: Thrombotargets Europe
# Data from company extracted: Tic Salut Social
# Data from company extracted: Tillotts Pharma Spain
# Data from company extracted: Time is Brain
# Data from company extracted: Tiselab Soluciones GMP
# Data from company extracted: Top Doctors (HQ, Barcelona)
# Data from company extracted: Topcon España
# Data from company extracted: Total Planning
# Data from company extracted: Touchland
# Data from company extracted: Trackyourmed
# Data from company extracted: Tractivus
#
# ********************************** Potential issue in company: Tramontane Therapeutics
#
# Data from company extracted: Transgenic Animals Unit (UAB)
# Data from company extracted: Transmural Biotech
# Data from company extracted: Treat
# Data from company extracted: Treematernity
# Data from company extracted: Trialing
# Data from company extracted: Trifermed
# Data from company extracted: Trinitytek Pharma
#
# ********************************** Potential issue in company: Trinitytek Pharma
#
# Data from company extracted: TripMedic
# Data from company extracted: Tynax
#
# ********************************** Potential issue in company: UhDa Health (Universal Health Digital Access)
#
# Data from company extracted: Ultrasion
# Data from company extracted: UM&amp;Asociados
# Data from company extracted: Unipharma
# Data from company extracted: Unit of Experimental Toxicology and Ecotoxicology (UTOX-PCB)
# Data from company extracted: Unitat de Producció de Vectors Virals (UAB)
# Data from company extracted: Unitat d'Innovació UPF Business Shuttle (TTO)
# Data from company extracted: Unitat Tècnica de Protecció Radiològica (UAB)
#
# ********************************** Potential issue in company: Universal Doctor
#
# Data from company extracted: Universal Robots (Barcelona)
# Data from company extracted: Universitat Abat Oliba CEU
# Data from company extracted: Universitat Autònoma de Barcelona (UAB)
# Data from company extracted: Universitat de Barcelona (UB)
# Data from company extracted: Universitat de Girona (UdG)
# Data from company extracted: Universitat de Lleida (UdL)
# Data from company extracted: Universitat de Vic (UVic)
# Data from company extracted: Universitat Internacional de Catalunya (UIC)
# Data from company extracted: Universitat Oberta de Catalunya (UOC)
#
# ********************************** Potential issue in company: Universitat Politècnica de Catalunya (UPC)
#
# Data from company extracted: Universitat Pompeu Fabra (UPF)
# Data from company extracted: Universitat Ramon Llull (URL)
# Data from company extracted: Universitat Rovira i Virgili (URV)
# Data from company extracted: Upbizor
# Data from company extracted: UPF Ventures
# Data from company extracted: Uppermat
# Data from company extracted: Up2Smart
# Data from company extracted: Uquifa
# Data from company extracted: Urdí-Solé &amp; Associats
# Data from company extracted: Urgo Medical
# Data from company extracted: Uriach (HQ, Palau-solità i Plegamans)
# Data from company extracted: USMIMA (MOWOOT)
#
# ********************************** Potential issue in company: Vall d'Hebron Institut de Recerca (VHIR)
#
# Data from company extracted: Vall d'Hebron Institut d'Oncologia (VHIO)
# Data from company extracted: Van Loon Chemical lnnovations (VLCI)
# Data from company extracted: Vanir Health
# Data from company extracted: Vantum Corporate
# Data from company extracted: VB Devices
# Data from company extracted: VDMHEALTH
# Data from company extracted: Vecmedical Spain
#
# ********************************** Potential issue in company: Veeva Systems (Cornellà de Llobregat)
#
#
# ********************************** Potential issue in company: Vemedia Pharma Hispania
#
# Data from company extracted: Venair Ibérica
# Data from company extracted: VenPharma
#
# ********************************** Potential issue in company: Ventura Innovation
#
#
# ********************************** Potential issue in company: Ventura Medical Technologies
#
# Data from company extracted: VenturCap
# Data from company extracted: Venvirotech Biotechnology
#
# ********************************** Potential issue in company: Vergara Capital
#
#
# ********************************** Potential issue in company: Veristat (Barcelona)
#
# Data from company extracted: Verkami
# Data from company extracted: Vertex Technics
# Data from company extracted: Vesismin
# Data from company extracted: Veterinary laboratory for the diagnosis of infectious diseases (UAB)
# Data from company extracted: Vetgenomics
# Data from company extracted: Vifor Pharma España
# Data from company extracted: Vilardell Purtí
#
# ********************************** Potential issue in company: Vincer.ai
#
# Data from company extracted: Virbac
# Data from company extracted: ViReInstruments
#
# ********************************** Potential issue in company: VirMedEx
#
#
# ********************************** Potential issue in company: Virtual Bodyworks
#
# Data from company extracted: Visiometrics
# Data from company extracted: Visyon
# Data from company extracted: Vitaance
# Data from company extracted: Vitala Technologies
# Data from company extracted: Viuho
# Data from company extracted: VRPharma
# Data from company extracted: VWR International Eurolab
# Data from company extracted: Vytrus Biotech
# Data from company extracted: W. L. Gore y Asociados
# Data from company extracted: Waldemar Link España
#
# ********************************** Potential issue in company: Wayalia Care
#
#
# ********************************** Potential issue in company: WeAR Technologies
#
# Data from company extracted: Weelko
# Data from company extracted: WeFitter
# Data from company extracted: Wegapixel
# Data from company extracted: WellTech Treatment Management System
# Data from company extracted: Werfenlife (HQ, Hospitalet del llobregat)
#
# ********************************** Potential issue in company: WETRON (Barcelona)
#
# Data from company extracted: Wharton Cells (Barcelona)
# Data from company extracted: Whole Genix
# Data from company extracted: Widex Audífonos
# Data from company extracted: Witte y Sola
# Data from company extracted: Wolters Kluwer España
#
# ********************************** Potential issue in company: World Health Organization Regional Office for Europe (Barcelona)
#
# Data from company extracted: Xarxa de Referència en Biotecnologia de la Generalitat de Catalunya
# Data from company extracted: Xarxa d'Inversors Privats i Family Offices de l'IESE
# Data from company extracted: xenOPAT
# Data from company extracted: Xkelet EasyLife
# Data from company extracted: Xpeer Meded
# Data from company extracted: Ypsicon
# Data from company extracted: Ypsomed
# Data from company extracted: Ysios Capital Partners SGEIC
# Data from company extracted: Zabala Innovation Consulting
#
# ********************************** Potential issue in company: Zambon
#
#
# ********************************** Potential issue in company: ZBM Business Connect
#
# Data from company extracted: ZBM patents
# Data from company extracted: ZeCardio Therapeutics
# Data from company extracted: ZeClinics
#
# ********************************** Potential issue in company: Zentiva
#
#
# ********************************** Potential issue in company: Zeus Quimica
#
# Data from company extracted: Zimmer Biomet
# Data from company extracted: ZIP Solutions
# Data from company extracted: Zoetis Manufacturing and Research Spain
# Data from company extracted: Zolertia
# Data from company extracted: Zoundream
#
# ********************************** Potential issue in company: Zymvol
#
# Data from company extracted: Zyrcular Foods
# Data from company extracted: 3CL-Bio
# Data from company extracted: 3D Tech Omega Zeta
# Data from company extracted: 3Digital Factory
# Data from company extracted: 3D-Shaper Medical
# Data from company extracted: 3DVisiomedicavirtual
# Data from company extracted: 4 Clinical Trials (4ct)
# Data from company extracted: 4Doctors
# Data from company extracted: 8Wires

# %%
len(data) + len(potential_conflict_companies)
# Out:
# 1610

# %%
pd.DataFrame({"conflicts": potential_conflict_companies}).to_csv("conflicts.csv")
data.to_csv("biocat.csv")

# %%
not_finished = True
potential_conflict_companies = []
potential_conflict_indexes = []

time.sleep(1)
t = time.time()

while not_finished:
    try:
        html = driver.execute_script("return document.getElementsByTagName('html')[0].innerHTML")
        soup = BeautifulSoup(html, "html.parser")
        cards = soup.find_all(True, {"class": "card-container"})
        for i, card in enumerate(cards):
            try:
                item_df = pd.DataFrame([list(biocat_parser(card))], columns=columns)
                data = pd.concat([data, item_df], ignore_index=True)
                print(f"Data from company extracted: {item_df['company'].iloc[0]}")
            except:
                potential_conflict_indexes.append(i)
                potential_conflict_companies.append(f"{item_df['company'].iloc[0]}")
                print(f"\n********************************** Potential issue in company with index {i}: {item_df['company']}\n")
        driver.find_element_by_xpath('//button[text()="Next"]').click()
        time.sleep(1)
    except:
        not_finished = False

print(f"\n\nTiempo total: {time.time()-t:.2f} segundos")
# Out:
# Data from company extracted: AB Medica Group
# Data from company extracted: Abac Capital
# Data from company extracted: Abac Therapeutics
# Data from company extracted: Abamed Pharma
# Data from company extracted: AB-Biotics
# Data from company extracted: ABC Farma Internacional
# Data from company extracted: Abeona Health
# Data from company extracted: ABG Patentes
# Data from company extracted: Ability Pharma
# Data from company extracted: ABLE Human Motion
# Data from company extracted: Abzu
# Data from company extracted: Accelerate Diagnostics
# Data from company extracted: ACCIÓ Agència per a la competitivitat de l'empresa
#
# ********************************** Potential issue in company with index 13: 0    ACCIÓ Agència per a la competitivitat de l'emp...
# Name: company, dtype: object
#
# Data from company extracted: Accure Therapeutics
# Data from company extracted: ACEFE
# Data from company extracted: Acellera
# Data from company extracted: Actelion Pharmaceuticals España
# Data from company extracted: Acteon Medico-Dental Iberica
# Data from company extracted: Active Medical Disposable
# Data from company extracted: Active Venture Partners
# Data from company extracted: Acuidad
# Data from company extracted: Adacyte Therapeutics
# Data from company extracted: Adan Medical Innovation
# Data from company extracted: ADAPT Localization Services
# Data from company extracted: AdaptiveCity
#
# ********************************** Potential issue in company with index 6: 0    AdaptiveCity
# Name: company, dtype: object
#
# Data from company extracted: AddVANTE Economists &amp; Lawyers
# Data from company extracted: AddVANTE M&amp;A
# Data from company extracted: Adecco Medical &amp; Science
# Data from company extracted: Adelphi
# Data from company extracted: Adiccare
# Data from company extracted: Adiemed
# Data from company extracted: Adienne Spain
# Data from company extracted: ADKNOMA Health Research
# Data from company extracted: ADmit Therapeutics
# Data from company extracted: AdSalutem Institute
#
# ********************************** Potential issue in company with index 17: 0    AdSalutem Institute
# Name: company, dtype: object
#
# Data from company extracted: Advanced Accelerator Applications Iberica
# Data from company extracted: Advanced Digital Microscopy Core Facility (IRB)
# Data from company extracted: Advanced Light Microscopy Unit (CRG)
#
# ********************************** Potential issue in company with index 1: 0    Advanced Light Microscopy Unit (CRG)
# Name: company, dtype: object
#
#
# ********************************** Potential issue in company with index 2: 0    Advanced Light Microscopy Unit (CRG)
# Name: company, dtype: object
#
# Data from company extracted: AEC Partners
# Data from company extracted: Aelix Therapeutics
# Data from company extracted: Aeris Tecnologías Ambientales
#
# ********************************** Potential issue in company with index 6: 0    Aeris Tecnologías Ambientales
# Name: company, dtype: object
#
# Data from company extracted: Aether Tech
#
# ********************************** Potential issue in company with index 8: 0    Aether Tech
# Name: company, dtype: object
#
# Data from company extracted: Afferent Technologies
# Data from company extracted: Affirma Biotech
# Data from company extracted: Afinitica
#
# ********************************** Potential issue in company with index 12: 0    Afinitica
# Name: company, dtype: object
#
# Data from company extracted: Agència de Salut Pública de Catalunya (ASPCAT)
# Data from company extracted: Agència per a la Qualitat del Sistema Universitari de Catalunya (AQU)
# Data from company extracted: Agromillora Catalana
# Data from company extracted: Agrprojects
# Data from company extracted: Aguettant Ibérica
# Data from company extracted: Ahead Therapeutics
# Data from company extracted: Aimentia Healthtech
# Data from company extracted: Airmedical Products
# Data from company extracted: Airpharm
# Data from company extracted: AIS Channel
# Data from company extracted: Albajuna Therapeutics
# Data from company extracted: Alchemlife
# Data from company extracted: Alcon
# Data from company extracted: Alcura Health
#
# ********************************** Potential issue in company with index 7: 0    Alcura Health
# Name: company, dtype: object
#
# Data from company extracted: Aldo-Union
#
# ********************************** Potential issue in company with index 9: 0    Aldo-Union
# Name: company, dtype: object
#
# Data from company extracted: Alexion Pharma Spain
# Data from company extracted: Alfasigma
# Data from company extracted: Algaktiv
# Data from company extracted: Alifarm
# Data from company extracted: AliNyMA Alimentación Nutrición y Medio Ambiente
# Data from company extracted: Alira Health
# Data from company extracted: Allergeneat
# Data from company extracted: Allergy Therapheutics Iberica
# Data from company extracted: Allinone Healthpro
# Data from company extracted: Alma Medical Imaging
# Data from company extracted: Almirall (HQ, Barcelona)
# Data from company extracted: Almus Farmaceutica
# Data from company extracted: Alta Life Sciences
# Data from company extracted: Alta Medical Services
# Data from company extracted: Altaquimica
# Data from company extracted: Alteraid
# Data from company extracted: Alter-Entorn
#
# ********************************** Potential issue in company with index 7: 0    Alter-Entorn
# Name: company, dtype: object
#
# Data from company extracted: Amalfi Analytics
# Data from company extracted: Amapex
# Data from company extracted: Amaris Consulting &amp; Innovation
# Data from company extracted: Ambit BST (HQ, Barcelona)
# Data from company extracted: Amedyn Healthcare
# Data from company extracted: Amelia Virtual Care
# Data from company extracted: Amgen
# Data from company extracted: AMP biotech
# Data from company extracted: Anaconda BioMed
# Data from company extracted: Anagram-ESIC
# Data from company extracted: ANAIS medical
# Data from company extracted: Anapharm Bioanalytics
# Data from company extracted: Anaxomics
#
# ********************************** Potential issue in company with index 1: 0    Anaxomics
# Name: company, dtype: object
#
# Data from company extracted: Andersen
# Data from company extracted: Andrés Pintaluba
#
# ********************************** Potential issue in company with index 4: 0    Andrés Pintaluba
# Name: company, dtype: object
#
# Data from company extracted: Aniling
# Data from company extracted: Ànima Design
# Data from company extracted: Anota
#
# ********************************** Potential issue in company with index 8: 0    Anota
# Name: company, dtype: object
#
# Data from company extracted: AntibodyBCN (AbBcn)
# Data from company extracted: Antonio Matachana
# Data from company extracted: AON Therapeutics
# Data from company extracted: AOResearch
# Data from company extracted: Aortyx
# Data from company extracted: Apa Laboratoris Clínics
# Data from company extracted: Applied Nanoparticles
# Data from company extracted: Aptadel Therapeutics
# Data from company extracted: Aqualogy
#
# ********************************** Potential issue in company with index 18: 0    Aqualogy
# Name: company, dtype: object
#
# Data from company extracted: Aragogamma
# Data from company extracted: Arber Surgical
# Data from company extracted: Arboribus
#
# ********************************** Potential issue in company with index 2: 0    Arboribus
# Name: company, dtype: object
#
# Data from company extracted: Archivel Farma
# Data from company extracted: Arelsa
# Data from company extracted: Arian International Projects
# Data from company extracted: Aristos Innovation Consulting
# Data from company extracted: Aromics
# Data from company extracted: Arroba Capital
# Data from company extracted: Arvor Consulting
# Data from company extracted: Asabys Partners
# Data from company extracted: ASCIL Biopharm
# Data from company extracted: Asho
# Data from company extracted: Asociación Forum Auditorias (AFA)
#
# ********************************** Potential issue in company with index 14: 0    Asociación Forum Auditorias (AFA)
# Name: company, dtype: object
#
# Data from company extracted: Aspen Pharma Iberia
# Data from company extracted: Asphalion
# Data from company extracted: Assi Sistemes
# Data from company extracted: Associació Catalana d’Entitats de Recerca (ACER)
# Data from company extracted: Associació Catalana d'Universitats Públiques (ACUP)
# Data from company extracted: Astradentium Health Technologies
# Data from company extracted: AstraZeneca
# Data from company extracted: Ateknea Solutions Catalonia
# Data from company extracted: Atens
# Data from company extracted: AtG Therapeutics
# Data from company extracted: ATIC (Centre d'Avantguarda Tecnològica per la Innovació)
# Data from company extracted: Atomian
# Data from company extracted: Atos Medical Spain
# Data from company extracted: Atraura
# Data from company extracted: Atrys Health
# Data from company extracted: AttendBio Research
# Data from company extracted: AuditGMP Pharma
# Data from company extracted: Auditories Tècniques BCN
# Data from company extracted: Aureel
# Data from company extracted: Auren
# Data from company extracted: Aurocis (Nanotargeting)
# Data from company extracted: Automated Crystallography Platform (IBMB-CSIC)
# Data from company extracted: Avançsa
# Data from company extracted: Àvida Biotech
# Data from company extracted: Avinent Implant System
# Data from company extracted: Axeb Biotech
# Data from company extracted: AYO by Novalogy
# Data from company extracted: Azbil Telstar Technologies
# Data from company extracted: Azelis España
# Data from company extracted: Azierta
# Data from company extracted: B. Braun VetCare
# Data from company extracted: Bactabio
# Data from company extracted: Bacteralia
# Data from company extracted: Bagi Xarxa d'Àngels Inversors de Girona
# Data from company extracted: Baker &amp; Mckenzie
# Data from company extracted: Ball Head System
# Data from company extracted: Banc de Sang i Teixits (BST)
#
# ********************************** Potential issue in company with index 12: 0    Banc de Sang i Teixits (BST)
# Name: company, dtype: object
#
#
# ********************************** Potential issue in company with index 13: 0    Banc de Sang i Teixits (BST)
# Name: company, dtype: object
#
# Data from company extracted: Barcelona Advanced Industry Park (BAIP)
#
# ********************************** Potential issue in company with index 15: 0    Barcelona Advanced Industry Park (BAIP)
# Name: company, dtype: object
#
# Data from company extracted: Barcelona Graduate School of Economics (Barcelona GSE)
# Data from company extracted: Barcelona Innovation Partners
# Data from company extracted: Barcelona Institut Emprenedoria (BIE)
# Data from company extracted: Barcelona International Medical Academy (BIMA)
# Data from company extracted: Barcelona Liver Bioservices
# Data from company extracted: Barcelona Macula Foundation: Research for Vision (BMF)
# Data from company extracted: Barcelona Skin Genomics (BSG)
#
# ********************************** Potential issue in company with index 3: 0    Barcelona Skin Genomics (BSG)
# Name: company, dtype: object
#
# Data from company extracted: Barcelona Synchrotron Park (Parc de l'Alba)
# Data from company extracted: Barcelona Ventures
# Data from company extracted: BarcelonaBeta Brain Research Center (BBRC)
# Data from company extracted: Bard de España
# Data from company extracted: Bardehle Pagenberg
# Data from company extracted: BASF Española
# Data from company extracted: Batec Mobility
# Data from company extracted: Bax &amp; Willems Consulting Venturing
# Data from company extracted: Bayer Hispania
# Data from company extracted: B&amp;B Asesores
# Data from company extracted: BCN Business Angels
# Data from company extracted: BCN Farma
# Data from company extracted: BCN Health Economics &amp; Outcomes Research
# Data from company extracted: BCN Innova Technological Evolution
#
# ********************************** Potential issue in company with index 18: 0    BCN Innova Technological Evolution
# Name: company, dtype: object
#
# Data from company extracted: BCN3D Technologies
# Data from company extracted: BDcare
# Data from company extracted: Beauty Cluster Barcelona
# Data from company extracted: Beckman Coulter
# Data from company extracted: Bellavista Legal
#
# ********************************** Potential issue in company with index 4: 0    Bellavista Legal
# Name: company, dtype: object
#
# Data from company extracted: Berdac
# Data from company extracted: Bertrandt (Barcelona)
#
# ********************************** Potential issue in company with index 7: 0    Bertrandt (Barcelona)
# Name: company, dtype: object
#
# Data from company extracted: Better Care
# Data from company extracted: BHV Partners
# Data from company extracted: Bicosome
# Data from company extracted: bIDEA Avant
# Data from company extracted: Biel Glasses
# Data from company extracted: Bien Air España
# Data from company extracted: Bimedica
# Data from company extracted: Bioaccez Controls
# Data from company extracted: Biobank (HUB-ICO-IDIBELL)
# Data from company extracted: Biobank (IDIBAPS)
# Data from company extracted: BIOBIZ Strategy &amp; Communications
# Data from company extracted: Biocat
# Data from company extracted: Biochemize
# Data from company extracted: BioClever
# Data from company extracted: BioCloud
# Data from company extracted: BIOcomuniCA'T
# Data from company extracted: Biocontrol Technologies
# Data from company extracted: Biocosmetica Exel
# Data from company extracted: BioEclosion
#
# ********************************** Potential issue in company with index 7: 0    BioEclosion
# Name: company, dtype: object
#
#
# ********************************** Potential issue in company with index 8: 0    BioEclosion
# Name: company, dtype: object
#
# Data from company extracted: Bioibérica (HQ, Barcelona)
# Data from company extracted: Bioinfogate
#
# ********************************** Potential issue in company with index 11: 0    Bioinfogate
# Name: company, dtype: object
#
#
# ********************************** Potential issue in company with index 12: 0    Bioinfogate
# Name: company, dtype: object
#
# Data from company extracted: Bioinformatics Unit (CRG)
# Data from company extracted: Bioingenium
# Data from company extracted: Bioinnove
# Data from company extracted: Biointaxis
# Data from company extracted: Biomedical Logistics
#
# ********************************** Potential issue in company with index 18: 0    Biomedical Logistics
# Name: company, dtype: object
#
# Data from company extracted: Bioner
# Data from company extracted: Bioo
# Data from company extracted: Biopharma Synergies (BPS)
# Data from company extracted: Bioprognos
# Data from company extracted: Bioquim
# Data from company extracted: Bio-Rad Laboratories
# Data from company extracted: BioSeed Capital
# Data from company extracted: Biosfer Teslab
# Data from company extracted: Biosystems
# Data from company extracted: BIOTAP
# Data from company extracted: Biotech Tricopharming Research
# Data from company extracted: Biotechnology Business Institute (BBI)
# Data from company extracted: Biotronik
# Data from company extracted: Biovert
# Data from company extracted: Biovet
# Data from company extracted: Biprocel
# Data from company extracted: Bitac
#
# ********************************** Potential issue in company with index 16: 0    Bitac
# Name: company, dtype: object
#
# Data from company extracted: Biwel
# Data from company extracted: Blanca
# Data from company extracted: Blistersuit
# Data from company extracted: BloodGenetics
# Data from company extracted: Blueberry Diagnostics (BCN)
# Data from company extracted: Bluephage
# Data from company extracted: Boehringer Ingelheim Animal Health
# Data from company extracted: Boehringer Ingelheim España
# Data from company extracted: Bolsaplast
# Data from company extracted: Bonoom
# Data from company extracted: Boston Scientific Barcelona
# Data from company extracted: Brain Health Solutions
#
# ********************************** Potential issue in company with index 9: 0    Brain Health Solutions
# Name: company, dtype: object
#
# Data from company extracted: Braingaze
# Data from company extracted: BRASCAT
# Data from company extracted: Brave Lifescience
# Data from company extracted: Breaz Medical
# Data from company extracted: BrickBio
# Data from company extracted: Brill Pharma
# Data from company extracted: Broomx
# Data from company extracted: Brudy Technology
# Data from company extracted: Brugués
# Data from company extracted: BSN Medical
# Data from company extracted: Bsure Medical (HQ, Cornellà de Llobregat)
# Data from company extracted: b_TEC Barcelona Innovació Tecnològica
# Data from company extracted: BTHT
#
# ********************************** Potential issue in company with index 3: 0    BTHT
# Name: company, dtype: object
#
# Data from company extracted: Butler Scientifics
#
# ********************************** Potential issue in company with index 5: 0    Butler Scientifics
# Name: company, dtype: object
#
# Data from company extracted: B'ZEOS
#
# ********************************** Potential issue in company with index 7: 0    B'ZEOS
# Name: company, dtype: object
#
# Data from company extracted: Cafosa Gum
# Data from company extracted: Caixa Capital Risc
# Data from company extracted: Cannabity Healthcare
# Data from company extracted: Capenergy Medical
#
# ********************************** Potential issue in company with index 12: 0    Capenergy Medical
# Name: company, dtype: object
#
# Data from company extracted: Cardiolink
#
# ********************************** Potential issue in company with index 14: 0    Cardiolink
# Name: company, dtype: object
#
# Data from company extracted: Cardiosafe
# Data from company extracted: CardioSOS
# Data from company extracted: Cardiumm
# Data from company extracted: Care Respite
# Data from company extracted: CataloniaBio &amp; HealthTech
# Data from company extracted: Catlab
# Data from company extracted: CDClinic
# Data from company extracted: Cebiotex
# Data from company extracted: Cellab
# Data from company extracted: Celltec UB
# Data from company extracted: Cenavisa
#
# ********************************** Potential issue in company with index 6: 0    Cenavisa
# Name: company, dtype: object
#
# Data from company extracted: Centre de Desenvolupaments Biotecnològics i Agroalimentaris (DBA)
# Data from company extracted: Centre de Medicina Comparativa i bioimatge de Catalunya (CMCiB)
#
# ********************************** Potential issue in company with index 9: 0    Centre de Medicina Comparativa i bioimatge de ...
# Name: company, dtype: object
#
# Data from company extracted: Centre de Recerca de Nanoenginyeria (CRNE)
# Data from company extracted: Centre de Recerca en Agrigenòmica (CRAG)
# Data from company extracted: Centre de Recerca en Agrotecnologia (Agrotecnio)
# Data from company extracted: Centre de Recerca en Enginyeria Biomèdica (CREB-UPC)
#
# ********************************** Potential issue in company with index 14: 0    Centre de Recerca en Enginyeria Biomèdica (CRE...
# Name: company, dtype: object
#
# Data from company extracted: Centre de Recerca en Sanitat Animal (CRESA)
#
# ********************************** Potential issue in company with index 16: 0    Centre de Recerca en Sanitat Animal (CRESA)
# Name: company, dtype: object
#
#
# ********************************** Potential issue in company with index 17: 0    Centre de Recerca en Sanitat Animal (CRESA)
# Name: company, dtype: object
#
# Data from company extracted: Centre de Recerca Matemàtica (CRM)
# Data from company extracted: Centre de Referència en Biotecnologia (CERBA)
# Data from company extracted: Centre de Regulació Genòmica (CRG)
#
# ********************************** Potential issue in company with index 1: 0    Centre de Regulació Genòmica (CRG)
# Name: company, dtype: object
#
#
# ********************************** Potential issue in company with index 2: 0    Centre de Regulació Genòmica (CRG)
# Name: company, dtype: object
#
#
# ********************************** Potential issue in company with index 3: 0    Centre de Regulació Genòmica (CRG)
# Name: company, dtype: object
#
# Data from company extracted: Centre de Transferència del Coneixement i Valorització de la Recerca de la Universitat Internacional de Catalunya (TTO)
# Data from company extracted: Centre de Visió per Computador (CVC)
# Data from company extracted: Centre d’Estudis de Ciència, Comunicació i Societat de la Universitat Pompeu Fabra (CCS-UPF)
# Data from company extracted: Centre d'Estudis Demogràfics (CED)
# Data from company extracted: Centre d'Estudis Sanitaris i Socials (CESS)
# Data from company extracted: Centre Especial de Recerca Planta de Tecnologia dels Aliments (CERPTA)
# Data from company extracted: Centre for Omic Sciences (COS)
#
# ********************************** Potential issue in company with index 11: 0    Centre for Omic Sciences (COS)
# Name: company, dtype: object
#
# Data from company extracted: Centre Nacional d'Anàlisi Genòmica (CNAG)
#
# ********************************** Potential issue in company with index 13: 0    Centre Nacional d'Anàlisi Genòmica (CNAG)
# Name: company, dtype: object
#
# Data from company extracted: Centro de Estudios Superiores de la Industria Farmacéutica (CESIF)
# Data from company extracted: Centro Médico Teknon
# Data from company extracted: Ceramtec Ibérica
# Data from company extracted: Cercle Tecnològic de Catalunya
# Data from company extracted: Cetir Grup Mèdic
# Data from company extracted: Ceva Salud Animal
# Data from company extracted: CEX Internacional
# Data from company extracted: CG Health Ventures
# Data from company extracted: Change Dyslexia
# Data from company extracted: Charles River Laboratories España
# Data from company extracted: Chasing Science
# Data from company extracted: Chemgineering (Barcelona)
# Data from company extracted: Chemo Iberica
# Data from company extracted: Chemotargets
#
# ********************************** Potential issue in company with index 8: 0    Chemotargets
# Name: company, dtype: object
#
# Data from company extracted: Chiesi España
# Data from company extracted: CIDQO
# Data from company extracted: Ciència i Recerca Experimental Biomèdica Aplicada (CREBA)
# Data from company extracted: CIMAB (Centro de Infertilidad Masculina y Análisis de Barcelona)
# Data from company extracted: Cimer
# Data from company extracted: Cinta-Plast
# Data from company extracted: Cirex Consulting
# Data from company extracted: CITA.iO
# Data from company extracted: Clarivate Analytics (Barcelona)
# Data from company extracted: Clarke, Modet y Companyía
# Data from company extracted: Clementine Global
# Data from company extracted: Click Doctors
# Data from company extracted: Clinic Point
# Data from company extracted: Clinica Eugin
# Data from company extracted: Clinical Document Engineering
#
# ********************************** Potential issue in company with index 4: 0    Clinical Document Engineering
# Name: company, dtype: object
#
# Data from company extracted: CLINOBS
# Data from company extracted: ClinTec International
#
# ********************************** Potential issue in company with index 7: 0    ClinTec International
# Name: company, dtype: object
#
#
# ********************************** Potential issue in company with index 8: 0    ClinTec International
# Name: company, dtype: object
#
# Data from company extracted: Clúster Digital
# Data from company extracted: CN Logistica
# Data from company extracted: Cobapharma
# Data from company extracted: Col·legi Oficial de Metges de Barcelona (COMB)
# Data from company extracted: ColorSensing
#
# ********************************** Potential issue in company with index 14: 0    ColorSensing
# Name: company, dtype: object
#
# Data from company extracted: Combinatorial Chemistry Unit (UQC-PCB)
#
# ********************************** Potential issue in company with index 16: 0    Combinatorial Chemistry Unit (UQC-PCB)
# Name: company, dtype: object
#
# Data from company extracted: Complife Group (Barcelona)
# Data from company extracted: Comser Pharma
# Data from company extracted: Connecta Therapeutics
#
# ********************************** Potential issue in company with index 0: 0    Connecta Therapeutics
# Name: company, dtype: object
#
# Data from company extracted: ConnecThink
#
# ********************************** Potential issue in company with index 2: 0    ConnecThink
# Name: company, dtype: object
#
# Data from company extracted: Consorci Hospitalari de Vic (CHV)
# Data from company extracted: Consorci Sanitari de Terrassa (CST)
# Data from company extracted: Consulpi
# Data from company extracted: Control Live
# Data from company extracted: Convatec
# Data from company extracted: Cook España
#
# ********************************** Potential issue in company with index 9: 0    Cook España
# Name: company, dtype: object
#
# Data from company extracted: Cornea Project
# Data from company extracted: Coronis Computing
# Data from company extracted: Corus Dental
#
# ********************************** Potential issue in company with index 13: 0    Corus Dental
# Name: company, dtype: object
#
# Data from company extracted: COSINGO - Imagine Optic Spain
# Data from company extracted: Costaisa
# Data from company extracted: Cotecnica
# Data from company extracted: Coyma
# Data from company extracted: CPQ Ingenieros
# Data from company extracted: Crea Inversión
# Data from company extracted: CRISA RX
# Data from company extracted: Crisalix
#
# ********************************** Potential issue in company with index 2: 0    Crisalix
# Name: company, dtype: object
#
# Data from company extracted: Crowdcube
#
# ********************************** Potential issue in company with index 4: 0    Crowdcube
# Name: company, dtype: object
#
# Data from company extracted: CSV Experts
# Data from company extracted: Cuantum Medical Cosmetics
# Data from company extracted: Cuatrecasas
# Data from company extracted: Cube Technology Innovation
# Data from company extracted: Cuideo
# Data from company extracted: Cuore Care
# Data from company extracted: Curell Suñol
# Data from company extracted: CV Medica
# Data from company extracted: Cygyc
# Data from company extracted: Cytes Biotechnologies
# Data from company extracted: Cytometry and Cell Sorting Facility (IDIBAPS)
# Data from company extracted: Cytomics Unit (IDIBELL)
# Data from company extracted: Daiprox
# Data from company extracted: Dallant
# Data from company extracted: Dana (A thousand colibris)
# Data from company extracted: Danagen
# Data from company extracted: DAN*NA Artificial Nature
# Data from company extracted: Dara Pharma
# Data from company extracted: DBGen Ocular Genomics
#
# ********************************** Potential issue in company with index 4: 0    DBGen Ocular Genomics
# Name: company, dtype: object
#
#
# ********************************** Potential issue in company with index 5: 0    DBGen Ocular Genomics
# Name: company, dtype: object
#
# Data from company extracted: DDBIOLAB
# Data from company extracted: De Dietrich Equipos Químicos
# Data from company extracted: DeepUll
# Data from company extracted: Deloitte Barcelona
# Data from company extracted: Deltalab
# Data from company extracted: Dentaid
# Data from company extracted: Dentsply Implants
#
# ********************************** Potential issue in company with index 13: 0    Dentsply Implants
# Name: company, dtype: object
#
# Data from company extracted: Deretil Agronutritional
# Data from company extracted: Dermavision Solutions
# Data from company extracted: Dermofarm
# Data from company extracted: Devicare
#
# ********************************** Potential issue in company with index 18: 0    Devicare
# Name: company, dtype: object
#
# Data from company extracted: Devsynthesis (Barcelona)
# Data from company extracted: Dextro Medica (HQ,Sant Cugat del Valles)
# Data from company extracted: Diagnóstica Stago
#
# ********************************** Potential issue in company with index 2: 0    Diagnóstica Stago
# Name: company, dtype: object
#
# Data from company extracted: DICOMOL
# Data from company extracted: Dictyapharma
# Data from company extracted: Dicus
# Data from company extracted: Diet Creator
# Data from company extracted: Dietary Molecular Diagnostics
# Data from company extracted: Dietox
# Data from company extracted: Digimevo
#
# ********************************** Potential issue in company with index 10: 0    Digimevo
# Name: company, dtype: object
#
# Data from company extracted: Dinbeat
# Data from company extracted: Disproquima
# Data from company extracted: Ditec Medical
# Data from company extracted: Divasa-Farmavic (DFV)
# Data from company extracted: DJO Ibérica
# Data from company extracted: DK Diagnostics EMEA
# Data from company extracted: DNANutricoach
# Data from company extracted: Doctivi
#
# ********************************** Potential issue in company with index 19: 0    Doctivi
# Name: company, dtype: object
#
# Data from company extracted: Doctoralia
# Data from company extracted: Doctuo
# Data from company extracted: Doctux Mhealth Services
# Data from company extracted: Docuchem
# Data from company extracted: Dominion
# Data from company extracted: DOMMA
# Data from company extracted: Dompé Farmaceutici España
# Data from company extracted: Doole Health
# Data from company extracted: Dosis Health
#
# ********************************** Potential issue in company with index 9: 0    Dosis Health
# Name: company, dtype: object
#
# Data from company extracted: DRACO SYSTEMS
# Data from company extracted: Draconis Pharma
# Data from company extracted: Dribia Data Research
# Data from company extracted: Dromex International
# Data from company extracted: Drug Development and Regulation (DDR)
# Data from company extracted: Dryox Health
# Data from company extracted: DSM Sinochem Pharmaceuticals Spain
# Data from company extracted: Duke Chem
# Data from company extracted: Durcal
# Data from company extracted: Durr Dental Medics Iberica
# Data from company extracted: DVD Dental
# Data from company extracted: Dycare (Dynamic Care Solutions)
# Data from company extracted: Dynamic Abutment Solutions
# Data from company extracted: eCareYou Innovation
# Data from company extracted: Ecobium Biotech
# Data from company extracted: Ecoceutics
# Data from company extracted: Ecogen
# Data from company extracted: Economistes BAN (Col·legi d'economistes de Catalunya)
# Data from company extracted: Econtrol Assessors y Consultors
# Data from company extracted: Ecopol Tech
#
# ********************************** Potential issue in company with index 10: 0    Ecopol Tech
# Name: company, dtype: object
#
# Data from company extracted: Efarmes
#
# ********************************** Potential issue in company with index 12: 0    Efarmes
# Name: company, dtype: object
#
# Data from company extracted: Efron Consulting
# Data from company extracted: EG Active Cosmetics
# Data from company extracted: eHealthAI
# Data from company extracted: Eignapharma
# Data from company extracted: EIT Health Spain (Barcelona)
# Data from company extracted: Eix Technova Barcelona
# Data from company extracted: El Coco
# Data from company extracted: Elausa
# Data from company extracted: Electro AD
# Data from company extracted: Electrolomas
# Data from company extracted: Elem Biotech
# Data from company extracted: Elix Polymers
# Data from company extracted: EMA
# Data from company extracted: Embryotools
#
# ********************************** Potential issue in company with index 7: 0    Embryotools
# Name: company, dtype: object
#
# Data from company extracted: EMLIFE
# Data from company extracted: Enantia
# Data from company extracted: ENDOASIC Technologies
# Data from company extracted: Endolipid Therapeutics
# Data from company extracted: Endor Nanotechnologies
# Data from company extracted: Enerbio
# Data from company extracted: Energy for Business
# Data from company extracted: Enext engineers and contractors
# Data from company extracted: EngiCom
# Data from company extracted: Engidi
# Data from company extracted: Enginy Biorem
# Data from company extracted: Ensis Sciences
#
# ********************************** Potential issue in company with index 0: 0    Ensis Sciences
# Name: company, dtype: object
#
# Data from company extracted: Envigo
# Data from company extracted: Enzyme Advising Group
# Data from company extracted: Eodyne Systems
# Data from company extracted: Eolo
# Data from company extracted: EoxSense
#
# ********************************** Potential issue in company with index 6: 0    EoxSense
# Name: company, dtype: object
#
# Data from company extracted: Eprodics
# Data from company extracted: EQ Esteve
# Data from company extracted: Ercros
# Data from company extracted: Ernst &amp; Young (EY) Barcelona
# Data from company extracted: ESADE
# Data from company extracted: ESADE BAN
# Data from company extracted: Esade Creapolis
# Data from company extracted: ESAME
# Data from company extracted: Escuela de Alta Dirección y Administración (EADA)
# Data from company extracted: Especialidades Medicas MYR
# Data from company extracted: Essilor
#
# ********************************** Potential issue in company with index 18: 0    Essilor
# Name: company, dtype: object
#
# Data from company extracted: Esteve
# Data from company extracted: Esteve-Teijin Healthcare
# Data from company extracted: EstimTrack
# Data from company extracted: eSTRATELIS
# Data from company extracted: Eurecat
# Data from company extracted: Eurofins BioPharma
# Data from company extracted: EUROGINE
# Data from company extracted: Eurohold
# Data from company extracted: Euroklee
# Data from company extracted: Euromed
# Data from company extracted: European Quality Assurance Spain (EQA)
# Data from company extracted: EVERAI Medical Technologies
# Data from company extracted: Everest, Tecnología Veterinaria y Médica
# Data from company extracted: Evic Hispania (Centro Experimental de Evaluación Cutánea)
# Data from company extracted: Evolutive Medica
# Data from company extracted: Excelera
# Data from company extracted: Exheus
# Data from company extracted: Expert Ymaging
# Data from company extracted: Family Synergy
# Data from company extracted: Farmaban
# Data from company extracted: Farmaconfianza
# Data from company extracted: Farmantra
# Data from company extracted: Farmaprojects
# Data from company extracted: Fatro Iberica
# Data from company extracted: Faus &amp; Moliner Advocats
# Data from company extracted: Federació Europea de Malalties Minoritàries (Eurordis)
# Data from company extracted: Fermentation Pilot Plant (UAB)
# Data from company extracted: Ferrer (HQ, Barcelona)
#
# ********************************** Potential issue in company with index 7: 0    Ferrer (HQ, Barcelona)
# Name: company, dtype: object
#
# Data from company extracted: Fisiovirtual
# Data from company extracted: Fitomón
# Data from company extracted: Flexor
# Data from company extracted: Flomics Biotech
# Data from company extracted: Flow Citometry (UPF)
# Data from company extracted: Flubetech
# Data from company extracted: Forbaker
# Data from company extracted: Formas Naturales
#
# ********************************** Potential issue in company with index 16: 0    Formas Naturales
# Name: company, dtype: object
#
# Data from company extracted: Forté Pharma
# Data from company extracted: Founder Institute
# Data from company extracted: FractalMed
# Data from company extracted: FreeOx Biotech
# Data from company extracted: Fresco International
# Data from company extracted: Fresco Podologia
# Data from company extracted: Fresenius Kabi España
# Data from company extracted: FrontWave Imaging
# Data from company extracted: Fuelfor
# Data from company extracted: Fuelium
# Data from company extracted: Fujirebio Iberia
# Data from company extracted: Funbrain
# Data from company extracted: Functional Genomics (IDIBAPS)
#
# ********************************** Potential issue in company with index 10: 0    Functional Genomics (IDIBAPS)
# Name: company, dtype: object
#
# Data from company extracted: Fundació Bosch i Gimpera FBG (TTO)
# Data from company extracted: Fundació CIM
# Data from company extracted: Fundació Clínic per a la Recerca Biomèdica (FCRB)
# Data from company extracted: Fundació Dr. Antoni Esteve
#
# ********************************** Potential issue in company with index 15: 0    Fundació Dr. Antoni Esteve
# Name: company, dtype: object
#
# Data from company extracted: Fundació DTI-Donation &amp; Transplantation Institute
# Data from company extracted: Fundació GAEM
# Data from company extracted: Fundació Garcia Cugat
# Data from company extracted: Fundació Hospital Asil de Granollers
#
# ********************************** Potential issue in company with index 0: 0    Fundació Hospital Asil de Granollers
# Name: company, dtype: object
#
# Data from company extracted: Fundació Oncològica de Catalunya (FOC)
# Data from company extracted: Fundació Pasqual Maragall per a la recerca sobre l’Alzheimer (FPM)
# Data from company extracted: Fundació per a la Investigació Nutricional (FIN)
# Data from company extracted: Fundació Puigvert
# Data from company extracted: Fundació The Barcelona Institute of Science and Technology (BIST)
# Data from company extracted: Fundación iSYS
# Data from company extracted: Fundación Step by Step
# Data from company extracted: Future Companies Partners
# Data from company extracted: Futureco Bioscience
# Data from company extracted: GAES Medica
# Data from company extracted: Gain Therapeutics (Barcelona)
# Data from company extracted: GalChimia
# Data from company extracted: Galenicum
# Data from company extracted: Galgo Medical
# Data from company extracted: Garrigues
# Data from company extracted: Gases Research Innovation and Technology (GRIT)
# Data from company extracted: Gasinox
# Data from company extracted: Gat Biosciences
# Data from company extracted: Gat Therapeutics
# Data from company extracted: Gate2Brain
# Data from company extracted: GE Healthcare
#
# ********************************** Potential issue in company with index 2: 0    GE Healthcare
# Name: company, dtype: object
#
# Data from company extracted: Gebro Pharma
# Data from company extracted: Gedeon Richter Iberica
# Data from company extracted: Gen Incode (Terrassa, Barcelona)
# Data from company extracted: GENESIS Biomed
#
# ********************************** Potential issue in company with index 7: 0    GENESIS Biomed
# Name: company, dtype: object
#
# Data from company extracted: Genomics Unit (IDIBELL)
# Data from company extracted: Gentec
# Data from company extracted: Gesaworld
#
# ********************************** Potential issue in company with index 11: 0    Gesaworld
# Name: company, dtype: object
#
# Data from company extracted: Gil Roda Medical writing
# Data from company extracted: Gisek Diagnostic Thermography
#
# ********************************** Potential issue in company with index 14: 0    Gisek Diagnostic Thermography
# Name: company, dtype: object
#
# Data from company extracted: Glifing
# Data from company extracted: GlobaCare Clinical trials
# Data from company extracted: Global Sensory
# Data from company extracted: GLOBMOD
#
# ********************************** Potential issue in company with index 19: 0    GLOBMOD
# Name: company, dtype: object
#
# Data from company extracted: GlyCardial Diagnostics
# Data from company extracted: GMI Ilerimplant Group
# Data from company extracted: Goo Apps
# Data from company extracted: Goo Medical
# Data from company extracted: Goodgrower
# Data from company extracted: GoodGut
# Data from company extracted: GP Pharm
# Data from company extracted: GPA Medical
# Data from company extracted: GraphenicaLab
#
# ********************************** Potential issue in company with index 9: 0    GraphenicaLab
# Name: company, dtype: object
#
# Data from company extracted: Greenaltech
# Data from company extracted: Grifols Engineering
# Data from company extracted: Grifols (HQ, Sant Cugat del Valles)
# Data from company extracted: Groenlandia Tech
# Data from company extracted: Grow Venture Partners
# Data from company extracted: Growup Services
# Data from company extracted: Grup Maculart
# Data from company extracted: Grup SAGESSA
# Data from company extracted: Grupo B. Braun España
# Data from company extracted: Grupo Menarini España
# Data from company extracted: Grupo Pulso
# Data from company extracted: g.tec medical engineering Spain
# Data from company extracted: Gutmar
# Data from company extracted: GxMed Healthcare
# Data from company extracted: Gyala Therapeutics
# Data from company extracted: Gym For Less
# Data from company extracted: HallTech
# Data from company extracted: Hamamatsu Photonics
# Data from company extracted: Hans e Ruth
# Data from company extracted: Hartington Pharmaceuticals (HQ)
# Data from company extracted: Hartmann España
#
# ********************************** Potential issue in company with index 11: 0    Hartmann España
# Name: company, dtype: object
#
# Data from company extracted: Health Innovation Technology Transfer (HITT)
# Data from company extracted: Health Market Research (HMR) - Barcelona
# Data from company extracted: Healthapp
#
# ********************************** Potential issue in company with index 15: 0    Healthapp
# Name: company, dtype: object
#
#
# ********************************** Potential issue in company with index 16: 0    Healthapp
# Name: company, dtype: object
#
# Data from company extracted: HealthQuay
# Data from company extracted: Health&amp;sportlab
#
# ********************************** Potential issue in company with index 19: 0    Health&amp;sportlab
# Name: company, dtype: object
#
# Data from company extracted: Hemophotonics
# Data from company extracted: Hemostatics Pharmaceuticals
# Data from company extracted: Herrero y Asociados
# Data from company extracted: Hesoft Group
# Data from company extracted: Hexacath España
# Data from company extracted: HHP Spain
#
# ********************************** Potential issue in company with index 6: 0    HHP Spain
# Name: company, dtype: object
#
# Data from company extracted: Higiatech
# Data from company extracted: Hipra (HQ, Girona)
# Data from company extracted: Hipra scientific
# Data from company extracted: Hipra scientific
# Data from company extracted: Hologic Iberia
# Data from company extracted: HoMu Health Ventures
# Data from company extracted: Hospital Clínic de Barcelona
# Data from company extracted: Hospital de la Santa Creu i Sant Pau (HSCiSP)
#
# ********************************** Potential issue in company with index 15: 0    Hospital de la Santa Creu i Sant Pau (HSCiSP)
# Name: company, dtype: object
#
#
# ********************************** Potential issue in company with index 16: 0    Hospital de la Santa Creu i Sant Pau (HSCiSP)
# Name: company, dtype: object
#
# Data from company extracted: Hospital del Mar
#
# ********************************** Potential issue in company with index 18: 0    Hospital del Mar
# Name: company, dtype: object
#
# Data from company extracted: Hospital Universitari Arnau de Vilanova
# Data from company extracted: Hospital Universitari de Bellvitge (HUB)
# Data from company extracted: Hospital Universitari de Girona Doctor Josep Trueta
# Data from company extracted: Hospital Universitari Dexeus
# Data from company extracted: Hospital Universitari d'Igualada
# Data from company extracted: Hospital Universitari General de Catalunya
# Data from company extracted: Hospital Universitari Germans Trias i Pujol (HUGTiP)
# Data from company extracted: Hospital Universitari Joan XXIII de Tarragona
# Data from company extracted: Hospital Universitari Mútua de Terrassa
# Data from company extracted: Hospital Universitari Sagrat Cor
# Data from company extracted: Hospital Universitari Sant Joan de Reus
# Data from company extracted: Hospital Universitari Vall d'Hebron
# Data from company extracted: Hospital Verge de la Cinta de Tortosa
# Data from company extracted: HPC Now!
# Data from company extracted: HTSS
# Data from company extracted: HumanITcare
# Data from company extracted: Humantiks
# Data from company extracted: Hygeia Technologies
# Data from company extracted: IALE Tecnologia
# Data from company extracted: IBERinsect
# Data from company extracted: ICON Clinical Research
# Data from company extracted: Idom Ingeniería y Consultoría
# Data from company extracted: I-Dositecno
# Data from company extracted: IDP Pharma
# Data from company extracted: IESE
# Data from company extracted: Ige Ingenieros
# Data from company extracted: Ignite Technologies
# Data from company extracted: Igrobe
# Data from company extracted: Iguña Pharmaceutical Technologies
# Data from company extracted: IHT - Innovative Health Technologies
# Data from company extracted: iMAZTECH Smartglove
# Data from company extracted: Imb Grup
#
# ********************************** Potential issue in company with index 11: 0    Imb Grup
# Name: company, dtype: object
#
# Data from company extracted: iMedicPlus
# Data from company extracted: ​IMIDomics (HQ, Barcelona)
# Data from company extracted: Immucor
# Data from company extracted: Impetux Optics
# Data from company extracted: Implant Microdent System
# Data from company extracted: Implant Protesis Dental 2004
# Data from company extracted: Impress
# Data from company extracted: Inbiomotion
# Data from company extracted: InBrain Neuroelectronics
# Data from company extracted: Indalter
#
# ********************************** Potential issue in company with index 2: 0    Indalter
# Name: company, dtype: object
#
# Data from company extracted: Induct
# Data from company extracted: Indukern S.A.
# Data from company extracted: Industrial Química LASEM
# Data from company extracted: Industrial Tècnica Pecuària (ITPSA) (HQ,Barcelona)
# Data from company extracted: Infinitec Activos (HQ, Barcelona)
# Data from company extracted: InfoGenia SCP
# Data from company extracted: Infomed Servicios Informaticos
# Data from company extracted: INGECAL, Ingeniería de la Calidad y el Medio Ambiente, SL
# Data from company extracted: INGELYT
# Data from company extracted: Inke
# Data from company extracted: Inkemia IUCT Group
# Data from company extracted: INKO21
# Data from company extracted: INLEAN Engineering
# Data from company extracted: Inn Flavours
# Data from company extracted: Innerva Pharmaceuticals
# Data from company extracted: INNERVIA Bioelectronics
#
# ********************************** Potential issue in company with index 19: 0    INNERVIA Bioelectronics
# Name: company, dtype: object
#
# Data from company extracted: Innoget
# Data from company extracted: InnoPharma
# Data from company extracted: Innopro Consulting
# Data from company extracted: Innoqua
# Data from company extracted: Innovafarm
# Data from company extracted: Innovamed Spain
# Data from company extracted: Innovatech Law Firm
# Data from company extracted: Innovem
# Data from company extracted: Innovex Therapeutics
# Data from company extracted: Innuo
# Data from company extracted: Institució Catalana de Recerca i Estudis Avançats (ICREA)
#
# ********************************** Potential issue in company with index 11: 0    Institució Catalana de Recerca i Estudis Avanç...
# Name: company, dtype: object
#
# Data from company extracted: Institut Català de Finances (ICF)
# Data from company extracted: Institut Català de la Salut (ICS)
# Data from company extracted: Institut Català de Nanociència i Nanotecnologia (ICN2)
# Data from company extracted: Institut Català de Recerca de l'Aigua (ICRA)
# Data from company extracted: Institut Català d'Investigació Química (ICIQ)
#
# ********************************** Potential issue in company with index 17: 0    Institut Català d'Investigació Química (ICIQ)
# Name: company, dtype: object
#
# Data from company extracted: Institut de Bioenginyeria de Catalunya (IBEC)
#
# ********************************** Potential issue in company with index 19: 0    Institut de Bioenginyeria de Catalunya (IBEC)
# Name: company, dtype: object
#
# Data from company extracted: Institut de Biologia Molecular de Barcelona (IBMB-CSIC)
# Data from company extracted: Institut de Biotecnologia i Biomedicina Vicent Villar Palasí (IBB)
# Data from company extracted: Institut de Ciència de Materials de Barcelona (ICMAB-CSIC)
# Data from company extracted: Institut de Ciències Fotòniques (ICFO)
# Data from company extracted: Institut de Física d'Altes Energies (IFAE)
# Data from company extracted: Institut de Microcirurgia Ocular (IMO)
# Data from company extracted: Institut de Microelectrònica de Barcelona (IMB-CNM-CSIC)
# Data from company extracted: Institut de Nanociència i Nanotecnologia (IN2UB)
#
# ********************************** Potential issue in company with index 8: 0    Institut de Nanociència i Nanotecnologia (IN2UB)
# Name: company, dtype: object
#
#
# ********************************** Potential issue in company with index 9: 0    Institut de Nanociència i Nanotecnologia (IN2UB)
# Name: company, dtype: object
#
# Data from company extracted: Institut de Química Avançada de Catalunya (IQAC-CSIC)
# Data from company extracted: Institut de Química Computacional (IQC)
# Data from company extracted: Institut de Química Teorica i Computacional (IQTC-UB)
#
# ********************************** Potential issue in company with index 13: 0    Institut de Química Teorica i Computacional (I...
# Name: company, dtype: object
#
# Data from company extracted: Institut de Recerca Biomèdica de Lleida (IRB Lleida)
# Data from company extracted: Institut de Recerca Contra la Leucèmia Josep Carreras (IJC)
# ...
# Name: company, dtype: object
#
# Data from company extracted: Servei de Granges i Camps Experimentals (UAB)
# Data from company extracted: Servei de Malherbologia i Botànica Agroforestal (UDL)
# Data from company extracted: Servei de Microscòpia electrònica (UDL)
# Data from company extracted: Servei de Microscòpia, Morfometria i Microfluorimetria (UDL)
# Data from company extracted: Servei de Microscòpia (UAB)
#
# ********************************** Potential issue in company with index 1: 0    Servei de Microscòpia (UAB)
# Name: company, dtype: object
#
# Data from company extracted: Servei de Proteòmica i Genòmica (UDL)
# Data from company extracted: Servei de Qualitat Microbiològica en el Sector Agroalimentari (UDL)
# Data from company extracted: Servei de Ressonància Magnètica Nuclear (UDL)
# Data from company extracted: Servei de Seqüenciació i Síntesi d'Àcids Nucleïcs (UAB)
# Data from company extracted: Servei d'Espectrofotometria UV-Vis / FT-IR (UDL)
#
# ********************************** Potential issue in company with index 7: 0    Servei d'Espectrofotometria UV-Vis / FT-IR (UDL)
# Name: company, dtype: object
#
# Data from company extracted: Service of Nuclear Magnetic Resonance- SERMN (UAB)
# Data from company extracted: Servocad Microtronics
# Data from company extracted: Sevibe Cells
# Data from company extracted: Sherplay
# Data from company extracted: Ship2B
# Data from company extracted: Sia Enginyers
# Data from company extracted: Sibelmed
# Data from company extracted: Siemens Healthineers
# Data from company extracted: Simpexfarma
# Data from company extracted: Sincrofarm
# Data from company extracted: Singularity Biomed
#
# ********************************** Potential issue in company with index 19: 0    Singularity Biomed
# Name: company, dtype: object
#
#
# ********************************** Potential issue in company with index 0: 0    Singularity Biomed
# Name: company, dtype: object
#
#
# ********************************** Potential issue in company with index 1: 0    Singularity Biomed
# Name: company, dtype: object
#
# Data from company extracted: Skilled Skin
# Data from company extracted: Skin Tech Pharma Group
# Data from company extracted: SkinTemp
# Data from company extracted: SM Genomics
# Data from company extracted: Smart MedTech Platform (SMTP)
# Data from company extracted: SmartSalus
# Data from company extracted: Smiletronix
# Data from company extracted: Smith &amp; Nephew
# Data from company extracted: Smiths Medical España
# Data from company extracted: Social Diabetes
# Data from company extracted: Societat Catalana de Biotecnologia Mèdica
# Data from company extracted: Societat Catalana d’Immunologia
#
# ********************************** Potential issue in company with index 14: 0    Societat Catalana d’Immunologia
# Name: company, dtype: object
#
# Data from company extracted: Solutia Global Health Solutions
# Data from company extracted: SOM Biotech
# Data from company extracted: Sonicat Systems
#
# ********************************** Potential issue in company with index 18: 0    Sonicat Systems
# Name: company, dtype: object
#
# Data from company extracted: Southern European Cluster in Photonics and Optics (SECPHO)
# Data from company extracted: SP Química
# Data from company extracted: SP Veterinaria
# Data from company extracted: SPCEN Invest XXI
# Data from company extracted: Special Chemicals
#
# ********************************** Potential issue in company with index 4: 0    Special Chemicals
# Name: company, dtype: object
#
# Data from company extracted: Sphera Global Health
# Data from company extracted: Spinreact
# Data from company extracted: Spiral Therapeutics
# Data from company extracted: Splice Bio (HQ, Barcelona)
# Data from company extracted: Stacks
# Data from company extracted: Stada
# Data from company extracted: Stalicla (Barcelona)
# Data from company extracted: Stallergenes Iberica
#
# ********************************** Potential issue in company with index 13: 0    Stallergenes Iberica
# Name: company, dtype: object
#
#
# ********************************** Potential issue in company with index 14: 0    Stallergenes Iberica
# Name: company, dtype: object
#
# Data from company extracted: Status EMA Partners Spain
# Data from company extracted: STE Pharma Systems
# Data from company extracted: Stimulo
#
# ********************************** Potential issue in company with index 18: 0    Stimulo
# Name: company, dtype: object
#
# Data from company extracted: Suanity
# Data from company extracted: SUCCIPRO
#
# ********************************** Potential issue in company with index 1: 0    SUCCIPRO
# Name: company, dtype: object
#
# Data from company extracted: Super's Diana
# Data from company extracted: SurgiTrainer
# Data from company extracted: Suvoda (Barcelona)
# Data from company extracted: Swan Medical
# Data from company extracted: SWEANTY
# Data from company extracted: Sycai Medical
# Data from company extracted: Sylvius
# Data from company extracted: Syna Therapeutics
#
# ********************************** Potential issue in company with index 10: 0    Syna Therapeutics
# Name: company, dtype: object
#
# Data from company extracted: Synchrotron Light facility ALBA (CELLS)
# Data from company extracted: Syneos Health Spain
# Data from company extracted: Synlab Barcelona
# Data from company extracted: SynteractHCR
# Data from company extracted: Synthon Hispania
# Data from company extracted: Sysmex España
# Data from company extracted: Systelab Technologies
# Data from company extracted: S4e Solutions Four Engineering BCN 2003
#
# ********************************** Potential issue in company with index 19: 0    S4e Solutions Four Engineering BCN 2003
# Name: company, dtype: object
#
# Data from company extracted: Tarbis Farma
# Data from company extracted: TAVIL
# Data from company extracted: TBIOM
#
# ********************************** Potential issue in company with index 3: 0    TBIOM
# Name: company, dtype: object
#
# Data from company extracted: Tecan Ibérica Instrumentación
#
# ********************************** Potential issue in company with index 5: 0    Tecan Ibérica Instrumentación
# Name: company, dtype: object
#
# Data from company extracted: Tech4freedom
# Data from company extracted: Tech4Health Systems
# Data from company extracted: TECIL
# Data from company extracted: Tecnic
# Data from company extracted: Tecno Products
# Data from company extracted: TecnoCampus Mataró-Maresme (TCM)
# Data from company extracted: Tecno-med Ingenieros
# Data from company extracted: Teknics
# Data from company extracted: Teknokroma
# Data from company extracted: Teladoc Health (Barcelona)
# Data from company extracted: Telemedicine Clinic
# Data from company extracted: TELIC
# Data from company extracted: Telomere Therapeutics
# Data from company extracted: Tempack Packaging Solutions
# Data from company extracted: Tensormedical
# Data from company extracted: Terapme
# Data from company extracted: Terrats Medical
# Data from company extracted: Texpol
# Data from company extracted: Textil Elastico
# Data from company extracted: TFS - Trial Form Support
# Data from company extracted: The Binding Site
# Data from company extracted: The Blue Box (Tarragona)
# Data from company extracted: The Smart Lollipop
# Data from company extracted: ThePaperMill
# Data from company extracted: Theriva Biologics (Barcelona)
# Data from company extracted: Thermo Fisher Diagnostics
# Data from company extracted: Thrombotargets Europe
# Data from company extracted: Tic Salut Social
# Data from company extracted: Tillotts Pharma Spain
# Data from company extracted: Time is Brain
# Data from company extracted: Tiselab Soluciones GMP
# Data from company extracted: Top Doctors (HQ, Barcelona)
# Data from company extracted: Topcon España
# Data from company extracted: Total Planning
# Data from company extracted: Touchland
# Data from company extracted: Trackyourmed
# Data from company extracted: Tractivus
#
# ********************************** Potential issue in company with index 3: 0    Tractivus
# Name: company, dtype: object
#
# Data from company extracted: Transgenic Animals Unit (UAB)
# Data from company extracted: Transmural Biotech
# Data from company extracted: Treat
# Data from company extracted: Treematernity
# Data from company extracted: Trialing
# Data from company extracted: Trifermed
# Data from company extracted: Trinitytek Pharma
#
# ********************************** Potential issue in company with index 11: 0    Trinitytek Pharma
# Name: company, dtype: object
#
# Data from company extracted: TripMedic
# Data from company extracted: Tynax
#
# ********************************** Potential issue in company with index 14: 0    Tynax
# Name: company, dtype: object
#
# Data from company extracted: Ultrasion
# Data from company extracted: UM&amp;Asociados
# Data from company extracted: Unipharma
# Data from company extracted: Unit of Experimental Toxicology and Ecotoxicology (UTOX-PCB)
# Data from company extracted: Unitat de Producció de Vectors Virals (UAB)
# Data from company extracted: Unitat d'Innovació UPF Business Shuttle (TTO)
# Data from company extracted: Unitat Tècnica de Protecció Radiològica (UAB)
#
# ********************************** Potential issue in company with index 2: 0    Unitat Tècnica de Protecció Radiològica (UAB)
# Name: company, dtype: object
#
# Data from company extracted: Universal Robots (Barcelona)
# Data from company extracted: Universitat Abat Oliba CEU
# Data from company extracted: Universitat Autònoma de Barcelona (UAB)
# Data from company extracted: Universitat de Barcelona (UB)
# Data from company extracted: Universitat de Girona (UdG)
# Data from company extracted: Universitat de Lleida (UdL)
# Data from company extracted: Universitat de Vic (UVic)
# Data from company extracted: Universitat Internacional de Catalunya (UIC)
# Data from company extracted: Universitat Oberta de Catalunya (UOC)
#
# ********************************** Potential issue in company with index 12: 0    Universitat Oberta de Catalunya (UOC)
# Name: company, dtype: object
#
# Data from company extracted: Universitat Pompeu Fabra (UPF)
# Data from company extracted: Universitat Ramon Llull (URL)
# Data from company extracted: Universitat Rovira i Virgili (URV)
# Data from company extracted: Upbizor
# Data from company extracted: UPF Ventures
# Data from company extracted: Uppermat
# Data from company extracted: Up2Smart
# Data from company extracted: Uquifa
# Data from company extracted: Urdí-Solé &amp; Associats
# Data from company extracted: Urgo Medical
# Data from company extracted: Uriach (HQ, Palau-solità i Plegamans)
# Data from company extracted: USMIMA (MOWOOT)
#
# ********************************** Potential issue in company with index 5: 0    USMIMA (MOWOOT)
# Name: company, dtype: object
#
# Data from company extracted: Vall d'Hebron Institut d'Oncologia (VHIO)
# Data from company extracted: Van Loon Chemical lnnovations (VLCI)
# Data from company extracted: Vanir Health
# Data from company extracted: Vantum Corporate
# Data from company extracted: VB Devices
# Data from company extracted: VDMHEALTH
# Data from company extracted: Vecmedical Spain
#
# ********************************** Potential issue in company with index 13: 0    Vecmedical Spain
# Name: company, dtype: object
#
#
# ********************************** Potential issue in company with index 14: 0    Vecmedical Spain
# Name: company, dtype: object
#
# Data from company extracted: Venair Ibérica
# Data from company extracted: VenPharma
#
# ********************************** Potential issue in company with index 17: 0    VenPharma
# Name: company, dtype: object
#
#
# ********************************** Potential issue in company with index 18: 0    VenPharma
# Name: company, dtype: object
#
# Data from company extracted: VenturCap
# Data from company extracted: Venvirotech Biotechnology
#
# ********************************** Potential issue in company with index 1: 0    Venvirotech Biotechnology
# Name: company, dtype: object
#
#
# ********************************** Potential issue in company with index 2: 0    Venvirotech Biotechnology
# Name: company, dtype: object
#
# Data from company extracted: Verkami
# Data from company extracted: Vertex Technics
# Data from company extracted: Vesismin
# Data from company extracted: Veterinary laboratory for the diagnosis of infectious diseases (UAB)
# Data from company extracted: Vetgenomics
# Data from company extracted: Vifor Pharma España
# Data from company extracted: Vilardell Purtí
#
# ********************************** Potential issue in company with index 10: 0    Vilardell Purtí
# Name: company, dtype: object
#
# Data from company extracted: Virbac
# Data from company extracted: ViReInstruments
#
# ********************************** Potential issue in company with index 13: 0    ViReInstruments
# Name: company, dtype: object
#
#
# ********************************** Potential issue in company with index 14: 0    ViReInstruments
# Name: company, dtype: object
#
# Data from company extracted: Visiometrics
# Data from company extracted: Visyon
# Data from company extracted: Vitaance
# Data from company extracted: Vitala Technologies
# Data from company extracted: Viuho
# Data from company extracted: VRPharma
# Data from company extracted: VWR International Eurolab
# Data from company extracted: Vytrus Biotech
# Data from company extracted: W. L. Gore y Asociados
# Data from company extracted: Waldemar Link España
#
# ********************************** Potential issue in company with index 5: 0    Waldemar Link España
# Name: company, dtype: object
#
#
# ********************************** Potential issue in company with index 6: 0    Waldemar Link España
# Name: company, dtype: object
#
# Data from company extracted: Weelko
# Data from company extracted: WeFitter
# Data from company extracted: Wegapixel
# Data from company extracted: WellTech Treatment Management System
# Data from company extracted: Werfenlife (HQ, Hospitalet del llobregat)
#
# ********************************** Potential issue in company with index 12: 0    Werfenlife (HQ, Hospitalet del llobregat)
# Name: company, dtype: object
#
# Data from company extracted: Wharton Cells (Barcelona)
# Data from company extracted: Whole Genix
# Data from company extracted: Widex Audífonos
# Data from company extracted: Witte y Sola
# Data from company extracted: Wolters Kluwer España
#
# ********************************** Potential issue in company with index 18: 0    Wolters Kluwer España
# Name: company, dtype: object
#
# Data from company extracted: Xarxa de Referència en Biotecnologia de la Generalitat de Catalunya
# Data from company extracted: Xarxa d'Inversors Privats i Family Offices de l'IESE
# Data from company extracted: xenOPAT
# Data from company extracted: Xkelet EasyLife
# Data from company extracted: Xpeer Meded
# Data from company extracted: Ypsicon
# Data from company extracted: Ypsomed
# Data from company extracted: Ysios Capital Partners SGEIC
# Data from company extracted: Zabala Innovation Consulting
#
# ********************************** Potential issue in company with index 8: 0    Zabala Innovation Consulting
# Name: company, dtype: object
#
#
# ********************************** Potential issue in company with index 9: 0    Zabala Innovation Consulting
# Name: company, dtype: object
#
# Data from company extracted: ZBM patents
# Data from company extracted: ZeCardio Therapeutics
# Data from company extracted: ZeClinics
#
# ********************************** Potential issue in company with index 13: 0    ZeClinics
# Name: company, dtype: object
#
#
# ********************************** Potential issue in company with index 14: 0    ZeClinics
# Name: company, dtype: object
#
# Data from company extracted: Zimmer Biomet
# Data from company extracted: ZIP Solutions
# Data from company extracted: Zoetis Manufacturing and Research Spain
# Data from company extracted: Zolertia
# Data from company extracted: Zoundream
#
# ********************************** Potential issue in company with index 0: 0    Zoundream
# Name: company, dtype: object
#
# Data from company extracted: Zyrcular Foods
# Data from company extracted: 3CL-Bio
# Data from company extracted: 3D Tech Omega Zeta
# Data from company extracted: 3Digital Factory
# Data from company extracted: 3D-Shaper Medical
# Data from company extracted: 3DVisiomedicavirtual
# Data from company extracted: 4 Clinical Trials (4ct)
# Data from company extracted: 4Doctors
# Data from company extracted: 8Wires
#
#
# Tiempo total: 93.54 segundos

# %%
len(data)
# Out:
# 1389

# %%
len(potential_conflict_companies)
# Out:
# 221

# %%
len(data) + len(potential_conflict_companies)
# Out:
# 1610

# %% [markdown]
# **Dato curioso**: Ahora EY tiene información de mi start-up **LEDMOTIVE**!!!

# %%
'Ledmotive' in list(data['company'])
# Out:
# True

# %%
data[data['company']=="Ledmotive"]
# Out:
#        company                         location                 main_sector  \
# 820  Ledmotive  Sant Adrià del Besos, Barcelona  Supplier &amp; Engineering
#
#            subsector primary  \
# 820  Instrumentation
#
#                                            description
# 820  Ledmotive is specialized in spectrally tunable...

# %%
data[data['company']=="Ledmotive"]['description'].iloc[0]
# Out:
# 'Ledmotive is specialized in spectrally tunable LED light engines with 10 independent channels. Integrated spectrometer to check the light output in real-time. Spectroscopy, microscopy, medical sciences, biology and optogenetics, photonics scientific fields can take advantage of their light sources and scientific software.'
