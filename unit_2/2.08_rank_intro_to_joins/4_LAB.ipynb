# %% [markdown]
# # Lab | SQL Queries 8
#
# In this lab, you will be using the [Sakila](https://dev.mysql.com/doc/sakila/en/) database of movie rentals. You have been using this database for a couple labs already, but if you need to get the data again, refer to the official [installation link](https://dev.mysql.com/doc/sakila/en/sakila-installation.html).
#
# The database is structured as follows:
# ![DB schema](https://education-team-2020.s3-eu-west-1.amazonaws.com/data-analytics/database-sakila-schema.png)
#
# ### Instructions
#
# 1. Rank films by length (filter out the rows with nulls or zeros in length column). Select only columns title, length and rank in your output.
# 2. Rank films by length within the `rating` category (filter out the rows with nulls or zeros in length column). In your output, only select the columns title, length, rating and rank.
# 3. How many films are there for each of the categories in the category table? **Hint**: Use appropriate join between the tables "category" and "film_category".
# 4. Which actor has appeared in the most films? **Hint**: You can create a join between the tables "actor" and "film actor" and count the number of times an actor appears.
# 5. Which is the most active customer (the customer that has rented the most number of films)? **Hint**: Use appropriate join between the tables "customer" and "rental" and count the `rental_id` for each customer.
#
# **Bonus**: Which is the most rented film? (The answer is Bucket Brotherhood).
#
# This query might require using more than one join statement. Give it a try. We will talk about queries with multiple join statements later in the lessons.
#
# **Hint**: You can use join between three tables - "Film", "Inventory", and "Rental" and count the *rental ids* for each film.

# %% [markdown]
# # Your solution here:

# %%
import pymysql
from sqlalchemy import create_engine
import pandas as pd
import getpass  # To get the password without showing the input

# %% [markdown]
# ##### Prepare SQL connection

# %%
password = getpass.getpass()
connection_string = 'mysql+pymysql://root:' + password + '@localhost/bank'
engine = create_engine(connection_string)
# %load_ext sql
# %sql {connection_string}
# Out:
#  ·········
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# 'Connected: root@bank'

# %%
# Your code:

# %% [markdown]
# **1**

# %%
# %%sql
# select title, length, rank() over (order by length desc) as 'Rank' from sakila.film
# where length is not null and length >0;
# Out:
#  * mysql+pymysql://root:***@localhost/bank
# 1000 rows affected.
# [('CHICAGO NORTH', 185, 1),
#  ('CONTROL ANTHEM', 185, 1),
#  ('DARN FORRESTER', 185, 1),
#  ('GANGS PRIDE', 185, 1),
#  ('HOME PITY', 185, 1),
#  ('MUSCLE BRIGHT', 185, 1),
#  ('POND SEATTLE', 185, 1),
#  ('SOLDIERS EVOLUTION', 185, 1),
#  ('SWEET BROTHERHOOD', 185, 1),
#  ('WORST BANGER', 185, 1),
#  ('CONSPIRACY SPIRIT', 184, 11),
#  ('CRYSTAL BREAKING', 184, 11),
#  ('KING EVOLUTION', 184, 11),
#  ('MOONWALKER FOOL', 184, 11),
#  ('SMOOCHY CONTROL', 184, 11),
#  ('SONS INTERVIEW', 184, 11),
#  ('SORORITY QUEEN', 184, 11),
#  ('THEORY MERMAID', 184, 11),
#  ('CATCH AMISTAD', 183, 19),
#  ('FRONTIER CABIN', 183, 19),
#  ('SCALAWAG DUCK', 183, 19),
#  ('WIFE TURN', 183, 19),
#  ('YOUNG LANGUAGE', 183, 19),
#  ('BAKED CLEOPATRA', 182, 24),
#  ('MONSOON CAUSE', 182, 24),
#  ('RECORDS ZORRO', 182, 24),
#  ('REDS POCUS', 182, 24),
#  ('SATURN NAME', 182, 24),
#  ('SEARCHERS WAIT', 182, 24),
#  ('ANALYZE HOOSIERS', 181, 30),
#  ('HAUNTING PIANIST', 181, 30),
#  ('HOTEL HAPPINESS', 181, 30),
#  ('INTRIGUE WORST', 181, 30),
#  ('JACKET FRISCO', 181, 30),
#  ('LAWLESS VISION', 181, 30),
#  ('LOVE SUICIDES', 181, 30),
#  ('RUNAWAY TENENBAUMS', 181, 30),
#  ('STAR OPERATION', 181, 30),
#  ('WILD APOLLO', 181, 30),
#  ('ALLEY EVOLUTION', 180, 40),
#  ('CONFIDENTIAL INTERVIEW', 180, 40),
#  ('IMPACT ALADDIN', 180, 40),
#  ('MIXED DOORS', 180, 40),
#  ('MUSSOLINI SPOILERS', 180, 40),
#  ('NASH CHOCOLAT', 180, 40),
#  ('SOMETHING DUCK', 180, 40),
#  ('ANONYMOUS HUMAN', 179, 47),
#  ('BORN SPINAL', 179, 47),
#  ('CASUALTIES ENCINO', 179, 47),
#  ('CAUSE DATE', 179, 47),
#  ('FLIGHT LIES', 179, 47),
#  ('KICK SAVANNAH', 179, 47),
#  ('POTLUCK MIXED', 179, 47),
#  ('REDEMPTION COMFORTS', 179, 47),
#  ('SLACKER LIAISONS', 179, 47),
#  ('TEXAS WATCH', 179, 47),
#  ('TORQUE BOUND', 179, 47),
#  ('VIRGIN DAISY', 179, 47),
#  ('YOUTH KICK', 179, 47),
#  ('DROP WATERFRONT', 178, 60),
#  ('EXPRESS LONELY', 178, 60),
#  ('FURY MURDER', 178, 60),
#  ('IMAGE PRINCESS', 178, 60),
#  ('INNOCENT USUAL', 178, 60),
#  ('MADNESS ATTACKS', 178, 60),
#  ('NAME DETECTIVE', 178, 60),
#  ('ROCKETEER MOTHER', 178, 60),
#  ('WARDROBE PHANTOM', 178, 60),
#  ('WRONG BEHAVIOR', 178, 60),
#  ('DOUBLE WRATH', 177, 70),
#  ('DOZEN LION', 177, 70),
#  ('EMPIRE MALKOVICH', 177, 70),
#  ('MANCHURIAN CURTAIN', 177, 70),
#  ('QUEST MUSSOLINI', 177, 70),
#  ('RIDER CADDYSHACK', 177, 70),
#  ('BRAVEHEART HUMAN', 176, 76),
#  ('CAPER MOTIONS', 176, 76),
#  ('CYCLONE FAMILY', 176, 76),
#  ('DRACULA CRYSTAL', 176, 76),
#  ('ENTRAPMENT SATISFACTION', 176, 76),
#  ('GATHERING CALENDAR', 176, 76),
#  ('GREEK EVERYONE', 176, 76),
#  ('HOOSIERS BIRDCAGE', 176, 76),
#  ('SWEDEN SHINING', 176, 76),
#  ('WRATH MILE', 176, 76),
#  ('BEAUTY GREASE', 175, 86),
#  ('DRIVING POLISH', 175, 86),
#  ('LAWRENCE LOVE', 175, 86),
#  ('MODEL FISH', 175, 86),
#  ('PATTON INTERVIEW', 175, 86),
#  ('SPLASH GUMP', 175, 86),
#  ('EVOLUTION ALTER', 174, 92),
#  ('ITALIAN AFRICAN', 174, 92),
#  ('JADE BUNCH', 174, 92),
#  ('LIGHTS DEER', 174, 92),
#  ('UPRISING UPTOWN', 174, 92),
#  ('VIETNAM SMOOCHY', 174, 92),
#  ('BALLROOM MOCKINGBIRD', 173, 98),
#  ('CONQUERER NUTS', 173, 98),
#  ('FIRE WOLVES', 173, 98),
#  ('GLADIATOR WESTWARD', 173, 98),
#  ('PIZZA JUMANJI', 173, 98),
#  ('TALENTED HOMICIDE', 173, 98),
#  ('VELVET TERMINATOR', 173, 98),
#  ('CONNECTICUT TRAMP', 172, 105),
#  ('CREEPERS KANE', 172, 105),
#  ('EYES DRIVING', 172, 105),
#  ('IDAHO LOVE', 172, 105),
#  ('JERK PAYCHECK', 172, 105),
#  ('NORTHWEST POLISH', 172, 105),
#  ('TIGHTS DAWN', 172, 105),
#  ('UNCUT SUICIDES', 172, 105),
#  ('DUFFEL APOCALYPSE', 171, 113),
#  ('JERICHO MULAN', 171, 113),
#  ('KRAMER CHOCOLATE', 171, 113),
#  ('MAGNOLIA FORRESTER', 171, 113),
#  ('MOONSHINE CABIN', 171, 113),
#  ('ROXANNE REBEL', 171, 113),
#  ('TRAMP OTHERS', 171, 113),
#  ('WORLD LEATHERNECKS', 171, 113),
#  ('ARTIST COLDBLOODED', 170, 121),
#  ('ATLANTIS CAUSE', 170, 121),
#  ('DRAGON SQUAD', 170, 121),
#  ('TRADING PINOCCHIO', 170, 121),
#  ('AGENT TRUMAN', 169, 125),
#  ('BREAKING HOME', 169, 125),
#  ('HEDWIG ALTER', 169, 125),
#  ('KENTUCKIAN GIANT', 169, 125),
#  ('OUTBREAK DIVINE', 169, 125),
#  ('SOUP WISDOM', 169, 125),
#  ('ANTITRUST TOMATOES', 168, 131),
#  ('DYING MAKER', 168, 131),
#  ('HAROLD FRENCH', 168, 131),
#  ('TRANSLATION SUMMER', 168, 131),
#  ('CAMPUS REMEMBER', 167, 135),
#  ('ESCAPE METROPOLIS', 167, 135),
#  ('EXORCIST STING', 167, 135),
#  ('INCH JET', 167, 135),
#  ('LESSON CLEOPATRA', 167, 135),
#  ('REQUIEM TYCOON', 167, 135),
#  ('SHOW LORD', 167, 135),
#  ('CONTACT ANONYMOUS', 166, 142),
#  ('GREEDY ROOTS', 166, 142),
#  ('MINE TITANS', 166, 142),
#  ('MOTIONS DETAILS', 166, 142),
#  ('MURDER ANTITRUST', 166, 142),
#  ('CITIZEN SHREK', 165, 147),
#  ('DARLING BREAKING', 165, 147),
#  ('MASSACRE USUAL', 165, 147),
#  ('SONG HEDWIG', 165, 147),
#  ('SPEAKEASY DATE', 165, 147),
#  ('CLERKS ANGELS', 164, 152),
#  ('MISSION ZOOLANDER', 164, 152),
#  ('UNITED PILOT', 164, 152),
#  ('VIRGINIAN PLUTO', 164, 152),
#  ('BIRD INDEPENDENCE', 163, 156),
#  ('CASPER DRAGONFLY', 163, 156),
#  ('EVERYONE CRAFT', 163, 156),
#  ('GILMORE BOILED', 163, 156),
#  ('KISS GLORY', 163, 156),
#  ('QUEEN LUKE', 163, 156),
#  ('STORY SIDE', 163, 156),
#  ('BADMAN DAWN', 162, 163),
#  ('BIRCH ANTITRUST', 162, 163),
#  ('LOVERBOY ATTACKS', 162, 163),
#  ('MIRACLE VIRTUAL', 162, 163),
#  ('ROSES TREASURE', 162, 163),
#  ('BROOKLYN DESERT', 161, 168),
#  ('DADDY PITTSBURGH', 161, 168),
#  ('GABLES METROPOLIS', 161, 168),
#  ('KILLER INNOCENT', 161, 168),
#  ('MASSAGE IMAGE', 161, 168),
#  ('METAL ARMAGEDDON', 161, 168),
#  ('NEIGHBORS CHARADE', 161, 168),
#  ('OLEANDER CLUE', 161, 168),
#  ('WASH HEAVENLY', 161, 168),
#  ('BEAR GRACELAND', 160, 177),
#  ('IGBY MAKER', 160, 177),
#  ('MULAN MOON', 160, 177),
#  ('MUMMY CREATURES', 160, 177),
#  ('PEACH INNOCENT', 160, 177),
#  ('STOCK GLASS', 160, 177),
#  ('DRIVER ANNIE', 159, 183),
#  ('FRANKENSTEIN STRANGER', 159, 183),
#  ('MALKOVICH PET', 159, 183),
#  ('NEWSIES STORY', 159, 183),
#  ('POSEIDON FOREVER', 159, 183),
#  ('WEST LION', 159, 183),
#  ('ENOUGH RAGING', 158, 189),
#  ('FEVER EMPIRE', 158, 189),
#  ('FOOL MOCKINGBIRD', 158, 189),
#  ('MONTEREY LABYRINTH', 158, 189),
#  ('ROAD ROXANNE', 158, 189),
#  ('SECRETARY ROUGE', 158, 189),
#  ('HOBBIT ALIEN', 157, 195),
#  ('INDEPENDENCE HOTEL', 157, 195),
#  ('MULHOLLAND BEAST', 157, 195),
#  ('PAST SUICIDES', 157, 195),
#  ('TOOTSIE PILOT', 157, 195),
#  ('VOLCANO TEXAS', 157, 195),
#  ('FINDING ANACONDA', 156, 201),
#  ('GRADUATE LORD', 156, 201),
#  ('OPERATION OPERATION', 156, 201),
#  ('SLIPPER FIDELITY', 156, 201),
#  ('ELF MURDER', 155, 205),
#  ('FAMILY SWEET', 155, 205),
#  ('GRAPES FURY', 155, 205),
#  ('LOLITA WORLD', 155, 205),
#  ('PSYCHO SHRUNK', 155, 205),
#  ('TADPOLE PARK', 155, 205),
#  ('DOUBTFIRE LABYRINTH', 154, 211),
#  ('DURHAM PANKY', 154, 211),
#  ('GOLD RIVER', 154, 211),
#  ('RAGING AIRPLANE', 154, 211),
#  ('SANTA PARIS', 154, 211),
#  ('SASSY PACKER', 154, 211),
#  ('SHREK LICENSE', 154, 211),
#  ('APOLLO TEEN', 153, 218),
#  ('BABY HALL', 153, 218),
#  ('CROSSROADS CASUALTIES', 153, 218),
#  ('EDGE KISSING', 153, 218),
#  ('GOLDMINE TYCOON', 153, 218),
#  ('LEATHERNECKS DWARFS', 153, 218),
#  ('RIGHT CRANES', 153, 218),
#  ('ROLLERCOASTER BRINGING', 153, 218),
#  ('RULES HUMAN', 153, 218),
#  ('CENTER DINOSAUR', 152, 227),
#  ('ELIZABETH SHANE', 152, 227),
#  ('LUCK OPUS', 152, 227),
#  ('SISTER FREDDY', 152, 227),
#  ('TELEMARK HEARTBREAKERS', 152, 227),
#  ('TOURIST PELICAN', 152, 227),
#  ('TUXEDO MILE', 152, 227),
#  ('TWISTED PIRATES', 152, 227),
#  ('WAGON JAWS', 152, 227),
#  ('BEETHOVEN EXORCIST', 151, 236),
#  ('CAROL TEXAS', 151, 236),
#  ('HUNCHBACK IMPOSSIBLE', 151, 236),
#  ('MASKED BUBBLE', 151, 236),
#  ('SCHOOL JACKET', 151, 236),
#  ('SPOILERS HELLFIGHTERS', 151, 236),
#  ('STRAIGHT HOURS', 151, 236),
#  ('ALI FOREVER', 150, 243),
#  ('BINGO TALENTED', 150, 243),
#  ('CHRISTMAS MOONSHINE', 150, 243),
#  ('CLEOPATRA DEVIL', 150, 243),
#  ('GRINCH MASSAGE', 150, 243),
#  ('HYSTERICAL GRAIL', 150, 243),
#  ('RUSHMORE MERMAID', 150, 243),
#  ('SATURDAY LAMBS', 150, 243),
#  ('COLOR PHILADELPHIA', 149, 251),
#  ('HOLOCAUST HIGHBALL', 149, 251),
#  ('MINDS TRUMAN', 149, 251),
#  ('NIGHTMARE CHILL', 149, 251),
#  ('RIVER OUTLAW', 149, 251),
#  ('SPIRIT FLINTSTONES', 149, 251),
#  ('ARMY FLINTSTONES', 148, 257),
#  ('BLANKET BEVERLY', 148, 257),
#  ('EASY GLADIATOR', 148, 257),
#  ('FIREBALL PHILADELPHIA', 148, 257),
#  ('FLINTSTONES HAPPINESS', 148, 257),
#  ('OUTLAW HANKY', 148, 257),
#  ('TELEGRAPH VOYAGE', 148, 257),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 147, 264),
#  ('DIRTY ACE', 147, 264),
#  ('LIES TREATMENT', 147, 264),
#  ('MADISON TRAP', 147, 264),
#  ('MENAGERIE RUSHMORE', 147, 264),
#  ('RACER EGG', 147, 264),
#  ('RANGE MOONWALKER', 147, 264),
#  ('SCISSORHANDS SLUMS', 147, 264),
#  ('SLUMS DUCK', 147, 264),
#  ('CHAPLIN LICENSE', 146, 273),
#  ('COWBOY DOOM', 146, 273),
#  ('HALF OUTFIELD', 146, 273),
#  ('HAMLET WISDOM', 146, 273),
#  ('MOURNING PURPLE', 146, 273),
#  ('FLOATS GARDEN', 145, 278),
#  ('NUTS TIES', 145, 278),
#  ('PAYCHECK WAIT', 145, 278),
#  ('ROCKY WAR', 145, 278),
#  ('RUN PACIFIC', 145, 278),
#  ('VACATION BOONDOCK', 145, 278),
#  ('VIDEOTAPE ARSENIC', 145, 278),
#  ('DANCING FEVER', 144, 285),
#  ('FACTORY DRAGON', 144, 285),
#  ('LAMBS CINCINATTI', 144, 285),
#  ('PACIFIC AMISTAD', 144, 285),
#  ('PRESIDENT BANG', 144, 285),
#  ('STRICTLY SCARFACE', 144, 285),
#  ('TOWERS HURRICANE', 144, 285),
#  ('VIRTUAL SPOILERS', 144, 285),
#  ('CINCINATTI WHISPERER', 143, 293),
#  ('CLOCKWORK PARADISE', 143, 293),
#  ('CROOKED FROGMEN', 143, 293),
#  ('DETECTIVE VISION', 143, 293),
#  ('ENCINO ELF', 143, 293),
#  ('SOUTH WAIT', 143, 293),
#  ('STEEL SANTA', 143, 293),
#  ('BIKINI BORROWERS', 142, 300),
#  ('CHILL LUCK', 142, 300),
#  ('FERRIS MOTHER', 142, 300),
#  ('MILLION ACE', 142, 300),
#  ('TOMORROW HUSTLER', 142, 300),
#  ('TRACY CIDER', 142, 300),
#  ('VANISHED GARDEN', 142, 300),
#  ('DISCIPLE MOTHER', 141, 307),
#  ('DYNAMITE TARZAN', 141, 307),
#  ('HOCUS FRIDA', 141, 307),
#  ('HOMICIDE PEACH', 141, 307),
#  ('KISSING DOLLS', 141, 307),
#  ('SPICE SORORITY', 141, 307),
#  ('SUN CONFESSIONS', 141, 307),
#  ('EAGLES PANKY', 140, 314),
#  ('GRACELAND DYNAMITE', 140, 314),
#  ('LIAISONS SWEET', 140, 314),
#  ('LOATHING LEGALLY', 140, 314),
#  ('STEERS ARMAGEDDON', 140, 314),
#  ('CLYDE THEORY', 139, 319),
#  ('CREATURES SHAKESPEARE', 139, 319),
#  ('DORADO NOTTING', 139, 319),
#  ('GROUNDHOG UNCUT', 139, 319),
#  ('HOPE TOOTSIE', 139, 319),
#  ('HORROR REIGN', 139, 319),
#  ('SHRUNK DIVINE', 139, 319),
#  ('STRANGER STRANGERS', 139, 319),
#  ('TRAFFIC HOBBIT', 139, 319),
#  ('VOICE PEACH', 139, 319),
#  ('WORKER TARZAN', 139, 319),
#  ('EXPECATIONS NATURAL', 138, 330),
#  ('LIBERTY MAGNIFICENT', 138, 330),
#  ('MAIDEN HOME', 138, 330),
#  ('POCUS PULP', 138, 330),
#  ('SPINAL ROCKY', 138, 330),
#  ('SPIRITED CASUALTIES', 138, 330),
#  ('ARSENIC INDEPENDENCE', 137, 336),
#  ('GRIT CLOCKWORK', 137, 336),
#  ('LIFE TWISTED', 137, 336),
#  ('LOSE INCH', 137, 336),
#  ('PHILADELPHIA WIFE', 137, 336),
#  ('POLLOCK DELIVERANCE', 137, 336),
#  ('SCORPION APOLLO', 137, 336),
#  ('SLEEPY JAPANESE', 137, 336),
#  ('WILLOW TRACY', 137, 336),
#  ('ALASKA PHANTOM', 136, 345),
#  ('BRINGING HYSTERICAL', 136, 345),
#  ('CRAZY HOME', 136, 345),
#  ('HOLLOW JEOPARDY', 136, 345),
#  ('MAKER GABLES', 136, 345),
#  ('PIANIST OUTFIELD', 136, 345),
#  ('REAP UNFAITHFUL', 136, 345),
#  ('SQUAD FISH', 136, 345),
#  ('TOWN ARK', 136, 345),
#  ('CANDLES GRAPES', 135, 354),
#  ('DREAM PICKUP', 135, 354),
#  ('GREASE YOUTH', 135, 354),
#  ('INDIAN LOVE', 135, 354),
#  ('JAPANESE RUN', 135, 354),
#  ('MONEY HAROLD', 135, 354),
#  ('SIERRA DIVIDE', 135, 354),
#  ('SUNRISE LEAGUE', 135, 354),
#  ('THIEF PELICAN', 135, 354),
#  ('WALLS ARTIST', 135, 354),
#  ('JUNGLE CLOSER', 134, 364),
#  ('PITTSBURGH HUNCHBACK', 134, 364),
#  ('ROBBERY BRIGHT', 134, 364),
#  ('SPLENDOR PATTON', 134, 364),
#  ('WEEKEND PERSONAL', 134, 364),
#  ('BUCKET BROTHERHOOD', 133, 369),
#  ('CURTAIN VIDEOTAPE', 133, 369),
#  ('DRAGONFLY STRANGERS', 133, 369),
#  ('FREEDOM CLEOPATRA', 133, 369),
#  ('MALLRATS UNITED', 133, 369),
#  ('CHOCOLATE DUCK', 132, 374),
#  ('DUDE BLINDNESS', 132, 374),
#  ('NECKLACE OUTBREAK', 132, 374),
#  ('PLATOON INSTINCT', 132, 374),
#  ('SKY MIRACLE', 132, 374),
#  ('STREAK RIDGEMONT', 132, 374),
#  ('TRAINSPOTTING STRANGERS', 132, 374),
#  ('VOLUME HOUSE', 132, 374),
#  ('FANTASIA PARK', 131, 382),
#  ('FOREVER CANDIDATE', 131, 382),
#  ('ICE CROSSING', 131, 382),
#  ('NEMO CAMPUS', 131, 382),
#  ('OPEN AFRICAN', 131, 382),
#  ('AFRICAN EGG', 130, 387),
#  ('DARKO DORADO', 130, 387),
#  ('FARGO GANDHI', 130, 387),
#  ('JASON TRAP', 130, 387),
#  ('MAJESTIC FLOATS', 130, 387),
#  ('STALLION SUNDANCE', 130, 387),
#  ('AMERICAN CIRCUS', 129, 393),
#  ('BAREFOOT MANCHURIAN', 129, 393),
#  ('GOSFORD DONNIE', 129, 393),
#  ('MUSIC BOONDOCK', 129, 393),
#  ('OUTFIELD MASSACRE', 129, 393),
#  ('SLEEPING SUSPECTS', 129, 393),
#  ('UNFORGIVEN ZOOLANDER', 129, 393),
#  ('GALAXY SWEETHEARTS', 128, 400),
#  ('HOLES BRANNIGAN', 128, 400),
#  ('JEDI BENEATH', 128, 400),
#  ('NOTORIOUS REUNION', 128, 400),
#  ('PAPI NECKLACE', 128, 400),
#  ('USUAL UNTOUCHABLES', 128, 400),
#  ('WARS PLUTO', 128, 400),
#  ('ARGONAUTS TOWN', 127, 407),
#  ('GUNFIGHTER MUSSOLINI', 127, 407),
#  ('MALTESE HOPE', 127, 407),
#  ('SEVEN SWARM', 127, 407),
#  ('SUBMARINE BED', 127, 407),
#  ('ALAMO VIDEOTAPE', 126, 412),
#  ('ELEPHANT TROJAN', 126, 412),
#  ('FREAKY POCUS', 126, 412),
#  ('MONTEZUMA COMMAND', 126, 412),
#  ('PAJAMA JAWBREAKER', 126, 412),
#  ('SINNERS ATLANTIS', 126, 412),
#  ('VAMPIRE WHALE', 126, 412),
#  ('WOMEN DORADO', 126, 412),
#  ('WONDERFUL DROP', 126, 412),
#  ('BULL SHAWSHANK', 125, 421),
#  ('DONNIE ALLEY', 125, 421),
#  ('FISH OPUS', 125, 421),
#  ('GENTLEMEN STAGE', 125, 421),
#  ('HUNTER ALTER', 125, 421),
#  ('SAINTS BRIDE', 125, 421),
#  ('SHINING ROSES', 125, 421),
#  ('CHISUM BEHAVIOR', 124, 428),
#  ('CLONES PINOCCHIO', 124, 428),
#  ('JINGLE SAGEBRUSH', 124, 428),
#  ('SPEED SUIT', 124, 428),
#  ('BREAKFAST GOLDFINGER', 123, 432),
#  ('FLASH WARS', 123, 432),
#  ('INSECTS STONE', 123, 432),
#  ('MASK PEACH', 123, 432),
#  ('REEF SALUTE', 123, 432),
#  ('SWARM GOLD', 123, 432),
#  ('VANISHING ROCKY', 123, 432),
#  ('BEACH HEARTBREAKERS', 122, 439),
#  ('BETRAYED REAR', 122, 439),
#  ('CHICKEN HELLFIGHTERS', 122, 439),
#  ('CONFUSED CANDLES', 122, 439),
#  ('DECEIVER BETRAYED', 122, 439),
#  ('DOGMA FAMILY', 122, 439),
#  ('EXTRAORDINARY CONQUERER', 122, 439),
#  ('HOURS RAGE', 122, 439),
#  ('ILLUSION AMELIE', 122, 439),
#  ('MIGHTY LUCK', 122, 439),
#  ('VANILLA DAY', 122, 439),
#  ('ARIZONA BANG', 121, 450),
#  ('BOOGIE AMELIE', 121, 450),
#  ('BRANNIGAN SUNRISE', 121, 450),
#  ('DANGEROUS UPTOWN', 121, 450),
#  ('HARRY IDAHO', 121, 450),
#  ('JUMANJI BLADE', 121, 450),
#  ('PARIS WEEKEND', 121, 450),
#  ('PURE RUNNER', 121, 450),
#  ('CALENDAR GUNFIGHT', 120, 458),
#  ('COMMAND DARLING', 120, 458),
#  ('DAZED PUNK', 120, 458),
#  ('DOLLS RAGE', 120, 458),
#  ('KARATE MOON', 120, 458),
#  ('LOCK REAR', 120, 458),
#  ('ORDER BETRAYED', 120, 458),
#  ('RAGE GAMES', 120, 458),
#  ('UNTOUCHABLES SUNRISE', 120, 458),
#  ('APOCALYPSE FLAMINGOS', 119, 467),
#  ('BUGSY SONG', 119, 467),
#  ('DUMBO LUST', 119, 467),
#  ('GAMES BOWFINGER', 119, 467),
#  ('IDENTITY LOVER', 119, 467),
#  ('STRANGERS GRAFFITI', 119, 467),
#  ('BACKLASH UNDEFEATED', 118, 473),
#  ('FIDELITY DEVIL', 118, 473),
#  ('JAWBREAKER BROOKLYN', 118, 473),
#  ('ORIENT CLOSER', 118, 473),
#  ('OTHERS SOUP', 118, 473),
#  ('PATHS CONTROL', 118, 473),
#  ('PERSONAL LADYBUGS', 118, 473),
#  ('ROUGE SQUAD', 118, 473),
#  ('AFFAIR PREJUDICE', 117, 481),
#  ('CHAMBER ITALIAN', 117, 481),
#  ('GRAFFITI LOVE', 117, 481),
#  ('MAGIC MALLRATS', 117, 481),
#  ('RESURRECTION SILVERADO', 117, 481),
#  ('DUCK RACER', 116, 486),
#  ('INSTINCT AIRPORT', 116, 486),
#  ('MADIGAN DORADO', 116, 486),
#  ('WORDS HUNTER', 116, 486),
#  ('CONNECTION MICROCOSMOS', 115, 490),
#  ('ELEMENT FREDDY', 115, 490),
#  ('GLORY TRACY', 115, 490),
#  ('OSCAR GOLD', 115, 490),
#  ('POTTER CONNECTICUT', 115, 490),
#  ('PRIX UNDEFEATED', 115, 490),
#  ('TROOPERS METAL', 115, 490),
#  ('ALABAMA DEVIL', 114, 497),
#  ('BLADE POLISH', 114, 497),
#  ('CARRIE BUNCH', 114, 497),
#  ('CHAINSAW UPTOWN', 114, 497),
#  ('CHASING FIGHT', 114, 497),
#  ('GILBERT PELICAN', 114, 497),
#  ('MARRIED GO', 114, 497),
#  ('PRIDE ALAMO', 114, 497),
#  ('SUGAR WONKA', 114, 497),
#  ('SUPERFLY TRIP', 114, 497),
#  ('AMADEUS HOLY', 113, 507),
#  ('ATTACKS HATE', 113, 507),
#  ('BANGER PINOCCHIO', 113, 507),
#  ('DAY UNFAITHFUL', 113, 507),
#  ('LADYBUGS ARMAGEDDON', 113, 507),
#  ('LEGALLY SECRETARY', 113, 507),
#  ('SHEPHERD MIDSUMMER', 113, 507),
#  ('STATE WASTELAND', 113, 507),
#  ('CAT CONEHEADS', 112, 515),
#  ('CONEHEADS SMOOCHY', 112, 515),
#  ('CONVERSATION DOWNHILL', 112, 515),
#  ('CROWDS TELEMARK', 112, 515),
#  ('CRUSADE HONEY', 112, 515),
#  ('FORRESTER COMANCHEROS', 112, 515),
#  ('JAWS HARRY', 112, 515),
#  ('QUILLS BULL', 112, 515),
#  ('SEABISCUIT PUNK', 112, 515),
#  ('SPY MILE', 112, 515),
#  ('STAGECOACH ARMAGEDDON', 112, 515),
#  ('WAIT CIDER', 112, 515),
#  ('WATERSHIP FRONTIER', 112, 515),
#  ('FROGMEN BREAKING', 111, 528),
#  ('GROOVE FICTION', 111, 528),
#  ('SIEGE MADRE', 111, 528),
#  ('SUIT WALLS', 111, 528),
#  ('TIES HUNGER', 111, 528),
#  ('WIND PHANTOM', 111, 528),
#  ('WONDERLAND CHRISTMAS', 111, 528),
#  ('CELEBRITY HORN', 110, 535),
#  ('DRUMLINE CYCLONE', 110, 535),
#  ('HIGHBALL POTTER', 110, 535),
#  ('LEAGUE HELLFIGHTERS', 110, 535),
#  ('REMEMBER DIARY', 110, 535),
#  ('SAMURAI LION', 110, 535),
#  ('SEATTLE EXPECATIONS', 110, 535),
#  ('SNATCH SLIPPER', 110, 535),
#  ('TRAP GUYS', 110, 535),
#  ('COMA HEAD', 109, 544),
#  ('HOUSE DYNAMITE', 109, 544),
#  ('PANTHER REDS', 109, 544),
#  ('PARK CITIZEN', 109, 544),
#  ('RUGRATS SHAKESPEARE', 109, 544),
#  ('SECRETS PARADISE', 109, 544),
#  ('WHALE BIKINI', 109, 544),
#  ('AUTUMN CROW', 108, 551),
#  ('GORGEOUS BINGO', 108, 551),
#  ('HANDICAP BOONDOCK', 108, 551),
#  ('LORD ARIZONA', 108, 551),
#  ('SWEETHEARTS SUSPECTS', 108, 551),
#  ('CHITTY LOCK', 107, 556),
#  ('DIARY PANIC', 107, 556),
#  ('EFFECT GLADIATOR', 107, 556),
#  ('HANKY OCTOBER', 107, 556),
#  ('HATE HANDICAP', 107, 556),
#  ('INTENTIONS EMPIRE', 107, 556),
#  ('MONSTER SPARTACUS', 107, 556),
#  ('PARTY KNOCK', 107, 556),
#  ('UNDEFEATED DALMATIONS', 107, 556),
#  ('WANDA CHAMBER', 107, 556),
#  ('BED HIGHBALL', 106, 566),
#  ('DALMATIONS SWEDEN', 106, 566),
#  ('DEER VIRGINIAN', 106, 566),
#  ('GASLIGHT CRUSADE', 106, 566),
#  ('PRIVATE DROP', 106, 566),
#  ('SAGEBRUSH CLUELESS', 106, 566),
#  ('HUNGER ROOF', 105, 572),
#  ('JOON NORTHWEST', 105, 572),
#  ('MICROCOSMOS PARADISE', 105, 572),
#  ('MOB DUFFEL', 105, 572),
#  ('WON DARES', 105, 572),
#  ('ZHIVAGO CORE', 105, 572),
#  ('CROW GREASE', 104, 578),
#  ('DATE SPEED', 104, 578),
#  ('FEATHERS METAL', 104, 578),
#  ('MERMAID INSECTS', 104, 578),
#  ('SHIP WONDERLAND', 104, 578),
#  ('TITANIC BOONDOCK', 104, 578),
#  ('BIRDCAGE CASPER', 103, 584),
#  ('BLINDNESS GUN', 103, 584),
#  ('FIREHOUSE VIETNAM', 103, 584),
#  ('GLASS DYING', 103, 584),
#  ('HOMEWARD CIDER', 103, 584),
#  ('IMPOSSIBLE PREJUDICE', 103, 584),
#  ('MOTHER OLEANDER', 103, 584),
#  ('PINOCCHIO SIMON', 103, 584),
#  ('STRANGELOVE DESIRE', 103, 584),
#  ('BOILED DARES', 102, 593),
#  ('FALCON VOLUME', 102, 593),
#  ('GIANT TROOPERS', 102, 593),
#  ('HEAVYWEIGHTS BEAST', 102, 593),
#  ('JEOPARDY ENCINO', 102, 593),
#  ('OPUS ICE', 102, 593),
#  ('PANIC CLUB', 102, 593),
#  ('ROBBERS JOON', 102, 593),
#  ('ROCK INSTINCT', 102, 593),
#  ('SCARFACE BANG', 102, 593),
#  ('TREASURE COMMAND', 102, 593),
#  ('CHOCOLAT HARRY', 101, 604),
#  ('CIDER DESIRE', 101, 604),
#  ('DWARFS ALTER', 101, 604),
#  ('GHOSTBUSTERS ELF', 101, 604),
#  ('ROOF CHAMPION', 101, 604),
#  ('RUNNER MADIGAN', 101, 604),
#  ('ZOOLANDER FICTION', 101, 604),
#  ('BEHAVIOR RUNAWAY', 100, 611),
#  ('BILKO ANONYMOUS', 100, 611),
#  ('DELIVERANCE MULHOLLAND', 100, 611),
#  ('DIVINE RESURRECTION', 100, 611),
#  ('FLATLINERS KILLER', 100, 611),
#  ('GUN BONNIE', 100, 611),
#  ('HAPPINESS UNITED', 100, 611),
#  ('HYDE DOCTOR', 100, 611),
#  ('PIRATES ROXANNE', 100, 611),
#  ('PUNK DIVORCE', 100, 611),
#  ('WITCHES PANIC', 100, 611),
#  ('WYOMING STORM', 100, 611),
#  ('ARMAGEDDON LOST', 99, 623),
#  ('DARKNESS WAR', 99, 623),
#  ('FRENCH HOLIDAY', 99, 623),
#  ('PATIENT SISTER', 99, 623),
#  ('PERDITION FARGO', 99, 623),
#  ('PET HAUNTING', 99, 623),
#  ('SABRINA MIDNIGHT', 99, 623),
#  ('TENENBAUMS COMMAND', 99, 623),
#  ('BOUND CHEAPER', 98, 631),
#  ('EARRING INSTINCT', 98, 631),
#  ('FEUD FROGMEN', 98, 631),
#  ('LOST BIRD', 98, 631),
#  ('MADRE GABLES', 98, 631),
#  ('PREJUDICE OLEANDER', 98, 631),
#  ('SENSIBILITY REAR', 98, 631),
#  ('WISDOM WORKER', 98, 631),
#  ('EXPENDABLE STALLION', 97, 639),
#  ('INVASION CYCLONE', 97, 639),
#  ('LUCKY FLYING', 97, 639),
#  ('REAR TRADING', 97, 639),
#  ('DRUMS DYNAMITE', 96, 643),
#  ('EARLY HOME', 96, 643),
#  ('CLUELESS BUCKET', 95, 645),
#  ('HORN WORKING', 95, 645),
#  ('ALICE FANTASIA', 94, 647),
#  ('DISTURBING SCARFACE', 94, 647),
#  ('FULL FLATLINERS', 94, 647),
#  ('STONE FIRE', 94, 647),
#  ('BILL OTHERS', 93, 651),
#  ('GOLDFINGER SENSIBILITY', 93, 651),
#  ('GREATEST NORTH', 93, 651),
#  ('HILLS NEIGHBORS', 93, 651),
#  ('PANKY SUBMARINE', 93, 651),
#  ('SHANE DARKNESS', 93, 651),
#  ('STING PERSONAL', 93, 651),
#  ('SUICIDES SILENCE', 93, 651),
#  ('ANACONDA CONFESSIONS', 92, 659),
#  ('APACHE DIVINE', 92, 659),
#  ('CARIBBEAN LIBERTY', 92, 659),
#  ('CORE SUIT', 92, 659),
#  ('ENCOUNTERS CURTAIN', 92, 659),
#  ('KANE EXORCIST', 92, 659),
#  ('MYSTIC TRUMAN', 92, 659),
#  ('NATIONAL STORY', 92, 659),
#  ('OPPOSITE NECKLACE', 92, 659),
#  ('SUNDANCE INVASION', 92, 659),
#  ('TRUMAN CRAZY', 92, 659),
#  ('ANTHEM LUKE', 91, 670),
#  ('FATAL HAUNTED', 91, 670),
#  ('FIGHT JAWBREAKER', 91, 670),
#  ('LICENSE WEEKEND', 91, 670),
#  ('TARZAN VIDEOTAPE', 91, 670),
#  ('TITANS JERK', 91, 670),
#  ('BASIC EASY', 90, 676),
#  ('CIRCUS YOUTH', 90, 676),
#  ('FORWARD TEMPLE', 90, 676),
#  ('SECRET GROUNDHOG', 90, 676),
#  ('VERTIGO NORTHWEST', 90, 676),
#  ('BEAST HUNCHBACK', 89, 681),
#  ('BUTTERFLY CHOCOLAT', 89, 681),
#  ('DARES PLUTO', 89, 681),
#  ('GLEAMING JAWBREAKER', 89, 681),
#  ('PULP BEVERLY', 89, 681),
#  ('ROOTS REMEMBER', 89, 681),
#  ('DETAILS PACKER', 88, 687),
#  ('HOLY TADPOLE', 88, 687),
#  ('PURPLE MOVIE', 88, 687),
#  ('TERMINATOR CLUB', 88, 687),
#  ('BANG KWAI', 87, 691),
#  ('CHEAPER CLYDE', 87, 691),
#  ('CONGENIALITY QUEST', 87, 691),
#  ('DEVIL DESIRE', 87, 691),
#  ('SLEUTH ORIENT', 87, 691),
#  ('TREATMENT JEKYLL', 87, 691),
#  ('ACADEMY DINOSAUR', 86, 697),
#  ('ANNIE IDENTITY', 86, 697),
#  ('GANDHI KWAI', 86, 697),
#  ('MIDNIGHT WESTWARD', 86, 697),
#  ('YENTL IDAHO', 86, 697),
#  ('AMISTAD MIDSUMMER', 85, 702),
#  ('BEVERLY OUTLAW', 85, 702),
#  ('BLACKOUT PRIVATE', 85, 702),
#  ('CANYON STOCK', 85, 702),
#  ('CASABLANCA SUPER', 85, 702),
#  ('EARTH VISION', 85, 702),
#  ('EGYPT TENENBAUMS', 85, 702),
#  ('ENDING CROWDS', 85, 702),
#  ('GHOST GROUNDHOG', 85, 702),
#  ('GRAIL FRANKENSTEIN', 85, 702),
#  ('LOLA AGENT', 85, 702),
#  ('OZ LIAISONS', 85, 702),
#  ('STAGE WORLD', 85, 702),
#  ('VARSITY TRIP', 85, 702),
#  ('WASTELAND DIVINE', 85, 702),
#  ('WINDOW SIDE', 85, 702),
#  ('WONKA SEA', 85, 702),
#  ('DAISY MENAGERIE', 84, 719),
#  ('GONE TROUBLE', 84, 719),
#  ('GUYS FALCON', 84, 719),
#  ('HIGH ENCINO', 84, 719),
#  ('HONEY TIES', 84, 719),
#  ('IDOLS SNATCHERS', 84, 719),
#  ('ISLAND EXORCIST', 84, 719),
#  ('JEEPERS WEDDING', 84, 719),
#  ('PACKER MADIGAN', 84, 719),
#  ('PLUTO OLEANDER', 84, 719),
#  ('SAVANNAH TOWN', 84, 719),
#  ('SLING LUKE', 84, 719),
#  ('UPTOWN YOUNG', 84, 719),
#  ('ATTRACTION NEWTON', 83, 732),
#  ('FUGITIVE MAGUIRE', 83, 732),
#  ('HUSTLER PARTY', 83, 732),
#  ('MOON BUNCH', 83, 732),
#  ('NONE SPIKING', 83, 732),
#  ('WARLOCK WEREWOLF', 83, 732),
#  ('ALONE TRIP', 82, 738),
#  ('ANYTHING SAVANNAH', 82, 738),
#  ('FROST HEAD', 82, 738),
#  ('PERFECT GROOVE', 82, 738),
#  ('RAIDERS ANTITRUST', 82, 738),
#  ('REIGN GENTLEMEN', 82, 738),
#  ('TYCOON GATHERING', 82, 738),
#  ('CLASH FREDDY', 81, 745),
#  ('DESPERATE TRAINSPOTTING', 81, 745),
#  ('ROMAN PUNK', 81, 745),
#  ('FLAMINGOS CONNECTICUT', 80, 748),
#  ('GARDEN ISLAND', 80, 748),
#  ('LOSER HUSTLER', 80, 748),
#  ('MEET CHOCOLATE', 80, 748),
#  ('PEAK FOREVER', 80, 748),
#  ('SADDLE ANTITRUST', 80, 748),
#  ('SEA VIRGIN', 80, 748),
#  ('SHAWSHANK BUBBLE', 80, 748),
#  ('TURN STAR', 80, 748),
#  ('WAR NOTTING', 80, 748),
#  ('AMELIE HELLFIGHTERS', 79, 758),
#  ('ISHTAR ROCKETEER', 79, 758),
#  ('MOULIN WAKE', 79, 758),
#  ('SHOCK CABIN', 79, 758),
#  ('SPIKING ELEMENT', 79, 758),
#  ('WEREWOLF LOLA', 79, 758),
#  ('HOLIDAY GAMES', 78, 764),
#  ('INSIDER ARIZONA', 78, 764),
#  ('LANGUAGE COWBOY', 78, 764),
#  ('UNFAITHFUL KILL', 78, 764),
#  ('VOYAGE LEGALLY', 78, 764),
#  ('WATCH TRACY', 78, 764),
#  ('BERETS AGENT', 77, 770),
#  ('ENEMY ODDS', 77, 770),
#  ('FELLOWSHIP AUTUMN', 77, 770),
#  ('MEMENTO ZOOLANDER', 77, 770),
#  ('MOD SECRETARY', 77, 770),
#  ('PICKUP DRIVING', 77, 770),
#  ('BOONDOCK BALLROOM', 76, 776),
#  ('COMFORTS RUSH', 76, 776),
#  ('DESIRE ALIEN', 76, 776),
#  ('DESTINATION JERK', 76, 776),
#  ('HAUNTED ANTITRUST', 76, 776),
#  ('ORANGE GRAPES', 76, 776),
#  ('VILLAIN DESPERATE', 76, 776),
#  ('BALLOON HOMEWARD', 75, 783),
#  ('CALIFORNIA BIRDS', 75, 783),
#  ('FIDDLER LOST', 75, 783),
#  ('HELLFIGHTERS SIERRA', 75, 783),
#  ('LOVER TRUMAN', 75, 783),
#  ('NETWORK PEAK', 75, 783),
#  ('NEWTON LABYRINTH', 75, 783),
#  ('SATISFACTION CONFIDENTIAL', 75, 783),
#  ('STAMPEDE DISTURBING', 75, 783),
#  ('WIZARD COLDBLOODED', 75, 783),
#  ('ANGELS LIFE', 74, 793),
#  ('INFORMER DOUBLE', 74, 793),
#  ('JUMPING WRATH', 74, 793),
#  ('LUKE MUMMY', 74, 793),
#  ('MAGUIRE APACHE', 74, 793),
#  ('MODERN DORADO', 74, 793),
#  ('PEARL DESTINY', 74, 793),
#  ('RAINBOW SHOCK', 74, 793),
#  ('SILVERADO GOLDFINGER', 74, 793),
#  ('SNATCHERS MONTEZUMA', 74, 793),
#  ('TEEN APOLLO', 74, 793),
#  ('WORKING MICROCOSMOS', 74, 793),
#  ('BEDAZZLED MARRIED', 73, 805),
#  ('BRIGHT ENCOUNTERS', 73, 805),
#  ('BROTHERHOOD BLANKET', 73, 805),
#  ('FRIDA SLIPPER', 73, 805),
#  ('GODFATHER DIARY', 73, 805),
#  ('MUSKETEERS WAIT', 73, 805),
#  ('RANDOM GO', 73, 805),
#  ('REBEL AIRPORT', 73, 805),
#  ('SALUTE APOLLO', 73, 805),
#  ('STREETCAR INTENTIONS', 73, 805),
#  ('VALLEY PACKER', 73, 805),
#  ('WAKE JAWS', 73, 805),
#  ('BOWFINGER GABLES', 72, 817),
#  ('FICTION CHRISTMAS', 72, 817),
#  ('HARDLY ROBBERS', 72, 817),
#  ('MAUDE MOD', 72, 817),
#  ('BLOOD ARGONAUTS', 71, 821),
#  ('CHARIOTS CONSPIRACY', 71, 821),
#  ('KNOCK WARLOCK', 71, 821),
#  ('MANNEQUIN WORST', 71, 821),
#  ('PRINCESS GIANT', 71, 821),
#  ('TEMPLE ATTRACTION', 71, 821),
#  ('TRAIN BUNCH', 71, 821),
#  ('CANDIDATE PERDITION', 70, 828),
#  ('CHANCE RESURRECTION', 70, 828),
#  ('CLUE GRAIL', 70, 828),
#  ('COLDBLOODED DARLING', 70, 828),
#  ('GUNFIGHT MOON', 70, 828),
#  ('LOUISIANA HARRY', 70, 828),
#  ('WEDDING APOLLO', 70, 828),
#  ('CRUELTY UNFORGIVEN', 69, 835),
#  ('FLYING HOOK', 69, 835),
#  ('HEAD STRANGER', 69, 835),
#  ('HOLLYWOOD ANONYMOUS', 69, 835),
#  ('LEBOWSKI SOLDIERS', 69, 835),
#  ('TIMBERLAND SKY', 69, 835),
#  ('ARK RIDGEMONT', 68, 841),
#  ('DIVIDE MONSTER', 68, 841),
#  ('DOOM DANCING', 68, 841),
#  ('HUMAN GRAFFITI', 68, 841),
#  ('TOMATOES HELLFIGHTERS', 68, 841),
#  ('BUTCH PANTHER', 67, 846),
#  ('COMANCHEROS ENEMY', 67, 846),
#  ('EGG IGBY', 67, 846),
#  ('LADY STAGE', 67, 846),
#  ('LONELY ELEPHANT', 67, 846),
#  ('NORTH TEQUILA', 67, 846),
#  ('SHOOTIST SUPERFLY', 67, 846),
#  ('SILENCE KANE', 67, 846),
#  ('CHARADE DUFFEL', 66, 854),
#  ('EVE RESURRECTION', 66, 854),
#  ('BARBARELLA STREETCAR', 65, 856),
#  ('CLUB GRAFFITI', 65, 856),
#  ('CONFESSIONS MAGUIRE', 65, 856),
#  ('FREDDY STORM', 65, 856),
#  ('HUNTING MUSKETEERS', 65, 856),
#  ('LOVELY JINGLE', 65, 856),
#  ('PATRIOT ROMAN', 65, 856),
#  ('CRAFT OUTFIELD', 64, 863),
#  ('DESERT POSEIDON', 64, 863),
#  ('METROPOLIS COMA', 64, 863),
#  ('MILE MULAN', 64, 863),
#  ('NOVOCAINE FLIGHT', 64, 863),
#  ('SLEEPLESS MONSOON', 64, 863),
#  ('TAXI KICK', 64, 863),
#  ('TRIP NEWTON', 64, 863),
#  ('VICTORY ACADEMY', 64, 863),
#  ('ALADDIN CALENDAR', 63, 872),
#  ('BONNIE HOLOCAUST', 63, 872),
#  ('BORROWERS BEDAZZLED', 63, 872),
#  ('BOULEVARD MOB', 63, 872),
#  ('BUNCH MINDS', 63, 872),
#  ('DINOSAUR SECRETARY', 63, 872),
#  ('FORREST SONS', 63, 872),
#  ('INTOLERABLE INTENTIONS', 63, 872),
#  ('REUNION WITCHES', 63, 872),
#  ('AIRPLANE SIERRA', 62, 881),
#  ('ARABIA DOGMA', 62, 881),
#  ('HANGING DEEP', 62, 881),
#  ('MARS ROMAN', 62, 881),
#  ('SNOWMAN ROLLERCOASTER', 62, 881),
#  ('UNBREAKABLE KARATE', 62, 881),
#  ('BIRDS PERDITION', 61, 887),
#  ('BULWORTH COMMANDMENTS', 61, 887),
#  ('CAMELOT VACATION', 61, 887),
#  ('CASSIDY WYOMING', 61, 887),
#  ('CHINATOWN GLADIATOR', 61, 887),
#  ('DRIFTER COMMANDMENTS', 61, 887),
#  ('POLISH BROOKLYN', 61, 887),
#  ('RESERVOIR ADAPTATION', 61, 887),
#  ('TROUBLE DATE', 61, 887),
#  ('WATERFRONT DELIVERANCE', 61, 887),
#  ('BUBBLE GROSSE', 60, 897),
#  ('JERSEY SASSY', 60, 897),
#  ('MOCKINGBIRD HOLLYWOOD', 60, 897),
#  ('PHANTOM GLORY', 60, 897),
#  ('PITY BOUND', 60, 897),
#  ('ROOM ROMAN', 60, 897),
#  ('SHAKESPEARE SADDLE', 60, 897),
#  ('SMILE EARRING', 60, 897),
#  ('COMMANDMENTS EXPRESS', 59, 905),
#  ('DAUGHTER MADIGAN', 59, 905),
#  ('HEARTBREAKERS BRIGHT', 59, 905),
#  ('INTERVIEW LIAISONS', 59, 905),
#  ('JET NEIGHBORS', 59, 905),
#  ('LEGEND JEDI', 59, 905),
#  ('MINORITY KISS', 59, 905),
#  ('VISION TORQUE', 59, 905),
#  ('WHISPERER GIANT', 59, 905),
#  ('CLOSER BANG', 58, 914),
#  ('DANCES NONE', 58, 914),
#  ('FANTASY TROOPERS', 58, 914),
#  ('JEKYLL FROGMEN', 58, 914),
#  ('OKLAHOMA JUMANJI', 58, 914),
#  ('RINGS HEARTBREAKERS', 58, 914),
#  ('SUPER WYOMING', 58, 914),
#  ('ALTER VICTORY', 57, 921),
#  ('CRANES RESERVOIR', 57, 921),
#  ('DAWN POND', 57, 921),
#  ('DOCTOR GRAIL', 57, 921),
#  ('MOSQUITO ARMAGEDDON', 57, 921),
#  ('NOON PAPI', 57, 921),
#  ('STORM HAPPINESS', 57, 921),
#  ('BRIDE INTRIGUE', 56, 928),
#  ('CUPBOARD SINNERS', 56, 928),
#  ('DESTINY SATURDAY', 56, 928),
#  ('GOODFELLAS SALUTE', 56, 928),
#  ('MATRIX SNOWMAN', 56, 928),
#  ('COAST RAINBOW', 55, 933),
#  ('WOLVES DESIRE', 55, 933),
#  ('AIRPORT POLLOCK', 54, 935),
#  ('GO PURPLE', 54, 935),
#  ('JUGGLER HARDLY', 54, 935),
#  ('KILL BROTHERHOOD', 54, 935),
#  ('OCTOBER SUBMARINE', 54, 935),
#  ('SENSE GREEK', 54, 935),
#  ('BENEATH RUSH', 53, 941),
#  ('CABIN FLASH', 53, 941),
#  ('GUMP DATE', 53, 941),
#  ('MAGNIFICENT CHITTY', 53, 941),
#  ('MOVIE SHAKESPEARE', 53, 941),
#  ('PRIMARY GLASS', 53, 941),
#  ('SUMMER SCARFACE', 53, 941),
#  ('TEQUILA PAST', 53, 941),
#  ('THIN SAGEBRUSH', 53, 941),
#  ('CADDYSHACK JEDI', 52, 950),
#  ('HARPER DYING', 52, 950),
#  ('LUST LOCK', 52, 950),
#  ('SIDE ARK', 52, 950),
#  ('SPARTACUS CHEAPER', 52, 950),
#  ('TROJAN TOMORROW', 52, 950),
#  ('WESTWARD SEABISCUIT', 52, 950),
#  ('CHAMPION FLATLINERS', 51, 957),
#  ('DEEP CRUSADE', 51, 957),
#  ('ENGLISH BULWORTH', 51, 957),
#  ('EXCITEMENT EVE', 51, 957),
#  ('FRISCO FORREST', 51, 957),
#  ('HALL CASSIDY', 51, 957),
#  ('SIMON NORTH', 51, 957),
#  ('ADAPTATION HOLES', 50, 964),
#  ('BLUES INSTINCT', 50, 964),
#  ('CROSSING DIVORCE', 50, 964),
#  ('LION UNCUT', 50, 964),
#  ('MUPPET MILE', 50, 964),
#  ('NATURAL STOCK', 50, 964),
#  ('PILOT HOOSIERS', 50, 964),
#  ('SMOKING BARBARELLA', 50, 964),
#  ('ZORRO ARK', 50, 964),
#  ('DOORS PRESIDENT', 49, 973),
#  ('GROSSE WONDERFUL', 49, 973),
#  ('HEAVENLY GUN', 49, 973),
#  ('HOOK CHARIOTS', 49, 973),
#  ('HURRICANE AFFAIR', 49, 973),
#  ('ACE GOLDFINGER', 48, 978),
#  ('HEAVEN FREEDOM', 48, 978),
#  ('MIDSUMMER GROUNDHOG', 48, 978),
#  ('NOTTING SPEAKEASY', 48, 978),
#  ('ODDS BOOGIE', 48, 978),
#  ('PARADISE SABRINA', 48, 978),
#  ('PELICAN COMFORTS', 48, 978),
#  ('RUSH GOODFELLAS', 48, 978),
#  ('STEPMOM DREAM', 48, 978),
#  ('SUNSET RACER', 48, 978),
#  ('VALENTINE VANISHING', 48, 978),
#  ('DIVORCE SHINING', 47, 989),
#  ('DOWNHILL ENOUGH', 47, 989),
#  ('HALLOWEEN NUTS', 47, 989),
#  ('HANOVER GALAXY', 47, 989),
#  ('HAWK CHILL', 47, 989),
#  ('SHANGHAI TYCOON', 47, 989),
#  ('SUSPECTS QUILLS', 47, 989),
#  ('ALIEN CENTER', 46, 996),
#  ('IRON MOON', 46, 996),
#  ('KWAI HOMEWARD', 46, 996),
#  ('LABYRINTH LEAGUE', 46, 996),
#  ('RIDGEMONT SUBMARINE', 46, 996)]

# %%
# 2

# %%
# %%sql
# select title, length, rating, rank() over (practition by ranking order by length desc) as 'Rank' from sakila.film
# where length is not null and length>0;
# Out:
#  * mysql+pymysql://root:***@localhost/bank
# (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'by ranking order by length desc) as 'Rank' from sakila.film\nwhere length is not ' at line 1")
# [SQL: select title, length, rating, rank() over (practition by ranking order by length desc) as 'Rank' from sakila.film
# where length is not null and length>0;]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %%
# 3

# %%
# %%sql
# select name as category_name, count(*) as num_films
# from sakila.category inner join sakila.film_category using (category_id)
# group by name
# order by num_films desc;
# Out:
#  * mysql+pymysql://root:***@localhost/bank
# 16 rows affected.
# [('Sports', 74),
#  ('Foreign', 73),
#  ('Family', 69),
#  ('Documentary', 68),
#  ('Animation', 66),
#  ('Action', 64),
#  ('New', 63),
#  ('Drama', 62),
#  ('Games', 61),
#  ('Sci-Fi', 61),
#  ('Children', 60),
#  ('Comedy', 58),
#  ('Classics', 57),
#  ('Travel', 57),
#  ('Horror', 56),
#  ('Music', 51)]

# %%
# 4

# %%
# 4
# %%sql
select actor.actor_id, actor.first_name, actor.last_name,
count(actor_id) as film_count
from sakila.actor join sakila.film_actor using (actor_id)
group by actor_id
order by film_count desc
limit 1;
# Out:
#   Input In [46]
#     select actor.actor_id, actor.first_name, actor.last_name,
#            ^
# SyntaxError: invalid syntax

# %%
# 5
# %%sql
select customer.*,
count(rental_id) as rental_count
from sakila.customer join sakila.rental using (customer_id)
group by customer_id
order by rental_count desc
limit 1;
# Out:
#   Input In [47]
#     select customer.*,
#            ^
# SyntaxError: invalid syntax

# %%
# Bonus 
# %%sql
select film.title, count(rental_id) as rental_count
from sakila.film inner join sakila.inventory using (film_id)
inner join sakila.rental using (inventory_id)
group by film_id
order by rental_count desc
limit 1;
# Out:
#   Input In [48]
#     select film.title, count(rental_id) as rental_count
#            ^
# SyntaxError: invalid syntax
